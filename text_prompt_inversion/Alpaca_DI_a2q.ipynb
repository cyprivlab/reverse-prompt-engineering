# %% [markdown]
# # Load Dataset and re-process

# %%
from datasets import load_dataset,load_from_disk

# %%
# Load dataset
dataset = load_dataset('vicgalle/alpaca-gpt4')

# %%
print(dataset['train'])
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output', 'text'],
#     num_rows: 52002
# })

# %% [markdown]
# # Different models training

# %%
DI_model_save_name = 'compare_work/DI_alpaca_0.2_t5_small_10e_2'
DI_generation_texts_pth = 'compare_work/DI_alpaca_gen_0_2_10e_2.txt'
#DI_FT_generation_texts_pth = 'compare_work/DI_FT_alpaca_gen_0_2_10e_2.txt'

# %% [markdown]
# ## DI-t5-small

# %%
def preprocess_t5_data(example,index):
    if example['output']:
        answer_text = example['output']
    else:
        answer_text = "No answer found"
    return {
        'index':index,
        'input_text': f"answer: {answer_text}",
        'target_text': f"enquiry: {example['instruction']+' '+example['input']}" 
    }

processed_t5small_dataset = dataset.map(preprocess_t5_data,with_indices=True)

# %%
processed_t5small_dataset['train']['target_text']

# %%
train_test_split_t5 = processed_t5small_dataset['train'].train_test_split(test_size=0.2)
train_dataset_t5 = train_test_split_t5['train']
val_dataset_t5 = train_test_split_t5['test']

# %%
val_dataset_t5
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output', 'text', 'index', 'input_text', 'target_text'],
#     num_rows: 10401
# })

# %%
train_dataset_t5.save_to_disk(dataset_path='compare_work/alpaca-0.2-train')
val_dataset_t5.save_to_disk(dataset_path='compare_work/alpaca-0.2-test')

# %%
from datasets import load_dataset,load_from_disk

train_dataset_t5 = load_from_disk('Ans2Seq/compare_work/alpaca-0.2-train')
val_dataset_t5 = load_from_disk('Ans2Seq/compare_work/alpaca-0.2-test')

# %%
from transformers import T5Tokenizer

t5_tokenizer = T5Tokenizer.from_pretrained('t5-small')

def tokenize_t5_function(examples):
    model_inputs = t5_tokenizer(examples['input_text'], padding="max_length", truncation=True)
    labels = t5_tokenizer(examples['target_text'], padding="max_length", truncation=True)
    print(labels)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_train_dataset_t5 = train_dataset_t5.map(tokenize_t5_function, batched=True)
tokenized_val_dataset_t5 = val_dataset_t5.map(tokenize_t5_function, batched=True)

# %%
import torch
from transformers import T5ForConditionalGeneration

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

t5_model = T5ForConditionalGeneration.from_pretrained('t5-small').to(device)

# %%
from transformers import Trainer, TrainingArguments

training_args_t5 = TrainingArguments(
    output_dir= DI_model_save_name,
    evaluation_strategy="epoch",
    learning_rate=3e-4,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=10,
    report_to="none"
)

trainer_t5 = Trainer(
    model=t5_model,
    args=training_args_t5,
    train_dataset=tokenized_train_dataset_t5,
    eval_dataset=tokenized_val_dataset_t5
)
# Out:
# 2024-10-09 21:53:09.958141: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-09 21:53:09.973497: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-09 21:53:09.973516: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-09 21:53:09.973530: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-09 21:53:09.976964: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-09 21:53:10.337032: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
trainer_t5.train()

# %%
trainer_t5.save_model(DI_model_save_name) 
t5_tokenizer.save_pretrained(DI_model_save_name)
# Out:
# Saving model checkpoint to compare_work/DI_alpaca_0.2_t5_small_10e_2
# Configuration saved in compare_work/DI_alpaca_0.2_t5_small_10e_2/config.json
# Model weights saved in compare_work/DI_alpaca_0.2_t5_small_10e_2/pytorch_model.bin
# tokenizer config file saved in compare_work/DI_alpaca_0.2_t5_small_10e_2/tokenizer_config.json
# Special tokens file saved in compare_work/DI_alpaca_0.2_t5_small_10e_2/special_tokens_map.json
# ('compare_work/DI_alpaca_0.2_t5_small_10e_2/tokenizer_config.json',
#  'compare_work/DI_alpaca_0.2_t5_small_10e_2/special_tokens_map.json',
#  'compare_work/DI_alpaca_0.2_t5_small_10e_2/spiece.model',
#  'compare_work/DI_alpaca_0.2_t5_small_10e_2/added_tokens.json')

# %%
def generate_question(answer):
    t5_model.eval()  
    input_ids = t5_tokenizer.encode("answer: " + answer, return_tensors="pt").to(device)
    outputs = t5_model.generate(input_ids, num_beams=5, early_stopping=True)
    question = t5_tokenizer.decode(outputs[0], skip_special_tokens=True)
    return question

# %%
from tqdm import tqdm


samples = val_dataset_t5  
res = []

with open(DI_generation_texts_pth, 'a') as file:
    for example in tqdm(samples):
        generated_question = generate_question(example['input_text'].replace("answer: ", ""))
        res.append(generated_question.replace("enquiry: ", ""))
        file.write((generated_question.replace("enquiry: ", "")+'\n'))
        # print(f"Answer: {example['input_text'].replace('answer: ', '')}")
        # print(f"Generated Question: {generated_question}")
        # print(f"Actual Question: {example['target_text']}\n")
# Out:
#   1%|          | 53/10401 [00:02<07:43, 22.33it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (513 > 512). Running this sequence through the model will result in indexing errors
#  13%|█▎        | 1393/10401 [00:59<06:14, 24.03it/s]
# 100%|██████████| 10401/10401 [07:18<00:00, 23.70it/s]

# %%
from datasets import load_metric
from nltk.tokenize import word_tokenize
from bert_score import score
from nltk.translate.meteor_score import meteor_score
import evaluate
import pandas as pd
import numpy as np
import torch

def Calmetic(references:list[list[str]], predictions:list[str]):
    '''
    Input format:

    predictions = [
        "What is the capital of France?",
        "Who wrote the book?",
        "What is the largest planet?"
    ]

    references = [
        ["What is the capital city of France?"],
        ["Who is the author of the book?"],
        ["Which planet is the largest in the solar system?"]
    ]
    '''

    # # Load BLEU scorer
    # bleu_metric = load_metric("bleu")

    # # Calculate BLEU score
    predictions_tokenized = [word_tokenize(pred) for pred in predictions]
    references_tokenized = [[word_tokenize(refs[0])] for refs in references]
    # B_S = {}
    # for n in range(1, 5):
    #     bleu_metric.add_batch(predictions=predictions_tokenized, references=references_tokenized)
    #     results = bleu_metric.compute(max_order=n)
    #     B_S[f"BLEU-{n}"] = results
    bleu_metric = evaluate.load("bleu")
    B_S = bleu_metric.compute(predictions=predictions, references=references,tokenizer=word_tokenize)
    for i,n in enumerate(B_S['precisions']):
        print(f"BLEU-{i+1} score: {n:.5f}")
        


    # Load ROUGE scorer
    rouge_metric = load_metric("rouge")
    '''
    ROUGE-1: Measures unigram matches between generated text and reference text.
    ROUGE-2: Measures bigram matches between generated text and reference text.
    ROUGE-L: Measures the longest common subsequence (LCS) between generated text and reference text.
    ROUGE-Lsum: A variant based on LCS, specifically designed for evaluating long texts.
    '''
    # Calculate ROUGE scores
    rouge_results = rouge_metric.compute(predictions=predictions, references=references)
    rouge1_mid_f1 = rouge_results['rouge1'][1][2]
    rouge2_mid_f1 = rouge_results['rouge2'][1][2]
    rougeL_mid_f1 = rouge_results['rougeL'][1][2]
    rougeLsum_mid_f1 = rouge_results['rougeLsum'][1][2]
    print(f"ROUGE-1 F1 score: {rouge1_mid_f1:.5f}")
    print(f"ROUGE-2 F1 score: {rouge2_mid_f1:.5f}")
    print(f"ROUGE-L F1 score: {rougeL_mid_f1:.5f}")
    print(f"ROUGE-Lsum F1 score: {rougeLsum_mid_f1:.5f}")

    # Calculate METEOR score
    meteor_scores = [meteor_score(references=refs, hypothesis=pred) for pred, refs in zip(predictions_tokenized, references_tokenized)]
    average_meteor_score = sum(meteor_scores) / len(meteor_scores)
    print(f"Average METEOR score: {average_meteor_score:.5f}")

    # Calculate BERTScore

    P, R, F1 = score(predictions, [ref[0] for ref in references], lang="en", verbose=False)
    average_bert_score = F1.mean().item()
    print(f"Average BERTScore F1: {average_bert_score:.5f}")

    return {
        "BLEU":B_S,
        "ROUGE":rouge_results,
        "METERO":meteor_scores,
        "BERTScore":{"Precision":P,"Recall":R,"F1":F1},
    }

# %%
with open(DI_generation_texts_pth, 'r') as file:
    content = file.readlines()

# %%
refs = [ [i.replace('enquiry: ',"")] for i in val_dataset_t5['target_text']]

# %%
refs
# Out:
# [['Generate a simile comparing a sunset to fiction. '],
#  ['What is the leading cause of death for children under the age of 5? '],
#  ['Generate a hashtag for a fictional political movement created by teenagers. '],
#  ['Name three common validation techniques used in Machine Learning. '],
#  ['Assign an appropriate name to the following new species of butterfly. '],
#  ['Tell me something about a Nissan leaf. '],
#  ['Create a summary of the following text in no more than 4 lines. The effect of gun violence in the United States is widespread. According to the CDC, in 2018 there were 38,390 deaths due to firearm. Of these, 24,432 were suicides. The rate of firearm deaths per 100,000 people increased from 10.3 per 100,000 in 1999 to 12 per 100,000 in 2017.'],
#  ['Fill in the blank with an appropriate preposition: I like to stay ____ top of my work.'],
#  ['Compose an email to a potential client explaining the benefits of your service. '],
#  ['Provide an appropriate metaphor for the following situation. The sun is beginning to set against the horizon.'],
#  ['Create a design for a web page about local movie theatres '],
#  ['Generate an AI-generated Insult '],
#  ['Generate an appropriate response when an employee has tried his best to do a task but failed. '],
#  ['Find the verb in the sentence. He sometimes visits his grandparents.'],
#  ['Create ten multiple-choice questions about the topic of history. '],
#  ['Make a valid sentence using the words "quick," "brown," and "fox." '],
#  ['Suggest a title for an essay about the right to privacy. '],
#  ['Construct an analogy for the following sentence: "A computer is to code what a chef is to food." '],
#  ['What is the importance of using project management software? '],
#  ['Edit the following sentence to eliminate redundancy. The verdict of the court was unanimous in agreement.'],
#  ['What is the aproximate population of the UK? '],
#  ['Develop an algorithm that can recognize handwriting. '],
#  ['Write a story beginning with “He saw himself reflected in the mirror…” '],
#  ['Identify a cybersecurity risk that could affect an online store. '],
#  ['Generate an input data set that has three members and five attributes. '],
#  ['Name five dangers of space exploration. '],
#  ['Invent a computer gaming character that uses magic. '],
#  ['What are the key ingredients of Fajitas? '],
#  ['Identify which of these objects is not a mineral. Garnet, Gold, Ceramic'],
#  ['Tell me what the article below is about. The article is about the growth of artificial intelligence in healthcare.'],
#  ['Name two types of unsupervised learning. '],
#  ['Propose an alternative solution to the following problem: The current system of food delivery is inefficient and leads to wastage.'],
#  ["Identify the person in the following sentence. Output the person's name My brother likes to play football"],
#  ['Design a GPT model to generate a chatbot that helpsthe user find hotels in a certain city. '],
#  ['Rank the following items in order of relevance to the topic of artificial intelligence. Robotics, Machine Learning, Natural Language Processing'],
#  ['Take a complicated theory or concept, and explain it as simply as possible. The Catastrophe Theory'],
#  ['Create a research outline for a paper that examines the causes of poverty in the United States. '],
#  ['Give an example of a verb ending in -ed. '],
#  ['Write a jingle for an energy bar '],
#  ['Generate a list of US Presidents. '],
#  ['Write a comment for a given post "I\'m so excited for my graduation day!"'],
#  ['Sort these numbers from lowest to highest. 3, 2, 7, 5'],
#  ['Use the given information to create a multiple choice question. Person: Julius Caesar \nFact: Assassinated in 44 BC \nTime: Autumn 2020'],
#  ['Generate 5 tips on how to improve your public speaking skills. '],
#  ['Rearrange the given sentence to be an interrogative sentence. She moved to the United States two years ago.'],
#  ['Rewrite the given sentence with fewer words but not sacrificing any information from the original sentence. We have to make sure that every single person follows the safety regulations.'],
#  ['Categorize the phrase under the appropriate labels. Hurricanes'],
#  ['Create two authentic Thai dishes. '],
#  ['Analyze similarities and differences between two arguments. Argument A: We should tax the wealthy to help fund social programs.\nArgument B: All citizens should pay the same amount in taxes regardless of their income.'],
#  ['Suggest a question to ask in a job interview. '],
#  ['Provide the output of code that completes the given matrix with the sum of each row. matrix = [[1, 2, 3], \n          [2, 3, 4], \n          [3, 4, 5]]'],
#  ['Translate the following sentence into French:\n"We had a great time" '],
#  ['Create a blog post of 300-400 words discussing the benefits of a healthy lifestyle. No Input'],
#  ['Describe the significance of the Crick–Watson model. '],
#  ['Predict the possible outcomes of the following situation. A student studying for an important exam has to decide between going to bed early or staying up late to study.'],
#  ['Design a workflow for a machine learning system to analyze customer sentiment on social media. '],
#  ['Generate a musical arrangement that includes melodic lines, chords and accompanying instruments. '],
#  ['Name five famous companies that are famous for their customer service. '],
#  ['Select a topic to write an essay about. '],
#  ['Create a marketing campaign to promote a new food delivery service. '],
#  ['Name one major feature of an eagle. '],
#  ['Group the words according to their part of speech. Strong, long, apple'],
#  ['Create a list of the differences between quantitative and qualitative data. '],
#  ['Given the following sentence, make a sentence that uses a specific literary device. The river was raging.'],
#  ['Construct a numerical series where each number is the sum of its two predecessor numbers. '],
#  ['Below is a text, correct the grammatical errors. Globle warming are bothering us.'],
#  ['Design an algorithm to remove duplicates from a given array. '],
#  ['Change the following sentence so that it no longer contains the modifier "very". She is a very nice person.'],
#  ['List three elements of a successful brand. '],
#  ['Describe the meaning of the phrase "carpe diem." '],
#  ['List all the even numbers from a given array [1, 2, 3, 4, 5, 6]'],
#  ['Name some computer viruses '],
#  ['Generate a recipe for making a vanilla milkshake. '],
#  ['Name three factors that could cause the rapid melting of sea ice in the North Atlantic Ocean. '],
#  ["Rewrite the following paragraph to make it sound more formal. Moving away from home to college was really hard. It's like I had to let go of my comfort and safety and figure things out on my own."],
#  ['Reword the sentence by changing its tense to the past. The driver carefully turns the corner.'],
#  ['Display the sentiment of the statement The movie was terrible.'],
#  ['Analyze the following quote: "Life is what you make it." '],
#  ['Generate a list of 5 popular songs from the 1990s. '],
#  ['Compose a news article about the latest tech advancements '],
#  ['List 5 tips for improving public speaking skills. '],
#  ['Give an example of a time when an animal displayed an act of heroism. '],
#  ['Identify two potential interpretations of the sentence. I said goodbye to my parents.'],
#  ['Spell out the given word in 3 different ways. Receive'],
#  ['Write an imaginary dialogue between a doctor and a patient '],
#  ['Give an example of an active sentence using the verb "give". '],
#  ['Generate a story based on this context Once upon a time, there was a brave knight who had a magical sword that could slay any monster.'],
#  ['Generate a dialogue between two customers arguing about price. '],
#  ['Modify the sentence to include the phrase "in addition". He went for a run, took a long walk.'],
#  ['What is the gerund of the verb "run"? '],
#  ['Find and replace all misspelled words in the sentence. We need to acomplish this tusk by end of day.'],
#  ['Classify the following as a concrete or abstract noun. ruthlessness'],
#  ['What type of clothing is required for cold weather? '],
#  ['Reverse engineer a solution for the given problem. How to minimize wait times in customer service?'],
#  ['Compare and contrast the two styles of writing: writing for outdoor media versus writing for academic purposes. '],
#  ['Describe a person called Tom. '],
#  ['Find the range of numbers 25, 28, 30, 33 '],
#  ['Name two applications of trigonometric functions in real life. '],
#  ['Find a suitable title for the poem. He is the only one\nToo much to him I owe\nHis grace more sweet than honey\nHis face the gentlest glow'],
#  ['Generate a funny pun about the internet. '],
#  ['What are four ways to save money? '],
#  ['Write a news article about a new product. Product: Smart Car'],
#  ['Generate a list of 10 ways to be kind to the environment. '],
#  ['Generate a creative idea for an aquarium. '],
#  ['Analyze the below social media post and identify the most effective marketing strategy used. ![Social Media Post](https://i2.wp.com/techwood.in/wp-content/uploads/2020/06/Spinny-Feat1.jpg?fit=1080%2C810&ssl=1)'],
#  ['Pick the antonym of the following word. Fate'],
#  ['Classify the major cities in Japan. Tokyo, Osaka, Yokohama'],
#  ['Given a sentence, output the number of vowels and the number of consonants. She had to decide what to do.'],
#  ['Write a step-by-step procedure to make chocolate chip cookies. '],
#  ['Analyze the label of the alcohol and tell what the bottle contains. Label: an Irish Whiskey with a smooth finish.'],
#  ['Rewrite the given paragraph in a shorter, easier to understand form. Although it is generally accepted that the internet has allowed us to connect with people all over the world, there are still those people who are not familiar with its basic functions, who don’t understand why it has become so commonplace, or what its true capabilities are.'],
#  ['Name a Harry Potter character. '],
#  ['You must come up with a character for a film. '],
#  ['Write a response to a customer who is complaining about the wrong delivery. We received a wrong delivery and need the correct item ASAP.'],
#  ['Generate a properly formed question based on the given sentence. She had a difficult journey.'],
#  ['Name one disadvantage of using a credit card. '],
#  ['Explain why cell phones are useful. No input.'],
#  ['Give a critique of this poem. I am a poet\nof life and of light\nIn my words I must strive\nto make a lasting impression.'],
#  ['Generate a creative product description of a <mask>. Make sure to include the features and benefits of the product. Bluetooth Headset'],
#  ['Identify the use of language She screamed in terror'],
#  ['Find the element present in both of the given lists: List A: [2, 5, 10] \nList B: [3, 6, 9]'],
#  ['Name one artist from the 20th century. '],
#  ['Create a new word that has the following attributes: 1. verb, 2. can be used in everyday conversation, 3. consists of 4 letters '],
#  ['Edit the following sentence to make it grammatically correct: "The patient had to put on a ventilator to surgery" '],
#  ['Construct a persuasive letter to persuade a school to reduce their fees '],
#  ['Find ways to improve the following code snippet. def leap_year(year): \n    if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0: \n        return True \n    else: \n        return False'],
#  ['Synthesize an argument in support of renewable energy sources. '],
#  ['Assign a category to the given list of words. food, furniture, books'],
#  ['Come up with 10 math terms and their respective meanings '],
#  ['List the different forms of energy. '],
#  ['Compare the differences between the effects of the pandemic on traditional retail and online retail '],
#  ['Suggest a 5-star restaurant for the following group: a vegetarian and two meat-eaters. '],
#  ['Give an example of a country located in South America. '],
#  ["Eliminate the double negative in the following sentence I can't not go"],
#  ['Describe how the author uses imagery. The lion roared so loudly that it shook the ground.'],
#  ['Share two tips on how to write concisely. '],
#  ['Generate a list of five characteristics of an ideal leader. '],
#  ['How would you encourage someone to try something new '],
#  ['Explain why a country may use tariffs '],
#  ['Edit the given text so that it follows APA formatting style. Writting in the APA style is important in order to make sure that your work is correctly documented'],
#  ['Create a song title that fits the given theme. Summer'],
#  ['Create an equation to represent a linear trend. '],
#  ['Suggest an alternative to using plastic bags. '],
#  ['Identify the figures of speech used in the given text Life is going to hit you hard'],
#  ['Classification Task - Classify the following piano piece as classical or jazz genre. https://www.youtube.com/watch?v=hPUTzyOyfN4'],
#  ['Design a logo for an app related to budgeting '],
#  ['Create a classifcation model to determine whether a given mammal is a carnivore or an herbivore. Fennec Fox'],
#  ['Find an example of a web page that includes an account creation form. '],
#  ['Determine if the following numbers are prime or not. Output 1 for prime, and 0 for not prime. 19'],
#  ['Analyze a given dataset and describe the insights from it. Dataset: Weather Temperature variations over the past month'],
#  ['Design an interface for a new productivity app. '],
#  ['Describe how a specific character participates in the climax of a novel. Harry Potter in "Harry Potter and the Deathly Hallows"'],
#  ['Sort this list from shortest to longest. Giraffe, Chimpanzee, Kangaroo, Gorilla'],
#  ['Write a 500-word article summarizing the challenges associated with developing self-driving cars. '],
#  ['Generate a tweet promoting a vegan lifestyle '],
#  ['Given the following chart, explain the trend it is showing <image of a chart showing a trend>'],
#  ['Tell me what type of diet the following statement is referring to. "I\'m aiming to eliminate processed food, animal sources of saturated fats, and dietary cholesterol from my diet."'],
#  ['Suggest me a way to save money on a family vacation. '],
#  ['Generate a limerick that rhymes with the given word. Fox'],
#  ['Please provide a brief explanation of the differences between a deep learning algorithm and a traditional machine learning algorithm. '],
#  ['Name a professional organization that a software engineer would be interested in joining. '],
#  ['Given an ingredient, provide a recipe that can be prepared with the ingredient. Eggs'],
#  ['Evaluate the given website. https://example.com'],
#  ['Write a summary of the article "The Impact of Social Media on Student Stress". '],
#  ['What scientific evidence is there that laughter is beneficial to our health? '],
#  ['Turn this paragraph into a story. John woke up early to a beautiful sunny day. He got out of bed, put on his sneakers, and grabbed his backpack. He was excited to explore the forest he had been dreaming of for months.'],
#  ['Change the text formatting of the following sentence to make it easier to read. Thestudenthadacomplexproblemtocomplete'],
#  ['Categorize the following restaurant as being a fast-food restaurant or a classic restaurant. It is a small restaurant that serves Mexican food.'],
#  ['Given a piece of text, identify the tense used. I would like to have a meeting today.'],
#  ['Write a letter to persuade the reader to do something. Conduct a research project'],
#  ['Explain what a blockchain is and its benefits '],
#  ['Given a list of countries, find the ones with the lowest population. India, Brazil, Mexico, China, Germany'],
#  ['Given the phrase, rephrase it without changing the original meaning. "Don\'t count your chickens before they hatch"'],
#  ['What food is New York famous for? '],
#  ['Say two sentences that could go in an email to a customer who has a complaint. '],
#  ['Categorise the following word: "Aliquippa". '],
#  ["Rewrite the following sentence in a more fluent way: “I ran away, so the monster won't catch me” "],
#  ['Given a list of materials, come up with a plan to build a table. Materials: Wood, paint, glue, nails, screws'],
#  ['Convert 179 centimeters to feet. 179 centimeters'],
#  ['How can we increase the engagement rate of emails? '],
#  ['Edit the following sentence: "Joanna loves to to go swimming." Joanna loves to to go swimming.'],
#  ['How many gigs are in a terabyte? '],
#  ['Name a popular product manufactured by Apple. '],
#  ['Generate an original sentence that begins with “If only". '],
#  ['What is the best way to play an E chord on a guitar? '],
#  ['Name a common chess opening move. '],
#  ['Name three tropical birds. '],
#  ['Write a snippet of code to find the largest number in the array. [1, 5, 7, 18, 24, 32]'],
#  ['Write a step-by-step guide on how to backup and restore a database. '],
#  ['Find a title for a book discussing environment protection. '],
#  ['Generate a password containing 8 characters with one number and one special character. '],
#  ['Analyze what themes are present in the text below: Every summer, our family would make the eight-hour drive from Atlanta to Corpus Christi, Texas. We would stay in a rustic guest house with nothing more than the sound of the wind and the tide. Every morning, my grandmother would take me to the beach, and while the sun rose over the horizon, I would dig my toes into the sand and make sandcastles with my siblings.'],
#  ['Describe what intelligence is and its role in psychology. '],
#  ['How would you explain the concept of natural language processing (NLP) to a 6th grader? '],
#  ['Create a list of tasks that should be done to prepare for a long camping trip. '],
#  ["Choose the better summary of the given context from the given two summaries. Context: Several icecaps on the Greenland ice sheet have started to melt rapidly.\n\nSummaries:\na. The Greenland ice sheet has lost numerous icecaps over time.\nb. Greenland's icecaps are quickly melting away."],
#  ['Describe the ideal workspace '],
#  ['Create a recipe for mashed potato pancakes. '],
#  ['Describe a difficult situation that you have faced and how you worked to overcome it. '],
#  ['Find and identify a historic landmark in the US. '],
#  ['Given a set of equations, solve them 2x + 7y = 5\n3x - 7y = 5'],
#  ['Reflect the following matrix about the vertical axis. [[1, 2], [3, 4]]'],
#  ['What are the differences between the terms "agent" and "organization"? '],
#  ['Classify the following items as clothing, food, and toys: shirt, banana, doll. '],
#  ['What can I do to reduce the costs of hosting a website? '],
#  ['Research the regulations for motor vehicle emission standards in California. '],
#  ['Describe the story based on the given description. Description:\nAn old man lives a simple life in a small, remote village in the mountains. He is a recluse who mostly keeps to himself but loves to visit the nearby forest every day.'],
#  ['Generate a movie quote using the following words: adventure, destiny, courage. '],
#  ['Create a list of activities for hosting a virtual scavenger hunt '],
#  ['Solve the following equation 2x+5=7'],
#  ['Summarize an article titled "Advantages of Owning a Pet" '],
#  ['Come up with a list of ways to reduce carbon footprints. '],
#  ['Estimate the number of African countries that have ratified the African Charter on the Rights and Welfare of the Child. '],
#  ['Find an appropriate response for the following question: What is the best way to make new friends? No input'],
#  ['Create an algorithm to arrange a set of numbers from lowest to highest [3,7,2,4,9]'],
#  ['Generate a fun fact about the cuisines of Thailand. '],
#  ['Please write a brief description of what stress is and how it can affect an individual. '],
#  ['Describe a home kitchen '],
#  ['Brainstorm 5 keywords related to the following article In this article, we will explore the concept of online privacy.'],
#  ['Reword the following sentence making it shorter and more punchy. We are looking for food delivery services in the region that offer reasonably priced meals.'],
#  ['Generate a list of five topics for discussion for a group of teenagers. '],
#  ['Write a lesson plan for teaching basic coding. '],
#  ["Summarize the given text in 1 sentence The Mediterranean Sea is a sea located between Europe, northern Africa, and the Middle East. It is connected to the Atlantic Ocean through the Strait of Gibraltar and to the Red Sea through the Suez Canal. It is bordered by a number of nations, including Italy, Spain, Greece, France, Turkey and Spain. The Mediterranean Sea is known for its warm climates and its diverse marine life, with some of the world's most popular beaches located in the area."],
#  ['Generate an argument for or against the use of robots in the workplace '],
#  ["Given a sentence, classify the sentiment in the sentence as 'Positive', 'Negative' or 'Neutral'. Sentence: I have had a wonderful day."],
#  ['Rewrite the formula $y = \\frac{2x-1}{3}$ so that it can be solved for x. '],
#  ['Re-write the following sentence omitting the word "comfortable". We were quite comfortable with our decision.'],
#  ["Write a code to output a word pyramid from the word 'apple.' "],
#  ['Calculate the length of an arc with the following parameters. Angle of arc = 90°\nRadius = 5m'],
#  ['Why is it important to eat healthy food? '],
#  ['Propose a plan to reduce air pollution in urban areas. '],
#  ['Why is Python a good language for data science? '],
#  ['Create a brand name which stands for a product. Product: Laptop'],
#  ['Classify the following sentence according to their emotions: I am so pleased with you. '],
#  ['Group the following words according to their type. Output a list with the groups.\n1) Noun; 2) Adjective; 3) Verb happy, dog, barking'],
#  ['Explain the historical significance of the Cuban Missile Crisis. '],
#  ['Give a health-related tip '],
#  ['What data should I collect to calculate market share? '],
#  ['Classify a set of data as valid or invalid. Apple, Amazon, Google'],
#  ['Complete the sentence by providing an appropriate word. She was wearing a ____ dress.'],
#  ['Create a couplet about the joy of being together '],
#  ['Develop a plan to reduce electricity usage in a home. '],
#  ['What is the average annual salary for a customer service developer? '],
#  ['Add two numbers together. 25 + 45'],
#  ['Automatically generate a logo given the following business name and design guidelines. Business Name: Awesome Cafe\nDesign Guidelines: Abstract design with an emphasis on vibrant colors.'],
#  ['Remove any unnecessary words from the following sentence to make the sentence concise: I believe that it is important to be kind to others.'],
#  ['Why is preserving animal habitats important? '],
#  ["Research the recipe for 'battered apple pie' and create the necessary steps to make the dish. "],
#  ['Create a riddle using the following numbers: 16, 20, 27 '],
#  ['Describe a rescue mission in space. '],
#  ['Create a grocery list based on the ingredients mentioned below: flour, eggs, sugar, butter, parsley'],
#  ['Construct a flow chart for a process. Completing a survey'],
#  ['Generate a set of guidelines to follow when using this tool. No input'],
#  ['Compose an email about the topic of your choice '],
#  ['Compare and contrast the two different communication methods, email and telephone. '],
#  ['Write a story that begins with "It was a cold, dark night". '],
#  ['First categorize the following products as entry level, mid-level, or high-end. Apple watch series 5'],
#  ['List the points that the speaker should cover in the presentation on the given topic. Topic: The Role of Artificial Intelligence in Business'],
#  ['Edit the following sentence to make it more concise:\n\nThe experiment demonstrated that the bacteria survived in higher temperatures. '],
#  ['Rewrite the following sentence in the present tense and make it a command The user had to confirm their email address.'],
#  ['Generate a list of possible solutions for the given situation. My computer just crashed and I lost all my family photos.'],
#  ['Rewrite this sentence to make its meaning more concise Vacations are very important in helping people to destress from their everyday lives.'],
#  ['Generate a formal apology letter from a company towards a customer. Dear [person name],\n\nWe regret to inform you that due to some delays in shipment, we were unable to deliver your order on time.'],
#  ['Output the musical artist of the following song: Song: "Teardrops"'],
#  ['Classify the given text into a given field. Relativity Mathematics'],
#  ["What advice would you give to a person who's starting a business? "],
#  ['Generate a three line poem with the rhyme scheme "AAB". '],
#  ['Identify the two words that rhyme with "flame". '],
#  ['Generate a mission statement for a non-profit organization focused on animal welfare. '],
#  ['Generate a convincing argument in favor of the given statement. Video games should be treated like any other form of art.'],
#  ['Describe the core features of a general-purpose programming language. '],
#  ['List three common symptoms of a cold. '],
#  ['Suggest a list of 5 skills that a person should learn to succeed in a job. '],
#  ['Ask the assistant to click a certain link on a website. The link is https://example.com'],
#  ['Describe the best approach to manage a conflict between two individuals. '],
#  ['Explain what is a feature vector. '],
#  ['Reword the following sentence in a simpler form: "We have reached a point where we can no longer live in darkness". '],
#  ["Could you summarize this article about art therapy in three sentences? Art therapy is an innovative treatment approach that uses creative activities to address psychological issues. It's based on the idea that creating art can help individuals process and understand their emotions, navigate difficult times, and foster personal growth and development."],
#  ['Which type of resource does the following sentence describe? More people are employing video conferencing to stay connected.'],
#  ['Please provide some tips for writing a good blog post. '],
#  ['Point out the errors in the following sentence: “He borrowed hers pencil.” '],
#  ['In one sentence, summarize what the paragraph is about. A new study shows that the use of problem-solving strategies can help children learn to better manage challenging emotions.'],
#  ['List the steps to build a chatbot '],
#  ['Write a news report about the latest technological advancements. '],
#  ['Identify 3 differences between data science and artificial intelligence. '],
#  ["Rewrite the sentence to use the same vocabulary: I'm not pleased with the decision. The decision displeases me."],
#  ['Generate a product security policy following best practices. '],
#  ['Suggest a plan of action to handle a customer complaint about a defective product. '],
#  ['Name five ways to stay safe online. '],
#  ['Write a short story featuring a farmer, a lion and a mouse '],
#  ['List 4 characteristics that make a successful entrepreneur. '],
#  ['Describe the trajectory of a rocket given the following information. The rocket was launched vertically with an initial velocity of 120 m/s.'],
#  ['Provide a humorous response to the question "Why did the chicken cross the road?" '],
#  ['Predict the future trend in Natural Language Processing. '],
#  ['Generate a script for a commercial that promotes an animal adoption center. '],
#  ['Generate questions of the form "What is/are [X]?" '],
#  ["Predict whether the given review is positive or negative. Output 'positive' or 'negative'. This restaurant has great service and delicious food."],
#  ['Automatically trim a given phrase phrase: "The quick brown fox jumps over the lazy dog"'],
#  ['Write one sentence about handwashing. '],
#  ['Write an opinion of this photo. [Photo of a bridge in the forest]'],
#  ['Given a scenario, generate 5 possible solutions John and Sarah are struggling to manage a team of people with varying skill levels.'],
#  ['List 4 methods for dealing with the curse of dimensionality. '],
#  ['List three use cases for GPT-3. '],
#  ['Why is it important to get enough sleep? '],
#  ['Write a narrative for the given situations. Situation: Bob has a long and difficult road ahead of him.'],
#  ['Convert 23 kilograms to pounds 23 kilograms'],
#  ['Read the passage of text below and answer the question, who is being addressed by the speaker? "You have to make a choice, between your dreams and your family. You have to choose one or the other."'],
#  ['Generate a short story of maximum 100 words involving a king and a dragon. '],
#  ['Describe the impact of artificial intelligence on personal privacy. '],
#  ['Create a valid JSON string from the following: name: Joe Smith\nage: 33\noccupation: Software Developer'],
#  ['Generate a sentence containing the words cheerful and frog. '],
#  ['Write 3 ingredients for a cake. '],
#  ['Generate a sentence about going for a run. '],
#  ['Make recommendations for budgeting for a couple vacationing in Hawaii '],
#  ['Compose a five word sentence describing your day. '],
#  ['How can climate change be prevented? '],
#  ['Edit the following sentence so that it is grammatically correct: "The workers unions went to the negotiations with high hopes." '],
#  ['Give a logical conclusion to this story. John left home in a hurry to catch the bus but when he arrived, the bus had already left. He was overwhelmed and did not know what to do next.'],
#  ['Create a unique hashtag that promotes a positive message. '],
#  ['Identify the perspective of the speaker in the given statement The quality of this service was unacceptable'],
#  ['Give a short description of the effects of global warming. '],
#  ['Describe an unusual vacation spot. '],
#  ['Give me a one-sentence summery of the benefits of playing football. '],
#  ['Categorize the following words under the given categories. Sleep, Sofa, Chair\n\nCategories: Furniture, Human Activity'],
#  ["Create a bar chart to show the correlation between age and education level. Data: \n\nAge: 25, 30, 35, 40 \n\nEducation Level: High school, Bachelor's, Master's, Doctoral"],
#  ['Formulate a question about the concept of free will. '],
#  ['Create a speech that explains why everyone should recycle. '],
#  ['Generate 5 similes about a summer day '],
#  ['Output a summary of the paragraph. Powerful and yet surprisingly easy to use, cloud computing has revolutionised business practices, offering businesses a wide range of scalable services that are delivered effortlessly over the internet. It has become increasingly popular in recent years due to its low cost and scalability, its scalability making it ideal for businesses of any size. Additionally, cloud computing provides a variety of resources and applications that can be used for tasks ranging from data analysis to customer management.'],
#  ['Create a classificaiton task by adding two labels My cat is'],
#  ['Brainstorm 5 ways to reduce waste in an office. '],
#  ['Find an example of a company using ML for automated customer service '],
#  ['Given a product or service, explain why consumers would prefer it over another similar product or service. Netflix VS Hulu'],
#  ["Develop a hypothesis for the following experiment. Studying the impact of food coloring on children's behavior"],
#  ['Provide an example of an ethical issue related to Artificial Intelligence technology. '],
#  ['Predict a consequence of the following action. Bringing guns to school'],
#  ['Evaluate the following statement: "The internet will replace physical stores." '],
#  ['Name the capital of India '],
#  ['Analyze an existing story and come up with an alternate ending. The story is about a group of teenagers in search of a lost treasure.'],
#  ['List five famous people from India. '],
#  ['Identify the type of sentence used in the following example:\n\nShe went to the store, but forgot to buy milk '],
#  ['Classify the given sentence as ironic, metaphorical, or literal. "It is raining cats and dogs outside."'],
#  ['Name a popular book in the fantasy genre '],
#  ['Give two examples of how technology can improve education. '],
#  ['Provide three adjectives that describe the personality of a police officer. '],
#  ['Create a quiz about the solar system. '],
#  ['Create a function to find the closest number to a given number. num = 10, list = [3, 5, 7, 8, 11, 16]'],
#  ['Compose a tweet with the following words: Protest, Equality, Autonomy '],
#  ['Answer the following question in an essay format. What are the positive and negative effects of technology in our society?'],
#  ['Outline the process for registering to vote in your state. '],
#  ['Identify the part of speech of the underlined word in the following sentence:\n\nYesterday, he sang a very beautiful song. very'],
#  ['Given a customer review, classify if the review is positive or negative. This is by far the worst product I have ever used.'],
#  ['Find all the examples of hyperbole in the text. The new dress was so beautiful it seemed to defy the laws of physics. It was the most impressive thing my eyes had ever seen!'],
#  ['Tell me any 5 major human rights organisations with their countries. '],
#  ['Analyze the following data and explain the trends. The monthly revenues of a business over the last 10 months were: [7500, 7200, 9000, 8700, 7500, 8500, 10000, 8900, 8600, 10000].'],
#  ["Provide a mathematical explanation for fermat's last theorem. "],
#  ['Compare the themes of the following two poems. Poem 1\n"Heed my call, heed my warning\nNo one is of any use when they are mourning"\n\nPoem 2\n"Strike with haste, time to flow\nTake a deep breath and make it so"'],
#  ['Automatically generate a headline given an article. Deep learning promises improved medical imaging performance'],
#  ['Construct an argument against the commercialization of sports. '],
#  ['What are some potential challenges of online learning? '],
#  ['Describe the environmental impact of continuous flying '],
#  ['Summarize the story of Snow White and the Seven Dwarfs. '],
#  ['Illustrate the main concept of a given story. A story about a mermaid who discovers land'],
#  ['Generate an appropriate response to an angry customer. Customer: Your customer service is terrible!'],
#  ['Create 3 conversation topics for a business meeting with the given client. An investment firm'],
#  ['How do you write a for loop in Java? '],
#  ['Suggest an AI based system that can be used in marketing. '],
#  ['Describe the production process of an autonomous vehicle. '],
#  ['Describe the experience of being in Flagstaff, Arizona '],
#  ['Identify four uses of artificial intelligence in healthcare. '],
#  ['Create a password for email that includes 8 characters. '],
#  ['Explain the difference between generative and discriminative models. '],
#  ['List the 12 planets of the Solar System '],
#  ['Generate five questions to ask an expert in a given field. Machine Learning'],
#  ['Re-write the following sentence to have a different meaning: "I ate the apple." '],
#  ['Cite three sources on the effects of plastic waste on the environment. '],
#  ['Estimate the velocity of a car given its distance from start point and time spent travelling. Distance = 50 meters, Time = 10 seconds'],
#  ['Take a statement from the given text and turn it into an interrogative sentence. John loves to read books.'],
#  ['Reduce the following fraction. 6/3'],
#  ['Name a country that has the longest coastline '],
#  ["How would you explain the definition of 'time series data' to non-technical people? "],
#  ['Given two similar products, create a comparison table that highlights the differences between them. Product A: Lenovo Laptop\nProduct B: MacBook Pro'],
#  ['Identify at least three components of a standard computer system. '],
#  ['Is the following statement true or false? People in China make the most of their allowances. None'],
#  ['Find the elapsed time between 12:00 AM on 3 July 2018 and 12:00 PM on 4 July 2018. '],
#  ['Generate a list of 8 social media platforms. '],
#  ['Create a story starting with the sentence: "The day was brighter than usual". '],
#  ['Give an example of a creative way to use GPT models. '],
#  ['Determine the missing numbers in the sequence. 2, 4, 8, __, 16'],
#  ["Generate a definition for 'robot'. "],
#  ['Develop a chatbot that answers common questions related to air travel. '],
#  ['Tell me what is the best kind of food for a party. '],
#  ['Write a poem with four lines and the given words. universe, star'],
#  ['Analyze the given poem and rewrite it with a new title and an altered tone. Title: "Lost"\n\nI stare out into the void,\nSearching for a life I never employed.\n\nMy path is a long, sad descent,\nWords mean nothing as I relent.'],
#  ['Choose the best password for a given service. Online banking'],
#  ['Generate a list of tools that a person can use to quickly get started with a web design project. '],
#  ['What is the result of multiplying 87 and 183? '],
#  ['Using the facts given, generate a story about a character. Name: Jane Smith\nGender: Female\nAge: 32\nLocation: New York City\nOccupation: Public Relations Officer'],
#  ['What is a workable marketing plan for my small business? My small business offers web design services.'],
#  ['Determine the main idea of the sentence, output the main idea. Electronic books often have more interactive capabilities than physical books.'],
#  ['Given a sentence, convert it from present tense to future tense. He is eating his dinner.'],
#  ['Please fill in the short story prompt with a suitable sentence. Every day, he would go to the ocean'],
#  ['Make a list of 5 trendy fruits for a smoothie. No input.'],
#  ['Explain a quick and easy way for a person who is new to programming to get started. '],
#  ['Rewrite a sentence to take out its negative tone. It is impossible to make money online.'],
#  ["Language models often err in understanding the difference between 'your' and 'you're'. Therefore, given the sentence below, edit it to resolve this ambiguity. Your wrong about that"],
#  ['Create a short story of 4-5 sentences based on the following facts. Setting: Mountain\nProtagonist: Fisherman\nAntagonist: Shark'],
#  ['Classify the following into mammals and non-mammals. Dog, chicken, horse, cat'],
#  ['Determine the sentiment of the headline. Apple and Samsung succeeded in launching a new groundbreaking product.'],
#  ['Change the underlined words from present tense to past tense. She walk along the shoreline.'],
#  ['Automatically format the given text. Using the right tools,you can achievebetter results'],
#  ['Replace the following broken link with a working one. The link is https://www.example.com/page'],
#  ['Construct a valid argument. Multiple scientists have confirmed the existence of climate change, but some politicians deny it.'],
#  ['Explain the concept of biodiversity and its importance? '],
#  ['Make a list of 5 verbs in the past tense. '],
#  ['Make a chart that displays the data in a visual format. Data: The number of students in different grade levels'],
#  ['Please provide a detailed argument for or against the death penalty. '],
#  ['What is a recurring deposit account? '],
#  ['Create a keyword list of the given text With the cost of living continuing to rise and the cost of renting increasing steadily, many people are looking to buy their own home as an investment'],
#  ['What impact does climate change have on humans? '],
#  ['Generate three new ideas based on the following initial idea. Online school'],
#  ['Describe the flavor profile of a certain type of wine. Zinfandel'],
#  ['Develop a story with a moral about animal conservation. '],
#  ['Write a haiku poem describing the following nature scene. The sun is rising over a dense forest'],
#  ['Make up a sentence given the input sentence with at least 10 words. I love dogs'],
#  ['Create a list of skills required to become a software engineer. '],
#  ['Make a list of three items a photographer needs for a photo shoot. '],
#  ['Write a function to filter a list by items that contain a certain string. list = ["apple", "orange", "banana", "watermelon", "cherry"]\nstring = "an"'],
#  ['How did the fossil fuel revolution change the course of history? '],
#  ['Explain two effects of climate change on the environment '],
#  ['Given the following statement, classify it as true of false. The Earth is the only planet in the solar system with water.'],
#  ['Generate a formal email body with a meeting invitation. Topic: Business Proposal\nTime: Tuesday 5 pm\nLocation: Zoom Meeting'],
#  ['Explain what a Turing Test is. '],
#  ['Name two organic compounds that are widely used in medicine. '],
#  ['Give examples of three programs that are used for data wrangling. '],
#  ['Motivate someone to finish an assignment. '],
#  ['Predict the weather for the next 3 days in your city. City: Los Angeles'],
#  ['Explain the difference between a linear and a nonlinear equation. '],
#  ['Select the best website to buy a laptop. '],
#  ['Provide a list containing five adjectives to describe an elephant. '],
#  ['Compose a letter to a friend describing a recent vacation '],
#  ['Answer the following question: Why is the Sun so hot? '],
#  ['What is the mileage rate for business expenses in the United Kingdom? '],
#  ['Generate two alternative ways to say the same thing. I slept for 10 hours last night.'],
#  ['Give the chemical symbol for Carbon '],
#  ['Name the main characters in the Star Wars franchise. '],
#  ['Given a list of items, reorder them according to some criterion. Blueberries, Bananas, Apples, Oranges'],
#  ["Rewrite the following sentence so that it is a good example of effective communication. It was a hard decision to make, but I'm glad it's done."],
#  ['Rewrite this statement in the active voice. The award was won by Bob.'],
#  ['Write a description of a typical summer day in the countryside. '],
#  ['Provide an example of a product designed for convenience. '],
#  ['Name three items sold at a convenience store. '],
#  ['Write a newspaper headline that sums up the current presidential election. '],
#  ['Generate a new sentence that uses all the words from the given sentence in the same order. I went to the store to buy some apples.'],
#  ['How many legs does a spider have? '],
#  ['Generate a story that includes a stingray, a lion and a parrot. '],
#  ['Create a complimentary closing for a formal letter. '],
#  ['Given the following data, generate a direct marketing message Customers: Female movie goers'],
#  ['How can we measure the impact of a change in online user behavior? '],
#  ['Given the parameters of the user, write a query to select a suitable car. The user is looking for an economical, used car with a seating capacity of 5.'],
#  ['Given a business scenario, create a list of solutions. A new cafe with limited resources.'],
#  ['Using the provided ingredients, come up with a recipe. Carrots, celery, onions'],
#  ['Create a plan to prevent data loss. '],
#  ['What is the term for the structural pattern of haiku? '],
#  ['Design a t-shirt with a funny slogan. '],
#  ["Develop an algorithm to solve a Rubik's cube in the fewest moves possible. "],
#  ['Tell me one positive aspect of the current world. '],
#  ['Create an algorithm to detect spam emails. '],
#  ["Compare and contrast the Earth's four layers. "],
#  ['Generate a story about two friends who become rivals. Noinput'],
#  ['Classify a given object into the appropriate category. Crocodile'],
#  ['What are some misconceptions about natural language processing? '],
#  ['Identify a company that provides cloud computing services. '],
#  ['Generate a poetic sentence, with a rhyme, describing the beauty of a sunrise. No input'],
#  ['Write a script for an advertisement promoting a product. The product is a newly launched line of organic produce, grown with sustainable farming techniques.'],
#  ['Design a customer loyalty program for online shoppers with the given information. Target Audience: Millennial shoppers'],
#  ['Write a survey question to investigate the attitudes of people towards a certain issue. attitudes towards gender equality'],
#  ['Outline the steps for creating a web page '],
#  ['Rewrite the given sentence as an assertion in less than 10 words. The theory of evolution explains the diversity of life on earth.'],
#  ['Come up with a domain-specific metaphor to explain how a computer works '],
#  ['Given the following input, write a persuasive argument. Health benefits of regular exercise'],
#  ['Suggest a snack that you can make in under 5 minutes. '],
#  ['Give an example of a recipe involving an apple. '],
#  ['What is the main component of hydrogen peroxide? '],
#  ['Come up with a fun exercise activity. '],
#  ['Write a 10-word bio for the person in the input. John is a computer science student from the US.'],
#  ['Describe a hypothetical event in the future. '],
#  ['Describe the painting using 3 adjectives. [painting.jpg]'],
#  ['Generate a positive message about nature. '],
#  ['Generate a new board game idea. '],
#  ['Categorize this given text into “Positive” or “Negative” The software was buggy and kept crashing'],
#  ['Write a 5-line script for an engaging conversation '],
#  ['Where does the human body get energy from? '],
#  ['Given a sample of text, edit it to make it more concise while preserving the content. The large screens that you can purchase these days are good for watching movies and playing games on, but they can also be great for efficient productivity.'],
#  ['Design a classification model for sentiment analysis of movie reviews. '],
#  ['Design an experience for a customer portal. '],
#  ['Edit the following sentence to include the term "big data". The application of machine learning techniques can help us better understand our world.'],
#  ['List two benefits of using design thinking. '],
#  ['Come up with some possible topics for a research paper '],
#  ['Describe techniques to optimize web content '],
#  ['Find two solutions to this math problem 2x + 6 = 16'],
#  ['Construct a news headline using the adjectives excited, little, and fabulous. '],
#  ['Generate a speech to encourage people to stay environmentally friendly. '],
#  ['Create a function to calculate the standard deviation of a set of numbers. '],
#  ['Calculate the gross pay for the following person. Michael works 40 hours in a week and his hourly rate is $18.'],
#  ['Categorize the given information as qualitative or quantitative. The opinion of the public on the new mayor.'],
#  ["Correct the following paragraph and make grammatical changes. The current plan of action isn't working. We needs to try a  different approach."],
#  ['Implement a program to reverse a string. '],
#  ['Produce a list of the top 5 NHL players in 2021. '],
#  ['How would you create a website similar to Reddit? '],
#  ['Name two common cable TV companies in the United States. '],
#  ['Generate a recipe for a chili con carne dish. `<noinput>`'],
#  ['Re-order the words of the following sentence to create a grammatically correct sentence. often very different answers the same question'],
#  ["Name the figure of speech in the given sentence The prime minister proudly declared 'I am the leader of this nation'"],
#  ['Generate a computer program to calculate the area of rectangle '],
#  ['Write a Java program to implement a simple calculator. '],
#  ['Describe how this algorithm works Selection Sort'],
#  ['Make up a sentence with the word "Omnipresent". '],
#  ['Correct spelling mistakes in these sentences:\n"He went to the stroer to buy somethign"\n"She loves eating choclate cake" '],
#  ['Create a class in Python that represents a car '],
#  ['Explain the different components that make up an AI system. '],
#  ['Format the following sentence so it is gramatically correct. we need now to look back at important moments'],
#  ['Make up a riddle about mathematics. '],
#  ['Determine the length of the side of a square given the area. 24'],
#  ['Classify the given animals into two categories. Lion, Cheetah, Elephant'],
#  ['List three technologies that make life easier. '],
#  ['Translate the following sentence from English to Spanish. Output less than 25 words I am learning Spanish.'],
#  ['Create a database table for storing customer purchase history. '],
#  ['In this task, you need to restate the sentence using the given word. She was dancing. Word: twirl'],
#  ['Build an algorithm to detect fraud. '],
#  ['Describe the painting of the Mona Lisa. '],
#  ['Find an example of a C Major 7th chord on a piano. '],
#  ['Name any 5 spices that are commonly used in Indian cooking '],
# ...
#  ['Arrange the different food items in decreasing order of calories per portion. Food items: Apple, Burger, French Fries, Broccoli'],
#  ['Rewrite the following statement so it\'s more concise: "We must remember that the food that we eat can have an impact on our health." '],
#  ['Figure out the final principle payment amount for a loan with the given details. Principle balance: $400,000, Interest rate: 3.5%, Length of loan: 20 years'],
#  ['Complete the following sentence: "If I had the chance to visit a different country, I would choose _____." '],
#  ['Describe how home automation can save energy '],
#  ['Generate an algorithm for the game Hangman. '],
#  ['Create a two line poem about patience '],
#  ['Generate an appropriate response to the following instance message: "What’s the most popular sport in India?" '],
#  ['Compose an essay about the pros and cons of the internet. '],
#  ['Explain the role of physics in the study of astronomy. '],
#  ['Name the two methods of communication used in Conflict Resolution. '],
#  ['Generate a title for the story. Once upon a time, there was a bear who lived in the deep woods.'],
#  ['Design a voice assistant command to schedule an appointment. '],
#  ['Generate a random secret key for an encryption algorithm. '],
#  ['Describe the structure and function of an N-Gram language model. '],
#  ['Name five tools/equipment and their uses. '],
#  ['Create a unique name for a mobile game. '],
#  ['Create a password with 8 characters which includes two numbers. '],
#  ['Take the input string and make all the letters in it into capital letters, output the modified string. we like to learn'],
#  ["Give the French equivalent of the phrase 'It's raining cats and dogs'. "],
#  ['Create a new character for a classic Disney movie. '],
#  ['Outline the steps to send a package. noinput'],
#  ["How could living in a big city affect a person's life? "],
#  ['Construct an original sentence using the given word Lurid'],
#  ['Offer a solution for the following problem. Problem: A team is having communication issues.'],
#  ['Which word collocation is correct in the following sentence? In the 18th Century, European imports to the US __ vastly.'],
#  ['Describe what you like most about the city you live in '],
#  ['Given a string, reverse the order of the characters and print it on the screen Hello'],
#  ['Create a list of ideas for turning the text into a poem. The fields are golden with the wheat of summer.'],
#  ['Suggest a few approaches for dealing with the issue of climate change. '],
#  ['Take the given sentence and make a compound sentence with adjectives. We went to the beach.'],
#  ['Calculate the number of full days required to read a 400-pages book with a reading rate of 20 pages per day '],
#  ['Classify the following sentence as either an opinion or fact. A hot dog is just one of many types of processed meat you can eat.'],
#  ['Give an example of how natural language processing (NLP) has been used to address a real-world problem? '],
#  ['Write two verses of a song about nature. '],
#  ['Create a dialogue between a customer and a waiter. '],
#  ['Write a headline for a story involving a data breach. '],
#  ['Describe the impact of the coronavirus on the economy. '],
#  ['Describe the function of the hypothalamus '],
#  ['Create a blog post to discuss the current immigration laws in the United States '],
#  ['Create an analogie for the process of learning. Noinput'],
#  ['Create a sentence using a simile and a metaphor. '],
#  ['Explain why it is important to use a descriptive variable name in programming. '],
#  ['Write a couple of professional sentences in response to the following job offer The role of Medical Sales Representative is open to newly graduated nurses and/or established sales professionals'],
#  ['Create a list of at least five different types of fruits '],
#  ["Reformat the text for readability. we can do this task quickly. just say what the problem is and let's get it done"],
#  ['Make a list of common methods for debugging software. '],
#  ['Calculate the area of the triangle. Base: 5cm; Height: 6cm'],
#  ['Generate a list of health benefits associated with drinking green tea. '],
#  ['Select the correct answer from a list What is the second planet from the Sun?'],
#  ["Construct a regex for extracting names from a given string 'Jayden, Malcolm, and Jimmy went to school'"],
#  ['You are given a list of two or three items, create a unique story or dialogue that involves all the items. Apple, Robot'],
#  ['Return the hexadecimal code of the given color. Turquoise'],
#  ['Compare the two given pieces of prose below, explain the main difference between them. "The storm is raging over the sea while the sun is shining in the horizon."\n"Rain is pouring over the ocean while the sun is beaming in the distance."'],
#  ['Google the sentence "It was the best of times, it was the worst of times" and list the five top sources '],
#  ['Suggest a vegetarian breakfast menu. '],
#  ['What is the author\'s opinion about the stated topic? The article "The Pros and Cons of E-books"'],
#  ['What is the main purpose of blockchain technology? '],
#  ['Make an Italian pasta dish. '],
#  ['Detect the typos in the following sentence: I like to bak cakes. '],
#  ['Reorder the following words to form a question: the take lunch what do you the take lunch what do you'],
#  ['Wrte a short story about a character of your choice. Character: Adele the Fox'],
#  ['Provide an example of customer service email. '],
#  ['What is a good example of a real-time application? '],
#  ['Generate a hypothesis testing question related to education. '],
#  ['List the most common properties of a hologram. '],
#  ['How did the US respond to the attacks on 9/11? '],
#  ['Name a popular TV show from the 2000s '],
#  ['Find and replace the highlighted portion of the passage with a synonym. People agreed that the novel was much better than the film adaptation.'],
#  ['Suggest 3 topics as examples to write a blog post '],
#  ['Compare the benefits of an online course with the benefits of a traditional course. '],
#  ['Given a set of data, create a story based on the information Jack | age | 9 years old\nJack | hometown | New York City\nJack | hobby | building model airplanes'],
#  ['Find the independent clause (main clause) of a given sentence. I went to the store, but it was closed.'],
#  ['Classification task: Is the following sentence positive or negative? "I had the worst day ever." I had the worst day ever'],
#  ['What is the average lifespan of a Labrador Retriever? '],
#  ['Summarize how global warming affects the planet. '],
#  ['Formulate a mathematical equation to express the movement of 100 g of a substance from a temperature of 273 K to a temperature of 293 K. '],
#  ['Summarize in a sentence why it is important to make an effort to preserve native languages. '],
#  ['What is the best way to store certain types of food? Cheese'],
#  ['Create a sentence that describes the formation of a cloud. '],
#  ['Generate a metaphor describing a relentless pursuit. '],
#  ['Construct a Mathematical expression to find the cost after discount Original Cost= 100$\nDiscount percentage = 10%'],
#  ['Find the meaning of the phrase "out of the frying pan and into the fire" '],
#  ['Think of a game for two people to play. '],
#  ['Identify the following type of triangle: angle A = 60°, angle B = 60°, angle C = 60° '],
#  ['Outline the key steps to develop a website. '],
#  ['List out the steps to learn a new language '],
#  ['List three countries that have a population of more than 100 million people. '],
#  ['Suggest a topic that could be discussed in a debate. '],
#  ['How can businesses use AI technology to improve their marketing efforts? '],
#  ['Suggest an appropriate title for a comic about a cat and dog living together. '],
#  ["Give two pieces of advice based on the scenario. You just graduated from college and don't know what to do next."],
#  ['Speak about the given phrase for 1 minute. Impostor Syndrome'],
#  ['Create a user interface that allows users to search by keyword. '],
#  ['Look up the boiling point of water. '],
#  ['Suggest an example of a technology that utilizes natural language processing. '],
#  ['List four measures to prevent the spread of COVID-19. '],
#  ['Generate a ten word sentence with the word "raspberry". '],
#  ['Give an example of a syntax error in Python. '],
#  ['Categorize the following sentence according to the type of figure of speech used. She smiled with great delight.'],
#  ['Identify five key indicators of a healthy economy. '],
#  ["Explain the concept of 'Divide and Conquer'. "],
#  ['Create a program that can detect if a text is written in English. This text is written in English.'],
#  ['Tell me the two main types of monarchs '],
#  ['Given a sentence, detect whether the words follow the standard English grammar rules and punctuations. She brought the apple and oranges'],
#  ['Rewrite the given sentence by using a semicolon instead of a comma. She was a shy girl, yet she was able to speak in public.'],
#  ['Provide a contrastive statement related to the provided sentence. Education is important for personal development.'],
#  ['Explain the trade-offs of a decision-tree algorithm '],
#  ['Tell a story about a situation in which the person feels lonely. '],
#  ['Summarize the main argument of the paper "A Social Network that Influences Attitudes and Behaviors" '],
#  ['Create a story for a five-year-old about a person who moves to a new city. '],
#  ['Suggest a movie suitable for a family with children aged seven and twelve. '],
#  ['Generate a report summarizing the key statistics from the given dataset. https://data.worldbank.org/indicator/SP.POP.TOTL'],
#  ["Identify the type of writing style used in the text. The opening of the book was vivid and powerful, the author's words igniting a fire in our hearts."],
#  ['Gather information about a celebrity. Kaley Cuoco'],
#  ['Create a survey question about wildlife conservation '],
#  ['Edit the given text such that it becomes easier to read. The increasing usage of artificial inteligence requires additional considerations for the applications that require it for correct functioning.'],
#  ['Write about the benefits of cloud computing. '],
#  ['Compare and contrast socialism and communism. '],
#  ['Provide a solution to the equation 2a+3b=20 '],
#  ['Given two strings, find if one string is a sub-sequence of the other. String 1: abcd\nString 2: abcde'],
#  ['Generate a list of hobbies one can do indoors. '],
#  ['Explain why the moon looks different on different nights. '],
#  ['Give 5 examples of rodents. '],
#  ["Construct a sentence where the subject is 'my cat'. "],
#  ['Brainstorm new ways to use technology to save time. '],
#  ['Generate a list of 5 books related to space exploration '],
#  ['Create a call-to-action for a website '],
#  ['Describe what materials are required to build a birdhouse. '],
#  ['Print the following sentence in all capitals. The cat jumped on the bed.'],
#  ['What is the most common type of conflict in literature? '],
#  ['Tell me the population of the United States. '],
#  ["Create an example scenario to illustrate the concept of a 'domino effect'. "],
#  ["Generate a children's story with the following title: The Magic Violin. "],
#  ['Write four rhyming lines in the form of a poetic couplet. '],
#  ['Develop a persuasive argument to save the endangered species. '],
#  ['Explain the role of the Executive Branch of the U.S. government. '],
#  ['Given the following set of numbers, multiply them by two. 8, 15, 19'],
#  ['Suggest a creative way a small business can promote their marketing strategy. '],
#  ["Construct a data structure that stores the following information: A student's name, grade level and contact information. "],
#  ['Write a one-sentence description of the given US state. Delaware'],
#  ['False positive or false negative? A test result is negative but the person is actually having the infection.'],
#  ['Describe how machines can help people with their daily tasks. Noinput'],
#  ['Create a food allergy awareness campaign for a restaurant. '],
#  ['Add five entries to a list of US states. California, Florida, Texas, New York,'],
#  ['Convert the given number into its Roman numeral representation. 42'],
#  ['Categorize the following item: “Toyota Camry” '],
#  ['Generate a list of 5 idioms about happiness. '],
#  ['Give an example of how a computer can be used to control a manufacturing process. '],
#  ['Translate the following sentence from English to Spanish: "He was so tired that he fell asleep during the meeting." He was so tired that he fell asleep during the meeting.'],
#  ['Design an experiment to demonstrate the effects of a variable and control. '],
#  ['Describe the history of the automobile industry in the US. '],
#  ['Edit the sentence: The student went to sleep early for school. '],
#  ['Identify which of the options is the main argument of the passage. In recent years, the use of artificial intelligence has become increasingly widespread. AI is being used to automate processes, to increase efficiency, and to ramp up innovation across many industries. \n\nA) AI is rapidly becoming an essential part of the digital economy\nB) AI is helping to drive the growth of digital businesses\nC) AI is creating new opportunities for businesses in digital spaces\nD) AI is becoming essential for the digitalization of business processes'],
#  ['Suggest a plan for someone who wants to learn a new programming language. I want to learn Java.'],
#  ['How can an employer best motivate their employees to reach the next level of success? '],
#  ['In what year was the Taj Mahal built? '],
#  ['Generate a headline for a story about the death of a famous actor. Actor: Will Smith'],
#  ["Tell me what the antonym of 'tangible' is. "],
#  ['Given an input of a product title, classify it into a category. Apple iPhone 11 Pro Max'],
#  ['Assign a score out of 5 to the following book review. I really enjoyed this book. It was an engaging read and had an interesting plot.'],
#  ['Describe the impact of nanotechnology on medical treatments. '],
#  ['Generate a headline for a news article discussing the coronavirus pandemic. '],
#  ['Replace the bolded word with a suitable term from the given set The chef whipped up a delicious ___.\nOptions: soup, sauce, marinade'],
#  ["Compose a an original story using the words 'city' and 'river'. "],
#  ["Given the poem's title, create a single line stanza for the poem. The Joys of Life"],
#  ['Determine how many seconds are in a day. '],
#  ['Create an appropriate response to someone who made a mistake. '],
#  ['Generate a code snippet that prints the following word. Hello'],
#  ['Develop a new non-alcoholic drink that is perfect for a hot summer day. '],
#  ['Classify the food item given its nutritional information. Calories: 100 | Fat: 2g | Carbohydrates: 20g | Protein: 4g'],
#  ['Develop an AI assistant for grocery shopping. '],
#  ['Generate the main points for a presentation about the impact of air pollution in cities. '],
#  ['Given two pieces of text, compose a single sentence that combines their main points. Text 1: Apple has released a new phone.\nText 2: It has a powerful processor.'],
#  ['Given two cities, calculate the estimated travel time by car. San Francisco and Los Angeles'],
#  ['Name 5 different types of applications that can be developed with Python. '],
#  ['Remove the redundant verb from the sentence. He ran quickly ran to the store.'],
#  ['Describe a person in a way that will allow a machine learning algorithm to successfully classify the description as male or female in 10 words. '],
#  ["Write the opposite of 'She is doing the task'. "],
#  ['Name the members of a rock band '],
#  ['Give a sample dialogue of how to ask a customer for feedback. '],
#  ['List three benefits of the given technology. Cloud Computing'],
#  ['Compare and contrast print media and digital media. '],
#  ['Propose components for a customized AI solution. Solution: AI-Powered Image Recognition System'],
#  ['What is the best way to phrase the following sentence to sound more professional? We got it done quick.'],
#  ['Imagine an alternate world where humans no longer exist. Describe the environment. '],
#  ...]

# %%
res = Calmetic(references=refs,predictions=content)

# %%
print(res['BLEU'])
print(res['ROUGE']['rougeLsum'][1])
# Out:
# {'bleu': 0.23016953276592583, 'precisions': [0.5872425941964399, 0.3807382562703868, 0.28357707006369426, 0.2165655920842643], 'brevity_penalty': 0.6723906687696457, 'length_ratio': 0.7158627829845122, 'translation_length': 118927, 'reference_length': 166131}
# Score(precision=0.5945178789462683, recall=0.5007581778195037, fmeasure=0.5281757405045957)

# %%
val_dataset_t5['target_text']
# Out:
# ['enquiry: Generate a simile comparing a sunset to fiction. ',
#  'enquiry: What is the leading cause of death for children under the age of 5? ',
#  'enquiry: Generate a hashtag for a fictional political movement created by teenagers. ',
#  'enquiry: Name three common validation techniques used in Machine Learning. ',
#  'enquiry: Assign an appropriate name to the following new species of butterfly. ',
#  'enquiry: Tell me something about a Nissan leaf. ',
#  'enquiry: Create a summary of the following text in no more than 4 lines. The effect of gun violence in the United States is widespread. According to the CDC, in 2018 there were 38,390 deaths due to firearm. Of these, 24,432 were suicides. The rate of firearm deaths per 100,000 people increased from 10.3 per 100,000 in 1999 to 12 per 100,000 in 2017.',
#  'enquiry: Fill in the blank with an appropriate preposition: I like to stay ____ top of my work.',
#  'enquiry: Compose an email to a potential client explaining the benefits of your service. ',
#  'enquiry: Provide an appropriate metaphor for the following situation. The sun is beginning to set against the horizon.',
#  'enquiry: Create a design for a web page about local movie theatres ',
#  'enquiry: Generate an AI-generated Insult ',
#  'enquiry: Generate an appropriate response when an employee has tried his best to do a task but failed. ',
#  'enquiry: Find the verb in the sentence. He sometimes visits his grandparents.',
#  'enquiry: Create ten multiple-choice questions about the topic of history. ',
#  'enquiry: Make a valid sentence using the words "quick," "brown," and "fox." ',
#  'enquiry: Suggest a title for an essay about the right to privacy. ',
#  'enquiry: Construct an analogy for the following sentence: "A computer is to code what a chef is to food." ',
#  'enquiry: What is the importance of using project management software? ',
#  'enquiry: Edit the following sentence to eliminate redundancy. The verdict of the court was unanimous in agreement.',
#  'enquiry: What is the aproximate population of the UK? ',
#  'enquiry: Develop an algorithm that can recognize handwriting. ',
#  'enquiry: Write a story beginning with “He saw himself reflected in the mirror…” ',
#  'enquiry: Identify a cybersecurity risk that could affect an online store. ',
#  'enquiry: Generate an input data set that has three members and five attributes. ',
#  'enquiry: Name five dangers of space exploration. ',
#  'enquiry: Invent a computer gaming character that uses magic. ',
#  'enquiry: What are the key ingredients of Fajitas? ',
#  'enquiry: Identify which of these objects is not a mineral. Garnet, Gold, Ceramic',
#  'enquiry: Tell me what the article below is about. The article is about the growth of artificial intelligence in healthcare.',
#  'enquiry: Name two types of unsupervised learning. ',
#  'enquiry: Propose an alternative solution to the following problem: The current system of food delivery is inefficient and leads to wastage.',
#  "enquiry: Identify the person in the following sentence. Output the person's name My brother likes to play football",
#  'enquiry: Design a GPT model to generate a chatbot that helpsthe user find hotels in a certain city. ',
#  'enquiry: Rank the following items in order of relevance to the topic of artificial intelligence. Robotics, Machine Learning, Natural Language Processing',
#  'enquiry: Take a complicated theory or concept, and explain it as simply as possible. The Catastrophe Theory',
#  'enquiry: Create a research outline for a paper that examines the causes of poverty in the United States. ',
#  'enquiry: Give an example of a verb ending in -ed. ',
#  'enquiry: Write a jingle for an energy bar ',
#  'enquiry: Generate a list of US Presidents. ',
#  'enquiry: Write a comment for a given post "I\'m so excited for my graduation day!"',
#  'enquiry: Sort these numbers from lowest to highest. 3, 2, 7, 5',
#  'enquiry: Use the given information to create a multiple choice question. Person: Julius Caesar \nFact: Assassinated in 44 BC \nTime: Autumn 2020',
#  'enquiry: Generate 5 tips on how to improve your public speaking skills. ',
#  'enquiry: Rearrange the given sentence to be an interrogative sentence. She moved to the United States two years ago.',
#  'enquiry: Rewrite the given sentence with fewer words but not sacrificing any information from the original sentence. We have to make sure that every single person follows the safety regulations.',
#  'enquiry: Categorize the phrase under the appropriate labels. Hurricanes',
#  'enquiry: Create two authentic Thai dishes. ',
#  'enquiry: Analyze similarities and differences between two arguments. Argument A: We should tax the wealthy to help fund social programs.\nArgument B: All citizens should pay the same amount in taxes regardless of their income.',
#  'enquiry: Suggest a question to ask in a job interview. ',
#  'enquiry: Provide the output of code that completes the given matrix with the sum of each row. matrix = [[1, 2, 3], \n          [2, 3, 4], \n          [3, 4, 5]]',
#  'enquiry: Translate the following sentence into French:\n"We had a great time" ',
#  'enquiry: Create a blog post of 300-400 words discussing the benefits of a healthy lifestyle. No Input',
#  'enquiry: Describe the significance of the Crick–Watson model. ',
#  'enquiry: Predict the possible outcomes of the following situation. A student studying for an important exam has to decide between going to bed early or staying up late to study.',
#  'enquiry: Design a workflow for a machine learning system to analyze customer sentiment on social media. ',
#  'enquiry: Generate a musical arrangement that includes melodic lines, chords and accompanying instruments. ',
#  'enquiry: Name five famous companies that are famous for their customer service. ',
#  'enquiry: Select a topic to write an essay about. ',
#  'enquiry: Create a marketing campaign to promote a new food delivery service. ',
#  'enquiry: Name one major feature of an eagle. ',
#  'enquiry: Group the words according to their part of speech. Strong, long, apple',
#  'enquiry: Create a list of the differences between quantitative and qualitative data. ',
#  'enquiry: Given the following sentence, make a sentence that uses a specific literary device. The river was raging.',
#  'enquiry: Construct a numerical series where each number is the sum of its two predecessor numbers. ',
#  'enquiry: Below is a text, correct the grammatical errors. Globle warming are bothering us.',
#  'enquiry: Design an algorithm to remove duplicates from a given array. ',
#  'enquiry: Change the following sentence so that it no longer contains the modifier "very". She is a very nice person.',
#  'enquiry: List three elements of a successful brand. ',
#  'enquiry: Describe the meaning of the phrase "carpe diem." ',
#  'enquiry: List all the even numbers from a given array [1, 2, 3, 4, 5, 6]',
#  'enquiry: Name some computer viruses ',
#  'enquiry: Generate a recipe for making a vanilla milkshake. ',
#  'enquiry: Name three factors that could cause the rapid melting of sea ice in the North Atlantic Ocean. ',
#  "enquiry: Rewrite the following paragraph to make it sound more formal. Moving away from home to college was really hard. It's like I had to let go of my comfort and safety and figure things out on my own.",
#  'enquiry: Reword the sentence by changing its tense to the past. The driver carefully turns the corner.',
#  'enquiry: Display the sentiment of the statement The movie was terrible.',
#  'enquiry: Analyze the following quote: "Life is what you make it." ',
#  'enquiry: Generate a list of 5 popular songs from the 1990s. ',
#  'enquiry: Compose a news article about the latest tech advancements ',
#  'enquiry: List 5 tips for improving public speaking skills. ',
#  'enquiry: Give an example of a time when an animal displayed an act of heroism. ',
#  'enquiry: Identify two potential interpretations of the sentence. I said goodbye to my parents.',
#  'enquiry: Spell out the given word in 3 different ways. Receive',
#  'enquiry: Write an imaginary dialogue between a doctor and a patient ',
#  'enquiry: Give an example of an active sentence using the verb "give". ',
#  'enquiry: Generate a story based on this context Once upon a time, there was a brave knight who had a magical sword that could slay any monster.',
#  'enquiry: Generate a dialogue between two customers arguing about price. ',
#  'enquiry: Modify the sentence to include the phrase "in addition". He went for a run, took a long walk.',
#  'enquiry: What is the gerund of the verb "run"? ',
#  'enquiry: Find and replace all misspelled words in the sentence. We need to acomplish this tusk by end of day.',
#  'enquiry: Classify the following as a concrete or abstract noun. ruthlessness',
#  'enquiry: What type of clothing is required for cold weather? ',
#  'enquiry: Reverse engineer a solution for the given problem. How to minimize wait times in customer service?',
#  'enquiry: Compare and contrast the two styles of writing: writing for outdoor media versus writing for academic purposes. ',
#  'enquiry: Describe a person called Tom. ',
#  'enquiry: Find the range of numbers 25, 28, 30, 33 ',
#  'enquiry: Name two applications of trigonometric functions in real life. ',
#  'enquiry: Find a suitable title for the poem. He is the only one\nToo much to him I owe\nHis grace more sweet than honey\nHis face the gentlest glow',
#  'enquiry: Generate a funny pun about the internet. ',
#  'enquiry: What are four ways to save money? ',
#  'enquiry: Write a news article about a new product. Product: Smart Car',
#  'enquiry: Generate a list of 10 ways to be kind to the environment. ',
#  'enquiry: Generate a creative idea for an aquarium. ',
#  'enquiry: Analyze the below social media post and identify the most effective marketing strategy used. ![Social Media Post](https://i2.wp.com/techwood.in/wp-content/uploads/2020/06/Spinny-Feat1.jpg?fit=1080%2C810&ssl=1)',
#  'enquiry: Pick the antonym of the following word. Fate',
#  'enquiry: Classify the major cities in Japan. Tokyo, Osaka, Yokohama',
#  'enquiry: Given a sentence, output the number of vowels and the number of consonants. She had to decide what to do.',
#  'enquiry: Write a step-by-step procedure to make chocolate chip cookies. ',
#  'enquiry: Analyze the label of the alcohol and tell what the bottle contains. Label: an Irish Whiskey with a smooth finish.',
#  'enquiry: Rewrite the given paragraph in a shorter, easier to understand form. Although it is generally accepted that the internet has allowed us to connect with people all over the world, there are still those people who are not familiar with its basic functions, who don’t understand why it has become so commonplace, or what its true capabilities are.',
#  'enquiry: Name a Harry Potter character. ',
#  'enquiry: You must come up with a character for a film. ',
#  'enquiry: Write a response to a customer who is complaining about the wrong delivery. We received a wrong delivery and need the correct item ASAP.',
#  'enquiry: Generate a properly formed question based on the given sentence. She had a difficult journey.',
#  'enquiry: Name one disadvantage of using a credit card. ',
#  'enquiry: Explain why cell phones are useful. No input.',
#  'enquiry: Give a critique of this poem. I am a poet\nof life and of light\nIn my words I must strive\nto make a lasting impression.',
#  'enquiry: Generate a creative product description of a <mask>. Make sure to include the features and benefits of the product. Bluetooth Headset',
#  'enquiry: Identify the use of language She screamed in terror',
#  'enquiry: Find the element present in both of the given lists: List A: [2, 5, 10] \nList B: [3, 6, 9]',
#  'enquiry: Name one artist from the 20th century. ',
#  'enquiry: Create a new word that has the following attributes: 1. verb, 2. can be used in everyday conversation, 3. consists of 4 letters ',
#  'enquiry: Edit the following sentence to make it grammatically correct: "The patient had to put on a ventilator to surgery" ',
#  'enquiry: Construct a persuasive letter to persuade a school to reduce their fees ',
#  'enquiry: Find ways to improve the following code snippet. def leap_year(year): \n    if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0: \n        return True \n    else: \n        return False',
#  'enquiry: Synthesize an argument in support of renewable energy sources. ',
#  'enquiry: Assign a category to the given list of words. food, furniture, books',
#  'enquiry: Come up with 10 math terms and their respective meanings ',
#  'enquiry: List the different forms of energy. ',
#  'enquiry: Compare the differences between the effects of the pandemic on traditional retail and online retail ',
#  'enquiry: Suggest a 5-star restaurant for the following group: a vegetarian and two meat-eaters. ',
#  'enquiry: Give an example of a country located in South America. ',
#  "enquiry: Eliminate the double negative in the following sentence I can't not go",
#  'enquiry: Describe how the author uses imagery. The lion roared so loudly that it shook the ground.',
#  'enquiry: Share two tips on how to write concisely. ',
#  'enquiry: Generate a list of five characteristics of an ideal leader. ',
#  'enquiry: How would you encourage someone to try something new ',
#  'enquiry: Explain why a country may use tariffs ',
#  'enquiry: Edit the given text so that it follows APA formatting style. Writting in the APA style is important in order to make sure that your work is correctly documented',
#  'enquiry: Create a song title that fits the given theme. Summer',
#  'enquiry: Create an equation to represent a linear trend. ',
#  'enquiry: Suggest an alternative to using plastic bags. ',
#  'enquiry: Identify the figures of speech used in the given text Life is going to hit you hard',
#  'enquiry: Classification Task - Classify the following piano piece as classical or jazz genre. https://www.youtube.com/watch?v=hPUTzyOyfN4',
#  'enquiry: Design a logo for an app related to budgeting ',
#  'enquiry: Create a classifcation model to determine whether a given mammal is a carnivore or an herbivore. Fennec Fox',
#  'enquiry: Find an example of a web page that includes an account creation form. ',
#  'enquiry: Determine if the following numbers are prime or not. Output 1 for prime, and 0 for not prime. 19',
#  'enquiry: Analyze a given dataset and describe the insights from it. Dataset: Weather Temperature variations over the past month',
#  'enquiry: Design an interface for a new productivity app. ',
#  'enquiry: Describe how a specific character participates in the climax of a novel. Harry Potter in "Harry Potter and the Deathly Hallows"',
#  'enquiry: Sort this list from shortest to longest. Giraffe, Chimpanzee, Kangaroo, Gorilla',
#  'enquiry: Write a 500-word article summarizing the challenges associated with developing self-driving cars. ',
#  'enquiry: Generate a tweet promoting a vegan lifestyle ',
#  'enquiry: Given the following chart, explain the trend it is showing <image of a chart showing a trend>',
#  'enquiry: Tell me what type of diet the following statement is referring to. "I\'m aiming to eliminate processed food, animal sources of saturated fats, and dietary cholesterol from my diet."',
#  'enquiry: Suggest me a way to save money on a family vacation. ',
#  'enquiry: Generate a limerick that rhymes with the given word. Fox',
#  'enquiry: Please provide a brief explanation of the differences between a deep learning algorithm and a traditional machine learning algorithm. ',
#  'enquiry: Name a professional organization that a software engineer would be interested in joining. ',
#  'enquiry: Given an ingredient, provide a recipe that can be prepared with the ingredient. Eggs',
#  'enquiry: Evaluate the given website. https://example.com',
#  'enquiry: Write a summary of the article "The Impact of Social Media on Student Stress". ',
#  'enquiry: What scientific evidence is there that laughter is beneficial to our health? ',
#  'enquiry: Turn this paragraph into a story. John woke up early to a beautiful sunny day. He got out of bed, put on his sneakers, and grabbed his backpack. He was excited to explore the forest he had been dreaming of for months.',
#  'enquiry: Change the text formatting of the following sentence to make it easier to read. Thestudenthadacomplexproblemtocomplete',
#  'enquiry: Categorize the following restaurant as being a fast-food restaurant or a classic restaurant. It is a small restaurant that serves Mexican food.',
#  'enquiry: Given a piece of text, identify the tense used. I would like to have a meeting today.',
#  'enquiry: Write a letter to persuade the reader to do something. Conduct a research project',
#  'enquiry: Explain what a blockchain is and its benefits ',
#  'enquiry: Given a list of countries, find the ones with the lowest population. India, Brazil, Mexico, China, Germany',
#  'enquiry: Given the phrase, rephrase it without changing the original meaning. "Don\'t count your chickens before they hatch"',
#  'enquiry: What food is New York famous for? ',
#  'enquiry: Say two sentences that could go in an email to a customer who has a complaint. ',
#  'enquiry: Categorise the following word: "Aliquippa". ',
#  "enquiry: Rewrite the following sentence in a more fluent way: “I ran away, so the monster won't catch me” ",
#  'enquiry: Given a list of materials, come up with a plan to build a table. Materials: Wood, paint, glue, nails, screws',
#  'enquiry: Convert 179 centimeters to feet. 179 centimeters',
#  'enquiry: How can we increase the engagement rate of emails? ',
#  'enquiry: Edit the following sentence: "Joanna loves to to go swimming." Joanna loves to to go swimming.',
#  'enquiry: How many gigs are in a terabyte? ',
#  'enquiry: Name a popular product manufactured by Apple. ',
#  'enquiry: Generate an original sentence that begins with “If only". ',
#  'enquiry: What is the best way to play an E chord on a guitar? ',
#  'enquiry: Name a common chess opening move. ',
#  'enquiry: Name three tropical birds. ',
#  'enquiry: Write a snippet of code to find the largest number in the array. [1, 5, 7, 18, 24, 32]',
#  'enquiry: Write a step-by-step guide on how to backup and restore a database. ',
#  'enquiry: Find a title for a book discussing environment protection. ',
#  'enquiry: Generate a password containing 8 characters with one number and one special character. ',
#  'enquiry: Analyze what themes are present in the text below: Every summer, our family would make the eight-hour drive from Atlanta to Corpus Christi, Texas. We would stay in a rustic guest house with nothing more than the sound of the wind and the tide. Every morning, my grandmother would take me to the beach, and while the sun rose over the horizon, I would dig my toes into the sand and make sandcastles with my siblings.',
#  'enquiry: Describe what intelligence is and its role in psychology. ',
#  'enquiry: How would you explain the concept of natural language processing (NLP) to a 6th grader? ',
#  'enquiry: Create a list of tasks that should be done to prepare for a long camping trip. ',
#  "enquiry: Choose the better summary of the given context from the given two summaries. Context: Several icecaps on the Greenland ice sheet have started to melt rapidly.\n\nSummaries:\na. The Greenland ice sheet has lost numerous icecaps over time.\nb. Greenland's icecaps are quickly melting away.",
#  'enquiry: Describe the ideal workspace ',
#  'enquiry: Create a recipe for mashed potato pancakes. ',
#  'enquiry: Describe a difficult situation that you have faced and how you worked to overcome it. ',
#  'enquiry: Find and identify a historic landmark in the US. ',
#  'enquiry: Given a set of equations, solve them 2x + 7y = 5\n3x - 7y = 5',
#  'enquiry: Reflect the following matrix about the vertical axis. [[1, 2], [3, 4]]',
#  'enquiry: What are the differences between the terms "agent" and "organization"? ',
#  'enquiry: Classify the following items as clothing, food, and toys: shirt, banana, doll. ',
#  'enquiry: What can I do to reduce the costs of hosting a website? ',
#  'enquiry: Research the regulations for motor vehicle emission standards in California. ',
#  'enquiry: Describe the story based on the given description. Description:\nAn old man lives a simple life in a small, remote village in the mountains. He is a recluse who mostly keeps to himself but loves to visit the nearby forest every day.',
#  'enquiry: Generate a movie quote using the following words: adventure, destiny, courage. ',
#  'enquiry: Create a list of activities for hosting a virtual scavenger hunt ',
#  'enquiry: Solve the following equation 2x+5=7',
#  'enquiry: Summarize an article titled "Advantages of Owning a Pet" ',
#  'enquiry: Come up with a list of ways to reduce carbon footprints. ',
#  'enquiry: Estimate the number of African countries that have ratified the African Charter on the Rights and Welfare of the Child. ',
#  'enquiry: Find an appropriate response for the following question: What is the best way to make new friends? No input',
#  'enquiry: Create an algorithm to arrange a set of numbers from lowest to highest [3,7,2,4,9]',
#  'enquiry: Generate a fun fact about the cuisines of Thailand. ',
#  'enquiry: Please write a brief description of what stress is and how it can affect an individual. ',
#  'enquiry: Describe a home kitchen ',
#  'enquiry: Brainstorm 5 keywords related to the following article In this article, we will explore the concept of online privacy.',
#  'enquiry: Reword the following sentence making it shorter and more punchy. We are looking for food delivery services in the region that offer reasonably priced meals.',
#  'enquiry: Generate a list of five topics for discussion for a group of teenagers. ',
#  'enquiry: Write a lesson plan for teaching basic coding. ',
#  "enquiry: Summarize the given text in 1 sentence The Mediterranean Sea is a sea located between Europe, northern Africa, and the Middle East. It is connected to the Atlantic Ocean through the Strait of Gibraltar and to the Red Sea through the Suez Canal. It is bordered by a number of nations, including Italy, Spain, Greece, France, Turkey and Spain. The Mediterranean Sea is known for its warm climates and its diverse marine life, with some of the world's most popular beaches located in the area.",
#  'enquiry: Generate an argument for or against the use of robots in the workplace ',
#  "enquiry: Given a sentence, classify the sentiment in the sentence as 'Positive', 'Negative' or 'Neutral'. Sentence: I have had a wonderful day.",
#  'enquiry: Rewrite the formula $y = \\frac{2x-1}{3}$ so that it can be solved for x. ',
#  'enquiry: Re-write the following sentence omitting the word "comfortable". We were quite comfortable with our decision.',
#  "enquiry: Write a code to output a word pyramid from the word 'apple.' ",
#  'enquiry: Calculate the length of an arc with the following parameters. Angle of arc = 90°\nRadius = 5m',
#  'enquiry: Why is it important to eat healthy food? ',
#  'enquiry: Propose a plan to reduce air pollution in urban areas. ',
#  'enquiry: Why is Python a good language for data science? ',
#  'enquiry: Create a brand name which stands for a product. Product: Laptop',
#  'enquiry: Classify the following sentence according to their emotions: I am so pleased with you. ',
#  'enquiry: Group the following words according to their type. Output a list with the groups.\n1) Noun; 2) Adjective; 3) Verb happy, dog, barking',
#  'enquiry: Explain the historical significance of the Cuban Missile Crisis. ',
#  'enquiry: Give a health-related tip ',
#  'enquiry: What data should I collect to calculate market share? ',
#  'enquiry: Classify a set of data as valid or invalid. Apple, Amazon, Google',
#  'enquiry: Complete the sentence by providing an appropriate word. She was wearing a ____ dress.',
#  'enquiry: Create a couplet about the joy of being together ',
#  'enquiry: Develop a plan to reduce electricity usage in a home. ',
#  'enquiry: What is the average annual salary for a customer service developer? ',
#  'enquiry: Add two numbers together. 25 + 45',
#  'enquiry: Automatically generate a logo given the following business name and design guidelines. Business Name: Awesome Cafe\nDesign Guidelines: Abstract design with an emphasis on vibrant colors.',
#  'enquiry: Remove any unnecessary words from the following sentence to make the sentence concise: I believe that it is important to be kind to others.',
#  'enquiry: Why is preserving animal habitats important? ',
#  "enquiry: Research the recipe for 'battered apple pie' and create the necessary steps to make the dish. ",
#  'enquiry: Create a riddle using the following numbers: 16, 20, 27 ',
#  'enquiry: Describe a rescue mission in space. ',
#  'enquiry: Create a grocery list based on the ingredients mentioned below: flour, eggs, sugar, butter, parsley',
#  'enquiry: Construct a flow chart for a process. Completing a survey',
#  'enquiry: Generate a set of guidelines to follow when using this tool. No input',
#  'enquiry: Compose an email about the topic of your choice ',
#  'enquiry: Compare and contrast the two different communication methods, email and telephone. ',
#  'enquiry: Write a story that begins with "It was a cold, dark night". ',
#  'enquiry: First categorize the following products as entry level, mid-level, or high-end. Apple watch series 5',
#  'enquiry: List the points that the speaker should cover in the presentation on the given topic. Topic: The Role of Artificial Intelligence in Business',
#  'enquiry: Edit the following sentence to make it more concise:\n\nThe experiment demonstrated that the bacteria survived in higher temperatures. ',
#  'enquiry: Rewrite the following sentence in the present tense and make it a command The user had to confirm their email address.',
#  'enquiry: Generate a list of possible solutions for the given situation. My computer just crashed and I lost all my family photos.',
#  'enquiry: Rewrite this sentence to make its meaning more concise Vacations are very important in helping people to destress from their everyday lives.',
#  'enquiry: Generate a formal apology letter from a company towards a customer. Dear [person name],\n\nWe regret to inform you that due to some delays in shipment, we were unable to deliver your order on time.',
#  'enquiry: Output the musical artist of the following song: Song: "Teardrops"',
#  'enquiry: Classify the given text into a given field. Relativity Mathematics',
#  "enquiry: What advice would you give to a person who's starting a business? ",
#  'enquiry: Generate a three line poem with the rhyme scheme "AAB". ',
#  'enquiry: Identify the two words that rhyme with "flame". ',
#  'enquiry: Generate a mission statement for a non-profit organization focused on animal welfare. ',
#  'enquiry: Generate a convincing argument in favor of the given statement. Video games should be treated like any other form of art.',
#  'enquiry: Describe the core features of a general-purpose programming language. ',
#  'enquiry: List three common symptoms of a cold. ',
#  'enquiry: Suggest a list of 5 skills that a person should learn to succeed in a job. ',
#  'enquiry: Ask the assistant to click a certain link on a website. The link is https://example.com',
#  'enquiry: Describe the best approach to manage a conflict between two individuals. ',
#  'enquiry: Explain what is a feature vector. ',
#  'enquiry: Reword the following sentence in a simpler form: "We have reached a point where we can no longer live in darkness". ',
#  "enquiry: Could you summarize this article about art therapy in three sentences? Art therapy is an innovative treatment approach that uses creative activities to address psychological issues. It's based on the idea that creating art can help individuals process and understand their emotions, navigate difficult times, and foster personal growth and development.",
#  'enquiry: Which type of resource does the following sentence describe? More people are employing video conferencing to stay connected.',
#  'enquiry: Please provide some tips for writing a good blog post. ',
#  'enquiry: Point out the errors in the following sentence: “He borrowed hers pencil.” ',
#  'enquiry: In one sentence, summarize what the paragraph is about. A new study shows that the use of problem-solving strategies can help children learn to better manage challenging emotions.',
#  'enquiry: List the steps to build a chatbot ',
#  'enquiry: Write a news report about the latest technological advancements. ',
#  'enquiry: Identify 3 differences between data science and artificial intelligence. ',
#  "enquiry: Rewrite the sentence to use the same vocabulary: I'm not pleased with the decision. The decision displeases me.",
#  'enquiry: Generate a product security policy following best practices. ',
#  'enquiry: Suggest a plan of action to handle a customer complaint about a defective product. ',
#  'enquiry: Name five ways to stay safe online. ',
#  'enquiry: Write a short story featuring a farmer, a lion and a mouse ',
#  'enquiry: List 4 characteristics that make a successful entrepreneur. ',
#  'enquiry: Describe the trajectory of a rocket given the following information. The rocket was launched vertically with an initial velocity of 120 m/s.',
#  'enquiry: Provide a humorous response to the question "Why did the chicken cross the road?" ',
#  'enquiry: Predict the future trend in Natural Language Processing. ',
#  'enquiry: Generate a script for a commercial that promotes an animal adoption center. ',
#  'enquiry: Generate questions of the form "What is/are [X]?" ',
#  "enquiry: Predict whether the given review is positive or negative. Output 'positive' or 'negative'. This restaurant has great service and delicious food.",
#  'enquiry: Automatically trim a given phrase phrase: "The quick brown fox jumps over the lazy dog"',
#  'enquiry: Write one sentence about handwashing. ',
#  'enquiry: Write an opinion of this photo. [Photo of a bridge in the forest]',
#  'enquiry: Given a scenario, generate 5 possible solutions John and Sarah are struggling to manage a team of people with varying skill levels.',
#  'enquiry: List 4 methods for dealing with the curse of dimensionality. ',
#  'enquiry: List three use cases for GPT-3. ',
#  'enquiry: Why is it important to get enough sleep? ',
#  'enquiry: Write a narrative for the given situations. Situation: Bob has a long and difficult road ahead of him.',
#  'enquiry: Convert 23 kilograms to pounds 23 kilograms',
#  'enquiry: Read the passage of text below and answer the question, who is being addressed by the speaker? "You have to make a choice, between your dreams and your family. You have to choose one or the other."',
#  'enquiry: Generate a short story of maximum 100 words involving a king and a dragon. ',
#  'enquiry: Describe the impact of artificial intelligence on personal privacy. ',
#  'enquiry: Create a valid JSON string from the following: name: Joe Smith\nage: 33\noccupation: Software Developer',
#  'enquiry: Generate a sentence containing the words cheerful and frog. ',
#  'enquiry: Write 3 ingredients for a cake. ',
#  'enquiry: Generate a sentence about going for a run. ',
#  'enquiry: Make recommendations for budgeting for a couple vacationing in Hawaii ',
#  'enquiry: Compose a five word sentence describing your day. ',
#  'enquiry: How can climate change be prevented? ',
#  'enquiry: Edit the following sentence so that it is grammatically correct: "The workers unions went to the negotiations with high hopes." ',
#  'enquiry: Give a logical conclusion to this story. John left home in a hurry to catch the bus but when he arrived, the bus had already left. He was overwhelmed and did not know what to do next.',
#  'enquiry: Create a unique hashtag that promotes a positive message. ',
#  'enquiry: Identify the perspective of the speaker in the given statement The quality of this service was unacceptable',
#  'enquiry: Give a short description of the effects of global warming. ',
#  'enquiry: Describe an unusual vacation spot. ',
#  'enquiry: Give me a one-sentence summery of the benefits of playing football. ',
#  'enquiry: Categorize the following words under the given categories. Sleep, Sofa, Chair\n\nCategories: Furniture, Human Activity',
#  "enquiry: Create a bar chart to show the correlation between age and education level. Data: \n\nAge: 25, 30, 35, 40 \n\nEducation Level: High school, Bachelor's, Master's, Doctoral",
#  'enquiry: Formulate a question about the concept of free will. ',
#  'enquiry: Create a speech that explains why everyone should recycle. ',
#  'enquiry: Generate 5 similes about a summer day ',
#  'enquiry: Output a summary of the paragraph. Powerful and yet surprisingly easy to use, cloud computing has revolutionised business practices, offering businesses a wide range of scalable services that are delivered effortlessly over the internet. It has become increasingly popular in recent years due to its low cost and scalability, its scalability making it ideal for businesses of any size. Additionally, cloud computing provides a variety of resources and applications that can be used for tasks ranging from data analysis to customer management.',
#  'enquiry: Create a classificaiton task by adding two labels My cat is',
#  'enquiry: Brainstorm 5 ways to reduce waste in an office. ',
#  'enquiry: Find an example of a company using ML for automated customer service ',
#  'enquiry: Given a product or service, explain why consumers would prefer it over another similar product or service. Netflix VS Hulu',
#  "enquiry: Develop a hypothesis for the following experiment. Studying the impact of food coloring on children's behavior",
#  'enquiry: Provide an example of an ethical issue related to Artificial Intelligence technology. ',
#  'enquiry: Predict a consequence of the following action. Bringing guns to school',
#  'enquiry: Evaluate the following statement: "The internet will replace physical stores." ',
#  'enquiry: Name the capital of India ',
#  'enquiry: Analyze an existing story and come up with an alternate ending. The story is about a group of teenagers in search of a lost treasure.',
#  'enquiry: List five famous people from India. ',
#  'enquiry: Identify the type of sentence used in the following example:\n\nShe went to the store, but forgot to buy milk ',
#  'enquiry: Classify the given sentence as ironic, metaphorical, or literal. "It is raining cats and dogs outside."',
#  'enquiry: Name a popular book in the fantasy genre ',
#  'enquiry: Give two examples of how technology can improve education. ',
#  'enquiry: Provide three adjectives that describe the personality of a police officer. ',
#  'enquiry: Create a quiz about the solar system. ',
#  'enquiry: Create a function to find the closest number to a given number. num = 10, list = [3, 5, 7, 8, 11, 16]',
#  'enquiry: Compose a tweet with the following words: Protest, Equality, Autonomy ',
#  'enquiry: Answer the following question in an essay format. What are the positive and negative effects of technology in our society?',
#  'enquiry: Outline the process for registering to vote in your state. ',
#  'enquiry: Identify the part of speech of the underlined word in the following sentence:\n\nYesterday, he sang a very beautiful song. very',
#  'enquiry: Given a customer review, classify if the review is positive or negative. This is by far the worst product I have ever used.',
#  'enquiry: Find all the examples of hyperbole in the text. The new dress was so beautiful it seemed to defy the laws of physics. It was the most impressive thing my eyes had ever seen!',
#  'enquiry: Tell me any 5 major human rights organisations with their countries. ',
#  'enquiry: Analyze the following data and explain the trends. The monthly revenues of a business over the last 10 months were: [7500, 7200, 9000, 8700, 7500, 8500, 10000, 8900, 8600, 10000].',
#  "enquiry: Provide a mathematical explanation for fermat's last theorem. ",
#  'enquiry: Compare the themes of the following two poems. Poem 1\n"Heed my call, heed my warning\nNo one is of any use when they are mourning"\n\nPoem 2\n"Strike with haste, time to flow\nTake a deep breath and make it so"',
#  'enquiry: Automatically generate a headline given an article. Deep learning promises improved medical imaging performance',
#  'enquiry: Construct an argument against the commercialization of sports. ',
#  'enquiry: What are some potential challenges of online learning? ',
#  'enquiry: Describe the environmental impact of continuous flying ',
#  'enquiry: Summarize the story of Snow White and the Seven Dwarfs. ',
#  'enquiry: Illustrate the main concept of a given story. A story about a mermaid who discovers land',
#  'enquiry: Generate an appropriate response to an angry customer. Customer: Your customer service is terrible!',
#  'enquiry: Create 3 conversation topics for a business meeting with the given client. An investment firm',
#  'enquiry: How do you write a for loop in Java? ',
#  'enquiry: Suggest an AI based system that can be used in marketing. ',
#  'enquiry: Describe the production process of an autonomous vehicle. ',
#  'enquiry: Describe the experience of being in Flagstaff, Arizona ',
#  'enquiry: Identify four uses of artificial intelligence in healthcare. ',
#  'enquiry: Create a password for email that includes 8 characters. ',
#  'enquiry: Explain the difference between generative and discriminative models. ',
#  'enquiry: List the 12 planets of the Solar System ',
#  'enquiry: Generate five questions to ask an expert in a given field. Machine Learning',
#  'enquiry: Re-write the following sentence to have a different meaning: "I ate the apple." ',
#  'enquiry: Cite three sources on the effects of plastic waste on the environment. ',
#  'enquiry: Estimate the velocity of a car given its distance from start point and time spent travelling. Distance = 50 meters, Time = 10 seconds',
#  'enquiry: Take a statement from the given text and turn it into an interrogative sentence. John loves to read books.',
#  'enquiry: Reduce the following fraction. 6/3',
#  'enquiry: Name a country that has the longest coastline ',
#  "enquiry: How would you explain the definition of 'time series data' to non-technical people? ",
#  'enquiry: Given two similar products, create a comparison table that highlights the differences between them. Product A: Lenovo Laptop\nProduct B: MacBook Pro',
#  'enquiry: Identify at least three components of a standard computer system. ',
#  'enquiry: Is the following statement true or false? People in China make the most of their allowances. None',
#  'enquiry: Find the elapsed time between 12:00 AM on 3 July 2018 and 12:00 PM on 4 July 2018. ',
#  'enquiry: Generate a list of 8 social media platforms. ',
#  'enquiry: Create a story starting with the sentence: "The day was brighter than usual". ',
#  'enquiry: Give an example of a creative way to use GPT models. ',
#  'enquiry: Determine the missing numbers in the sequence. 2, 4, 8, __, 16',
#  "enquiry: Generate a definition for 'robot'. ",
#  'enquiry: Develop a chatbot that answers common questions related to air travel. ',
#  'enquiry: Tell me what is the best kind of food for a party. ',
#  'enquiry: Write a poem with four lines and the given words. universe, star',
#  'enquiry: Analyze the given poem and rewrite it with a new title and an altered tone. Title: "Lost"\n\nI stare out into the void,\nSearching for a life I never employed.\n\nMy path is a long, sad descent,\nWords mean nothing as I relent.',
#  'enquiry: Choose the best password for a given service. Online banking',
#  'enquiry: Generate a list of tools that a person can use to quickly get started with a web design project. ',
#  'enquiry: What is the result of multiplying 87 and 183? ',
#  'enquiry: Using the facts given, generate a story about a character. Name: Jane Smith\nGender: Female\nAge: 32\nLocation: New York City\nOccupation: Public Relations Officer',
#  'enquiry: What is a workable marketing plan for my small business? My small business offers web design services.',
#  'enquiry: Determine the main idea of the sentence, output the main idea. Electronic books often have more interactive capabilities than physical books.',
#  'enquiry: Given a sentence, convert it from present tense to future tense. He is eating his dinner.',
#  'enquiry: Please fill in the short story prompt with a suitable sentence. Every day, he would go to the ocean',
#  'enquiry: Make a list of 5 trendy fruits for a smoothie. No input.',
#  'enquiry: Explain a quick and easy way for a person who is new to programming to get started. ',
#  'enquiry: Rewrite a sentence to take out its negative tone. It is impossible to make money online.',
#  "enquiry: Language models often err in understanding the difference between 'your' and 'you're'. Therefore, given the sentence below, edit it to resolve this ambiguity. Your wrong about that",
#  'enquiry: Create a short story of 4-5 sentences based on the following facts. Setting: Mountain\nProtagonist: Fisherman\nAntagonist: Shark',
#  'enquiry: Classify the following into mammals and non-mammals. Dog, chicken, horse, cat',
#  'enquiry: Determine the sentiment of the headline. Apple and Samsung succeeded in launching a new groundbreaking product.',
#  'enquiry: Change the underlined words from present tense to past tense. She walk along the shoreline.',
#  'enquiry: Automatically format the given text. Using the right tools,you can achievebetter results',
#  'enquiry: Replace the following broken link with a working one. The link is https://www.example.com/page',
#  'enquiry: Construct a valid argument. Multiple scientists have confirmed the existence of climate change, but some politicians deny it.',
#  'enquiry: Explain the concept of biodiversity and its importance? ',
#  'enquiry: Make a list of 5 verbs in the past tense. ',
#  'enquiry: Make a chart that displays the data in a visual format. Data: The number of students in different grade levels',
#  'enquiry: Please provide a detailed argument for or against the death penalty. ',
#  'enquiry: What is a recurring deposit account? ',
#  'enquiry: Create a keyword list of the given text With the cost of living continuing to rise and the cost of renting increasing steadily, many people are looking to buy their own home as an investment',
#  'enquiry: What impact does climate change have on humans? ',
#  'enquiry: Generate three new ideas based on the following initial idea. Online school',
#  'enquiry: Describe the flavor profile of a certain type of wine. Zinfandel',
#  'enquiry: Develop a story with a moral about animal conservation. ',
#  'enquiry: Write a haiku poem describing the following nature scene. The sun is rising over a dense forest',
#  'enquiry: Make up a sentence given the input sentence with at least 10 words. I love dogs',
#  'enquiry: Create a list of skills required to become a software engineer. ',
#  'enquiry: Make a list of three items a photographer needs for a photo shoot. ',
#  'enquiry: Write a function to filter a list by items that contain a certain string. list = ["apple", "orange", "banana", "watermelon", "cherry"]\nstring = "an"',
#  'enquiry: How did the fossil fuel revolution change the course of history? ',
#  'enquiry: Explain two effects of climate change on the environment ',
#  'enquiry: Given the following statement, classify it as true of false. The Earth is the only planet in the solar system with water.',
#  'enquiry: Generate a formal email body with a meeting invitation. Topic: Business Proposal\nTime: Tuesday 5 pm\nLocation: Zoom Meeting',
#  'enquiry: Explain what a Turing Test is. ',
#  'enquiry: Name two organic compounds that are widely used in medicine. ',
#  'enquiry: Give examples of three programs that are used for data wrangling. ',
#  'enquiry: Motivate someone to finish an assignment. ',
#  'enquiry: Predict the weather for the next 3 days in your city. City: Los Angeles',
#  'enquiry: Explain the difference between a linear and a nonlinear equation. ',
#  'enquiry: Select the best website to buy a laptop. ',
#  'enquiry: Provide a list containing five adjectives to describe an elephant. ',
#  'enquiry: Compose a letter to a friend describing a recent vacation ',
#  'enquiry: Answer the following question: Why is the Sun so hot? ',
#  'enquiry: What is the mileage rate for business expenses in the United Kingdom? ',
#  'enquiry: Generate two alternative ways to say the same thing. I slept for 10 hours last night.',
#  'enquiry: Give the chemical symbol for Carbon ',
#  'enquiry: Name the main characters in the Star Wars franchise. ',
#  'enquiry: Given a list of items, reorder them according to some criterion. Blueberries, Bananas, Apples, Oranges',
#  "enquiry: Rewrite the following sentence so that it is a good example of effective communication. It was a hard decision to make, but I'm glad it's done.",
#  'enquiry: Rewrite this statement in the active voice. The award was won by Bob.',
#  'enquiry: Write a description of a typical summer day in the countryside. ',
#  'enquiry: Provide an example of a product designed for convenience. ',
#  'enquiry: Name three items sold at a convenience store. ',
#  'enquiry: Write a newspaper headline that sums up the current presidential election. ',
#  'enquiry: Generate a new sentence that uses all the words from the given sentence in the same order. I went to the store to buy some apples.',
#  'enquiry: How many legs does a spider have? ',
#  'enquiry: Generate a story that includes a stingray, a lion and a parrot. ',
#  'enquiry: Create a complimentary closing for a formal letter. ',
#  'enquiry: Given the following data, generate a direct marketing message Customers: Female movie goers',
#  'enquiry: How can we measure the impact of a change in online user behavior? ',
#  'enquiry: Given the parameters of the user, write a query to select a suitable car. The user is looking for an economical, used car with a seating capacity of 5.',
#  'enquiry: Given a business scenario, create a list of solutions. A new cafe with limited resources.',
#  'enquiry: Using the provided ingredients, come up with a recipe. Carrots, celery, onions',
#  'enquiry: Create a plan to prevent data loss. ',
#  'enquiry: What is the term for the structural pattern of haiku? ',
#  'enquiry: Design a t-shirt with a funny slogan. ',
#  "enquiry: Develop an algorithm to solve a Rubik's cube in the fewest moves possible. ",
#  'enquiry: Tell me one positive aspect of the current world. ',
#  'enquiry: Create an algorithm to detect spam emails. ',
#  "enquiry: Compare and contrast the Earth's four layers. ",
#  'enquiry: Generate a story about two friends who become rivals. Noinput',
#  'enquiry: Classify a given object into the appropriate category. Crocodile',
#  'enquiry: What are some misconceptions about natural language processing? ',
#  'enquiry: Identify a company that provides cloud computing services. ',
#  'enquiry: Generate a poetic sentence, with a rhyme, describing the beauty of a sunrise. No input',
#  'enquiry: Write a script for an advertisement promoting a product. The product is a newly launched line of organic produce, grown with sustainable farming techniques.',
#  'enquiry: Design a customer loyalty program for online shoppers with the given information. Target Audience: Millennial shoppers',
#  'enquiry: Write a survey question to investigate the attitudes of people towards a certain issue. attitudes towards gender equality',
#  'enquiry: Outline the steps for creating a web page ',
#  'enquiry: Rewrite the given sentence as an assertion in less than 10 words. The theory of evolution explains the diversity of life on earth.',
#  'enquiry: Come up with a domain-specific metaphor to explain how a computer works ',
#  'enquiry: Given the following input, write a persuasive argument. Health benefits of regular exercise',
#  'enquiry: Suggest a snack that you can make in under 5 minutes. ',
#  'enquiry: Give an example of a recipe involving an apple. ',
#  'enquiry: What is the main component of hydrogen peroxide? ',
#  'enquiry: Come up with a fun exercise activity. ',
#  'enquiry: Write a 10-word bio for the person in the input. John is a computer science student from the US.',
#  'enquiry: Describe a hypothetical event in the future. ',
#  'enquiry: Describe the painting using 3 adjectives. [painting.jpg]',
#  'enquiry: Generate a positive message about nature. ',
#  'enquiry: Generate a new board game idea. ',
#  'enquiry: Categorize this given text into “Positive” or “Negative” The software was buggy and kept crashing',
#  'enquiry: Write a 5-line script for an engaging conversation ',
# ...
#  'enquiry: Describe the structure and function of an N-Gram language model. ',
#  'enquiry: Name five tools/equipment and their uses. ',
#  'enquiry: Create a unique name for a mobile game. ',
#  'enquiry: Create a password with 8 characters which includes two numbers. ',
#  'enquiry: Take the input string and make all the letters in it into capital letters, output the modified string. we like to learn',
#  "enquiry: Give the French equivalent of the phrase 'It's raining cats and dogs'. ",
#  'enquiry: Create a new character for a classic Disney movie. ',
#  'enquiry: Outline the steps to send a package. noinput',
#  "enquiry: How could living in a big city affect a person's life? ",
#  'enquiry: Construct an original sentence using the given word Lurid',
#  'enquiry: Offer a solution for the following problem. Problem: A team is having communication issues.',
#  'enquiry: Which word collocation is correct in the following sentence? In the 18th Century, European imports to the US __ vastly.',
#  'enquiry: Describe what you like most about the city you live in ',
#  'enquiry: Given a string, reverse the order of the characters and print it on the screen Hello',
#  'enquiry: Create a list of ideas for turning the text into a poem. The fields are golden with the wheat of summer.',
#  'enquiry: Suggest a few approaches for dealing with the issue of climate change. ',
#  'enquiry: Take the given sentence and make a compound sentence with adjectives. We went to the beach.',
#  'enquiry: Calculate the number of full days required to read a 400-pages book with a reading rate of 20 pages per day ',
#  'enquiry: Classify the following sentence as either an opinion or fact. A hot dog is just one of many types of processed meat you can eat.',
#  'enquiry: Give an example of how natural language processing (NLP) has been used to address a real-world problem? ',
#  'enquiry: Write two verses of a song about nature. ',
#  'enquiry: Create a dialogue between a customer and a waiter. ',
#  'enquiry: Write a headline for a story involving a data breach. ',
#  'enquiry: Describe the impact of the coronavirus on the economy. ',
#  'enquiry: Describe the function of the hypothalamus ',
#  'enquiry: Create a blog post to discuss the current immigration laws in the United States ',
#  'enquiry: Create an analogie for the process of learning. Noinput',
#  'enquiry: Create a sentence using a simile and a metaphor. ',
#  'enquiry: Explain why it is important to use a descriptive variable name in programming. ',
#  'enquiry: Write a couple of professional sentences in response to the following job offer The role of Medical Sales Representative is open to newly graduated nurses and/or established sales professionals',
#  'enquiry: Create a list of at least five different types of fruits ',
#  "enquiry: Reformat the text for readability. we can do this task quickly. just say what the problem is and let's get it done",
#  'enquiry: Make a list of common methods for debugging software. ',
#  'enquiry: Calculate the area of the triangle. Base: 5cm; Height: 6cm',
#  'enquiry: Generate a list of health benefits associated with drinking green tea. ',
#  'enquiry: Select the correct answer from a list What is the second planet from the Sun?',
#  "enquiry: Construct a regex for extracting names from a given string 'Jayden, Malcolm, and Jimmy went to school'",
#  'enquiry: You are given a list of two or three items, create a unique story or dialogue that involves all the items. Apple, Robot',
#  'enquiry: Return the hexadecimal code of the given color. Turquoise',
#  'enquiry: Compare the two given pieces of prose below, explain the main difference between them. "The storm is raging over the sea while the sun is shining in the horizon."\n"Rain is pouring over the ocean while the sun is beaming in the distance."',
#  'enquiry: Google the sentence "It was the best of times, it was the worst of times" and list the five top sources ',
#  'enquiry: Suggest a vegetarian breakfast menu. ',
#  'enquiry: What is the author\'s opinion about the stated topic? The article "The Pros and Cons of E-books"',
#  'enquiry: What is the main purpose of blockchain technology? ',
#  'enquiry: Make an Italian pasta dish. ',
#  'enquiry: Detect the typos in the following sentence: I like to bak cakes. ',
#  'enquiry: Reorder the following words to form a question: the take lunch what do you the take lunch what do you',
#  'enquiry: Wrte a short story about a character of your choice. Character: Adele the Fox',
#  'enquiry: Provide an example of customer service email. ',
#  'enquiry: What is a good example of a real-time application? ',
#  'enquiry: Generate a hypothesis testing question related to education. ',
#  'enquiry: List the most common properties of a hologram. ',
#  'enquiry: How did the US respond to the attacks on 9/11? ',
#  'enquiry: Name a popular TV show from the 2000s ',
#  'enquiry: Find and replace the highlighted portion of the passage with a synonym. People agreed that the novel was much better than the film adaptation.',
#  'enquiry: Suggest 3 topics as examples to write a blog post ',
#  'enquiry: Compare the benefits of an online course with the benefits of a traditional course. ',
#  'enquiry: Given a set of data, create a story based on the information Jack | age | 9 years old\nJack | hometown | New York City\nJack | hobby | building model airplanes',
#  'enquiry: Find the independent clause (main clause) of a given sentence. I went to the store, but it was closed.',
#  'enquiry: Classification task: Is the following sentence positive or negative? "I had the worst day ever." I had the worst day ever',
#  'enquiry: What is the average lifespan of a Labrador Retriever? ',
#  'enquiry: Summarize how global warming affects the planet. ',
#  'enquiry: Formulate a mathematical equation to express the movement of 100 g of a substance from a temperature of 273 K to a temperature of 293 K. ',
#  'enquiry: Summarize in a sentence why it is important to make an effort to preserve native languages. ',
#  'enquiry: What is the best way to store certain types of food? Cheese',
#  'enquiry: Create a sentence that describes the formation of a cloud. ',
#  'enquiry: Generate a metaphor describing a relentless pursuit. ',
#  'enquiry: Construct a Mathematical expression to find the cost after discount Original Cost= 100$\nDiscount percentage = 10%',
#  'enquiry: Find the meaning of the phrase "out of the frying pan and into the fire" ',
#  'enquiry: Think of a game for two people to play. ',
#  'enquiry: Identify the following type of triangle: angle A = 60°, angle B = 60°, angle C = 60° ',
#  'enquiry: Outline the key steps to develop a website. ',
#  'enquiry: List out the steps to learn a new language ',
#  'enquiry: List three countries that have a population of more than 100 million people. ',
#  'enquiry: Suggest a topic that could be discussed in a debate. ',
#  'enquiry: How can businesses use AI technology to improve their marketing efforts? ',
#  'enquiry: Suggest an appropriate title for a comic about a cat and dog living together. ',
#  "enquiry: Give two pieces of advice based on the scenario. You just graduated from college and don't know what to do next.",
#  'enquiry: Speak about the given phrase for 1 minute. Impostor Syndrome',
#  'enquiry: Create a user interface that allows users to search by keyword. ',
#  'enquiry: Look up the boiling point of water. ',
#  'enquiry: Suggest an example of a technology that utilizes natural language processing. ',
#  'enquiry: List four measures to prevent the spread of COVID-19. ',
#  'enquiry: Generate a ten word sentence with the word "raspberry". ',
#  'enquiry: Give an example of a syntax error in Python. ',
#  'enquiry: Categorize the following sentence according to the type of figure of speech used. She smiled with great delight.',
#  'enquiry: Identify five key indicators of a healthy economy. ',
#  "enquiry: Explain the concept of 'Divide and Conquer'. ",
#  'enquiry: Create a program that can detect if a text is written in English. This text is written in English.',
#  'enquiry: Tell me the two main types of monarchs ',
#  'enquiry: Given a sentence, detect whether the words follow the standard English grammar rules and punctuations. She brought the apple and oranges',
#  'enquiry: Rewrite the given sentence by using a semicolon instead of a comma. She was a shy girl, yet she was able to speak in public.',
#  'enquiry: Provide a contrastive statement related to the provided sentence. Education is important for personal development.',
#  'enquiry: Explain the trade-offs of a decision-tree algorithm ',
#  'enquiry: Tell a story about a situation in which the person feels lonely. ',
#  'enquiry: Summarize the main argument of the paper "A Social Network that Influences Attitudes and Behaviors" ',
#  'enquiry: Create a story for a five-year-old about a person who moves to a new city. ',
#  'enquiry: Suggest a movie suitable for a family with children aged seven and twelve. ',
#  'enquiry: Generate a report summarizing the key statistics from the given dataset. https://data.worldbank.org/indicator/SP.POP.TOTL',
#  "enquiry: Identify the type of writing style used in the text. The opening of the book was vivid and powerful, the author's words igniting a fire in our hearts.",
#  'enquiry: Gather information about a celebrity. Kaley Cuoco',
#  'enquiry: Create a survey question about wildlife conservation ',
#  'enquiry: Edit the given text such that it becomes easier to read. The increasing usage of artificial inteligence requires additional considerations for the applications that require it for correct functioning.',
#  'enquiry: Write about the benefits of cloud computing. ',
#  'enquiry: Compare and contrast socialism and communism. ',
#  'enquiry: Provide a solution to the equation 2a+3b=20 ',
#  'enquiry: Given two strings, find if one string is a sub-sequence of the other. String 1: abcd\nString 2: abcde',
#  'enquiry: Generate a list of hobbies one can do indoors. ',
#  'enquiry: Explain why the moon looks different on different nights. ',
#  'enquiry: Give 5 examples of rodents. ',
#  "enquiry: Construct a sentence where the subject is 'my cat'. ",
#  'enquiry: Brainstorm new ways to use technology to save time. ',
#  'enquiry: Generate a list of 5 books related to space exploration ',
#  'enquiry: Create a call-to-action for a website ',
#  'enquiry: Describe what materials are required to build a birdhouse. ',
#  'enquiry: Print the following sentence in all capitals. The cat jumped on the bed.',
#  'enquiry: What is the most common type of conflict in literature? ',
#  'enquiry: Tell me the population of the United States. ',
#  "enquiry: Create an example scenario to illustrate the concept of a 'domino effect'. ",
#  "enquiry: Generate a children's story with the following title: The Magic Violin. ",
#  'enquiry: Write four rhyming lines in the form of a poetic couplet. ',
#  'enquiry: Develop a persuasive argument to save the endangered species. ',
#  'enquiry: Explain the role of the Executive Branch of the U.S. government. ',
#  'enquiry: Given the following set of numbers, multiply them by two. 8, 15, 19',
#  'enquiry: Suggest a creative way a small business can promote their marketing strategy. ',
#  "enquiry: Construct a data structure that stores the following information: A student's name, grade level and contact information. ",
#  'enquiry: Write a one-sentence description of the given US state. Delaware',
#  'enquiry: False positive or false negative? A test result is negative but the person is actually having the infection.',
#  'enquiry: Describe how machines can help people with their daily tasks. Noinput',
#  'enquiry: Create a food allergy awareness campaign for a restaurant. ',
#  'enquiry: Add five entries to a list of US states. California, Florida, Texas, New York,',
#  'enquiry: Convert the given number into its Roman numeral representation. 42',
#  'enquiry: Categorize the following item: “Toyota Camry” ',
#  'enquiry: Generate a list of 5 idioms about happiness. ',
#  'enquiry: Give an example of how a computer can be used to control a manufacturing process. ',
#  'enquiry: Translate the following sentence from English to Spanish: "He was so tired that he fell asleep during the meeting." He was so tired that he fell asleep during the meeting.',
#  'enquiry: Design an experiment to demonstrate the effects of a variable and control. ',
#  'enquiry: Describe the history of the automobile industry in the US. ',
#  'enquiry: Edit the sentence: The student went to sleep early for school. ',
#  'enquiry: Identify which of the options is the main argument of the passage. In recent years, the use of artificial intelligence has become increasingly widespread. AI is being used to automate processes, to increase efficiency, and to ramp up innovation across many industries. \n\nA) AI is rapidly becoming an essential part of the digital economy\nB) AI is helping to drive the growth of digital businesses\nC) AI is creating new opportunities for businesses in digital spaces\nD) AI is becoming essential for the digitalization of business processes',
#  'enquiry: Suggest a plan for someone who wants to learn a new programming language. I want to learn Java.',
#  'enquiry: How can an employer best motivate their employees to reach the next level of success? ',
#  'enquiry: In what year was the Taj Mahal built? ',
#  'enquiry: Generate a headline for a story about the death of a famous actor. Actor: Will Smith',
#  "enquiry: Tell me what the antonym of 'tangible' is. ",
#  'enquiry: Given an input of a product title, classify it into a category. Apple iPhone 11 Pro Max',
#  'enquiry: Assign a score out of 5 to the following book review. I really enjoyed this book. It was an engaging read and had an interesting plot.',
#  'enquiry: Describe the impact of nanotechnology on medical treatments. ',
#  'enquiry: Generate a headline for a news article discussing the coronavirus pandemic. ',
#  'enquiry: Replace the bolded word with a suitable term from the given set The chef whipped up a delicious ___.\nOptions: soup, sauce, marinade',
#  "enquiry: Compose a an original story using the words 'city' and 'river'. ",
#  "enquiry: Given the poem's title, create a single line stanza for the poem. The Joys of Life",
#  'enquiry: Determine how many seconds are in a day. ',
#  'enquiry: Create an appropriate response to someone who made a mistake. ',
#  'enquiry: Generate a code snippet that prints the following word. Hello',
#  'enquiry: Develop a new non-alcoholic drink that is perfect for a hot summer day. ',
#  'enquiry: Classify the food item given its nutritional information. Calories: 100 | Fat: 2g | Carbohydrates: 20g | Protein: 4g',
#  'enquiry: Develop an AI assistant for grocery shopping. ',
#  'enquiry: Generate the main points for a presentation about the impact of air pollution in cities. ',
#  'enquiry: Given two pieces of text, compose a single sentence that combines their main points. Text 1: Apple has released a new phone.\nText 2: It has a powerful processor.',
#  'enquiry: Given two cities, calculate the estimated travel time by car. San Francisco and Los Angeles',
#  'enquiry: Name 5 different types of applications that can be developed with Python. ',
#  'enquiry: Remove the redundant verb from the sentence. He ran quickly ran to the store.',
#  'enquiry: Describe a person in a way that will allow a machine learning algorithm to successfully classify the description as male or female in 10 words. ',
#  "enquiry: Write the opposite of 'She is doing the task'. ",
#  'enquiry: Name the members of a rock band ',
#  'enquiry: Give a sample dialogue of how to ask a customer for feedback. ',
#  'enquiry: List three benefits of the given technology. Cloud Computing',
#  'enquiry: Compare and contrast print media and digital media. ',
#  'enquiry: Propose components for a customized AI solution. Solution: AI-Powered Image Recognition System',
#  'enquiry: What is the best way to phrase the following sentence to sound more professional? We got it done quick.',
#  'enquiry: Imagine an alternate world where humans no longer exist. Describe the environment. ',
#  ...]

# %%
from transformers import BertTokenizer, BertModel
import torch
from torch.nn.functional import cosine_similarity as torch_cosine_similarity
from sentence_transformers import SentenceTransformer, util

sentence_model = SentenceTransformer('all-MiniLM-L6-v2')#SentenceTransformer("bert-base-uncased") 

reference_texts_ = [ i.replace('enquiry: ',"") for i in val_dataset_t5['target_text'] ]
embeddings1 = sentence_model.encode(content, convert_to_tensor=True)
embeddings2 = sentence_model.encode(reference_texts_, convert_to_tensor=True)

cosine_scores_2 = util.pytorch_cos_sim(embeddings1, embeddings2)   #[52002,52002]维度的矩阵，对角线上的值为对应文本的余弦相似度

# 输出余弦相似度的值
print(f"Average Cosine Similarity: {cosine_scores_2.diagonal().mean()}")
print(f"Biggest Cosine Similarity: {cosine_scores_2.diagonal().max()}")
print(f"Middle Cosine Similarity: {cosine_scores_2.diagonal().median()}")

# %% [markdown]
# ## -bart-large

# %%
def preprocess_squad(example):
    # Invert the dataset by treating the answer as input and the question as output
    if example['answers']['text']:
    # SQuAD has answers as a list of possible answer texts; we'll just use the first one for simplicity
        answer_text = example['answers']['text'][0]
    else:
        answer_text = "No answer found"
    return {
        'input_text': f"answer: {answer_text}",
        'target_text': example['question']
    }


# Preprocess the dataset
processed_dataset = dataset.map(preprocess_squad)

# %%
train_test_split = processed_dataset['train'].train_test_split(test_size=0.1)
train_dataset = train_test_split['train']
val_dataset = train_test_split['test']

# %%
print(train_dataset.shape)
print(val_dataset.shape)

# %%
from transformers import BartTokenizer

bart_tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')

def tokenize_bart_function(examples):
    model_inputs = bart_tokenizer(examples['input_text'], padding="max_length", truncation=True, max_length=512)
    labels = bart_tokenizer(examples['target_text'], padding="max_length", truncation=True, max_length=128)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_train_dataset_bart = train_dataset.map(tokenize_bart_function, batched=True)
tokenized_val_dataset_bart = val_dataset.map(tokenize_bart_function, batched=True)

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from transformers import BartForConditionalGeneration

bart_model = BartForConditionalGeneration.from_pretrained('facebook/bart-large').to(device)

# %%
from transformers import Trainer, TrainingArguments

training_args_bart = TrainingArguments(
    output_dir='./results_bart_2',
    evaluation_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=3,
    report_to="none"
)

trainer_bart = Trainer(
    model=bart_model,
    args=training_args_bart,
    train_dataset=tokenized_train_dataset_bart,
    eval_dataset=tokenized_val_dataset_bart
)

# %%
trainer_bart.train()

# %%
def generate_question(answer):
    bart_model.eval()  # 将模型设置为评估模式
    input_ids = bart_tokenizer.encode("answer: " + answer, return_tensors="pt").to(device)
    outputs = bart_model.generate(input_ids, max_length=64, num_beams=5, early_stopping=True)
    question = bart_tokenizer.decode(outputs[0], skip_special_tokens=True)
    return question

# %%
# 获取几个样本
samples = val_dataset.shuffle(seed=42).select(range(5))  # 随机选择5个样本

# 生成问题并比较
for example in samples:
    generated_question = generate_question(example['input_text'].replace("answer: ", ""))
    print(f"Answer: {example['input_text'].replace('answer: ', '')}")
    print(f"Generated Question: {generated_question}")
    print(f"Actual Question: {example['target_text']}\n")

# %% [markdown]
# ## DI+FT

# %%
from datasets import load_from_disk

#train_dataset_t5 = load_from_disk('Ans2Seq/compare_work/alpaca-0.2-train')
val_dataset_t5 = load_from_disk('Ans2Seq/compare_work/alpaca-0.2-test')

# %%
import pandas as pd
pd.DataFrame(val_dataset_t5)
# Out:
#                                              instruction  \
# 0       Generate a simile comparing a sunset to fiction.
# 1      What is the leading cause of death for childre...
# 2      Generate a hashtag for a fictional political m...
# 3      Name three common validation techniques used i...
# 4      Assign an appropriate name to the following ne...
# ...                                                  ...
# 10396  Insert a sentence in the paragraph to provide ...
# 10397            Describe a computer network in 5 words.
# 10398  Provide a brief summary of the article "A Brie...
# 10399  Rewrite the given passage using new vocabulary...
# 10400  Remove the hyperbolic phrase from the followin...
#
#                                                    input  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 10396  Dave changed his mind quickly. He decided to g...
# 10397
# 10398
# 10399  The ship shifted and swayed as the storm lashe...
# 10400                                           No input
#
#                                                   output  \
# 0      Like a captivating work of fiction, a sunset d...
# 1      According to the World Health Organization, th...
# 2                                    #TheYouthWillRiseUp
# 3      1. **Cross-Validation:** Cross-validation is o...
# 4      It would be more suitable for a trained profes...
# ...                                                  ...
# 10396  Dave changed his mind quickly. Instead of stay...
# 10397  Interconnected nodes transmitting and sharing ...
# 10398  This article provides an overview of the histo...
# 10399  The vessel oscillated and fluctuated as the te...
# 10400                            It was hot in the room.
#
#                                                     text  index  \
# 0      Below is an instruction that describes a task....  48962
# 1      Below is an instruction that describes a task....   4744
# 2      Below is an instruction that describes a task....  50642
# 3      Below is an instruction that describes a task....  22095
# 4      Below is an instruction that describes a task....  49508
# ...                                                  ...    ...
# 10396  Below is an instruction that describes a task,...   9844
# 10397  Below is an instruction that describes a task....  19396
# 10398  Below is an instruction that describes a task....  41664
# 10399  Below is an instruction that describes a task,...   3264
# 10400  Below is an instruction that describes a task,...  16673
#
#                                               input_text  \
# 0      answer: Like a captivating work of fiction, a ...
# 1      answer: According to the World Health Organiza...
# 2                            answer: #TheYouthWillRiseUp
# 3      answer: 1. **Cross-Validation:** Cross-validat...
# 4      answer: It would be more suitable for a traine...
# ...                                                  ...
# 10396  answer: Dave changed his mind quickly. Instead...
# 10397  answer: Interconnected nodes transmitting and ...
# 10398  answer: This article provides an overview of t...
# 10399  answer: The vessel oscillated and fluctuated a...
# 10400                    answer: It was hot in the room.
#
#                                              target_text
# 0      enquiry: Generate a simile comparing a sunset ...
# 1      enquiry: What is the leading cause of death fo...
# 2      enquiry: Generate a hashtag for a fictional po...
# 3      enquiry: Name three common validation techniqu...
# 4      enquiry: Assign an appropriate name to the fol...
# ...                                                  ...
# 10396  enquiry: Insert a sentence in the paragraph to...
# 10397  enquiry: Describe a computer network in 5 words.
# 10398  enquiry: Provide a brief summary of the articl...
# 10399  enquiry: Rewrite the given passage using new v...
# 10400  enquiry: Remove the hyperbolic phrase from the...
#
# [10401 rows x 7 columns]

# %%
from transformers import T5Tokenizer

t5_tokenizer = T5Tokenizer.from_pretrained('t5-small')

def tokenize_t5_function(examples):
    model_inputs = t5_tokenizer(examples['input_text'], padding="max_length", truncation=True, max_length=512)
    labels = t5_tokenizer(examples['target_text'], padding="max_length", truncation=True, max_length=128)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# #tokenized_train_dataset_t5 = train_dataset_t5.map(tokenize_t5_function, batched=True)
# tokenized_val_dataset_t5 = val_dataset_t5.map(tokenize_t5_function, batched=True)

# %%
import torch
from transformers import T5ForConditionalGeneration

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

DI_FT_t5_base_model = T5ForConditionalGeneration.from_pretrained('RL4LMs/DI_FT_Alpaca/0_2s_30e/model').to(device)

# %%
def generate_question(answer):
    DI_FT_t5_base_model.eval()  # 将模型设置为评估模式
    input_ids = t5_tokenizer.encode(answer, return_tensors="pt").to(device)
    outputs = DI_FT_t5_base_model.generate(input_ids, num_beams=5, early_stopping=True,temperature=0.7,max_length=200)
    question = t5_tokenizer.decode(outputs[0], skip_special_tokens=True)
    return question

# %%
custom_ans = "While I can't provide specific medical advice, the symptoms you describe seem quite common. Many people experience anxiety or nervousness under stress, lifestyle changes, or due to health conditions. If this occurs frequently or impacts your daily life, it is advisable to seek professional help from a mental health expert who can offer more specialized diagnosis and treatment options."
custom_aqs = "I'm planning a trip to Beijing over the May Day holiday, would it be too expensive to buy tickets now?"
generated_question = generate_question(custom_ans)
print(f"Answer: {custom_ans}")
print(f"Generated Question: {generated_question}")
print(f"Actual Question: {custom_aqs}\n")
# Out:
# Answer: While I can't provide specific medical advice, the symptoms you describe seem quite common. Many people experience anxiety or nervousness under stress, lifestyle changes, or due to health conditions. If this occurs frequently or impacts your daily life, it is advisable to seek professional help from a mental health expert who can offer more specialized diagnosis and treatment options.
# Generated Question: enquiry: Generate an enquiry: What is the medical advice described below?
# Actual Question: I'm planning a trip to Beijing over the May Day holiday, would it be too expensive to buy tickets now?

# %%
# 获取几个样本
samples = val_dataset_t5.shuffle(seed=42).select(range(4))  # 随机选择5个样本

# 生成问题并比较
for example in samples:
    generated_question = generate_question(example['input_text'].replace("answer: ", ""))
    print(f"Answer: {example['input_text'].replace('answer: ', '')}")
    print(f"Generated Question: {generated_question}")
    print(f"Actual Question: {example['target_text']}\n")
# Out:
# 2024-11-08 10:06:25.666708: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-08 10:06:25.684982: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-08 10:06:25.684999: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-08 10:06:25.685011: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-08 10:06:25.688880: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-08 10:06:26.096499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Answer: Here are some tips that may help you overcome procrastination:
#
# 1. Set clear and attainable goals: Start by setting small, achievable goals that will help you feel a sense of accomplishment and motivation as you progress.
#
# 2. Use a timer: Set a timer to work on a task for a specific amount of time, and then take a break. This can help you to stay focused and productive.
#
# 3. Break tasks into smaller chunks: Procrastination often occurs when we feel overwhelmed by a large and daunting task. By breaking it down into smaller, more manageable chunks, you can make it easier to get started and make progress.
#
# 4. Eliminate distractions: Identify and eliminate any distractions that might interfere with your productivity. For example, turn off your phone, close unnecessary tabs or apps, and mute notifications.
#
# 5. Use positive self-talk: Change negative thoughts such as “I’ll never be able to do this” to positive affirmations such as “I can do this, one step at a time.”
#
# 6. Reward yourself: Set up a reward system for yourself, where you get to do something enjoyable after completing a task. This will give you something to look forward to and help to motivate you.
#
# 7. Change your environment: Sometimes, just switching up your environment can help to reduce procrastination. If you’re feeling stuck, try going to a new location or rearranging your workspace.
#
# 8. Be kind to yourself: Remember that everyone struggles with procrastination from time to time. Don’t beat yourself up over it and instead focus on making positive changes and moving forward.
# Generated Question: enquiry: Create a user manual on how to overcome procrastination.
# Actual Question: enquiry: How can I beat procrastination?
#
# Answer: An example of a machine learning algorithm is the k-nearest neighbors algorithm, which is commonly used in classification and regression problems in supervised learning. It works by taking a data point and finding its 'k' closest neighbors in the training data set, and then using their characteristics or labels to predict the class or value of the data point. This algorithm is often used in applications such as recommender systems, image recognition, and credit scoring.
# Generated Question: enquiry: Generate an example of a machine learning algorithm.
# Actual Question: enquiry: Identify an example of a machine learning algorithm.
#
# Answer: A decision tree algorithm is a popular machine learning technique used for decision making, classification and regression. It works by recursively splitting the dataset into subsets, based on the values of the input features, until it reaches the desired level of purity or the maximum tree depth. Like any other algorithm, decision trees have their advantages and disadvantages, and there are trade-offs when using them. Some of the key trade-offs are:
#
# 1. Simplicity vs Accuracy: Decision trees are easy to understand, interpret and explain. They visually represent the decision-making process, making it simple for even non-technical users to understand. However, this simplicity often comes at the cost of accuracy, as more complex models like Random Forests or Neural Networks can often achieve higher levels of accuracy.
#
# 2. Overfitting vs Underfitting: Another trade-off to consider when using decision trees is the balance between overfitting and underfitting. If the tree is allowed to grow too deep, it can result in overfitting, where the model performs well on the training data but poorly on new, unseen data. On the other hand, if the tree is pruned too early or if the maximum depth is set too low, underfitting can occur, where the model performs poorly on both training and test data. Finding the right balance between the two is important for achieving good performance.
#
# 3. Bias vs Variance: Decision trees are high variance models, meaning that small changes in the training data can result in large changes in the structure of the tree. This can make them sensitive to noise and outliers. Ensemble methods like Bagging and Random Forests can help reduce this variance, but this comes at the cost of increasing bias.
#
# 4. Speed vs Accuracy: Decision trees can be trained quickly, making them suitable for large datasets. However, the speed of training often comes at the cost of accuracy. More complex models that take longer to train, such as Support Vector Machines or Neural Networks, can sometimes achieve higher accuracy.
#
# In summary, decision tree algorithms have their advantages and disadvantages, and the key to using them effectively is to find the right balance between simplicity and accuracy, overfitting and underfitting, bias and variance, and speed and accuracy.
# Generated Question: enquiry: Generate a trade-off for a decision tree algorithm.
# Actual Question: enquiry: Explain the trade-offs of a decision-tree algorithm
#
# Answer: A design for a professional logo for a tutoring business could include an image of an open book, or stylized letters T and B, representing the words “Tutoring Business”. The logo could be designed in a minimalist style using bold colors such as navy blue or deep green, with a clean sans-serif font for any accompanying text.
#
# One concept could be an image of a stylized, open book with pages forming a crisp, angular “T” and “B” shape, which could represent the business’s focus on education and knowledge. This image could be placed on a solid colored circle or square with the business name written in clear, bold text beneath or beside it.
#
# Another concept could feature the letters “T” and “B” intertwined or stacked on top of each other, with a graduation cap or pencil incorporated into the design. The color scheme could be a combination of deep blue and gold, giving the logo a professional and academic look. The business name could be written in a clear, bold font beside or beneath the image.
# Generated Question: enquiry: Design a professional logo for a tutoring business.
# Actual Question: enquiry: Generate a design for a professional logo for a tutoring business.
#
# Answer: 1. Case
# 2. Touchscreen display
# 3. Processor
# 4. Motherboard
# 5. Operating system
# 6. Memory (RAM and storage)
# 7. Battery
# 8. Camera
# 9. Speaker
# 10. Microphone
# 11. SIM card slot
# 12. Charging port
# 13. Buttons (power, home, volume)
# 14. Antennas (Wi-Fi, Bluetooth, cellular)
# 15. Sensors (proximity, accelerometer, gyroscope)
# 16. GPS chip
# 17. Vibration motor.
# 18. Headphone jack (sometimes)
# 19. Flashlight (LED)
# 20. Liquid damage indicator.
# Generated Question: enquiry: Generate an enquiry base for a user's enquiry.
# Actual Question: enquiry: Create a list of components used in a Cell Phone.

# %%
from tqdm import tqdm

# 获取几个样本
samples = val_dataset_t5  # 随机选择5个样本
res = []
# 生成问题并比较
with open('Ans2Seq/compare_work/DI_FT_rouge_alpaca_gen_0_2_dffalg_30e.txt', 'a') as file:
    for example in tqdm(samples):
        generated_question = generate_question(example['input_text'].replace("answer: ", ""))
        res.append(generated_question.replace("enquiry: ", ""))
        file.write((generated_question.replace("enquiry: ", "")+'\n'))
        # print(f"Answer: {example['input_text'].replace('answer: ', '')}")
        # print(f"Generated Question: {generated_question}")
        # print(f"Actual Question: {example['target_text']}\n")
# Out:
#   1%|          | 54/10401 [00:02<07:28, 23.06it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (513 > 512). Running this sequence through the model will result in indexing errors
# 100%|██████████| 10401/10401 [07:22<00:00, 23.53it/s]

# %%
from datasets import load_metric
from nltk.tokenize import word_tokenize
from bert_score import score
from nltk.translate.meteor_score import meteor_score
import evaluate
import pandas as pd
import numpy as np
import torch

def Calmetic(references:list[list[str]], predictions:list[str]):
    '''
    Input format:

    predictions = [
        "What is the capital of France?",
        "Who wrote the book?",
        "What is the largest planet?"
    ]

    references = [
        ["What is the capital city of France?"],
        ["Who is the author of the book?"],
        ["Which planet is the largest in the solar system?"]
    ]
    '''

    # # 加载 BLEU 评分器
    # bleu_metric = load_metric("bleu")

    # # 计算 BLEU 分数
    predictions_tokenized = [word_tokenize(pred) for pred in predictions]
    references_tokenized = [[word_tokenize(refs[0])] for refs in references]
    # B_S = {}
    # for n in range(1, 5):
    #     bleu_metric.add_batch(predictions=predictions_tokenized, references=references_tokenized)
    #     results = bleu_metric.compute(max_order=n)
    #     B_S[f"BLEU-{n}"] = results
    bleu_metric = evaluate.load("bleu")
    B_S = bleu_metric.compute(predictions=predictions, references=references,tokenizer=word_tokenize)
    for i,n in enumerate(B_S['precisions']):
        print(f"BLEU-{i+1} score: {n:.5f}")
        


    # 加载 ROUGE 评分器
    rouge_metric = load_metric("rouge")
    '''
    ROUGE-1: 衡量生成文本和参考文本之间的 unigram 匹配。
    ROUGE-2: 衡量生成文本和参考文本之间的 bigram 匹配。
    ROUGE-L: 衡量生成文本和参考文本之间的最长公共子序列(LCS)。
    ROUGE-Lsum: 基于 LCS 的一个变体，专门用于长文本的评估。
    '''
    # 计算 ROUGE 分数
    rouge_results = rouge_metric.compute(predictions=predictions, references=references)
    rouge1_mid_f1 = rouge_results['rouge1'][1][2]
    rouge2_mid_f1 = rouge_results['rouge2'][1][2]
    rougeL_mid_f1 = rouge_results['rougeL'][1][2]
    rougeLsum_mid_f1 = rouge_results['rougeLsum'][1][2]
    print(f"ROUGE-1 F1 score: {rouge1_mid_f1:.5f}")
    print(f"ROUGE-2 F1 score: {rouge2_mid_f1:.5f}")
    print(f"ROUGE-L F1 score: {rougeL_mid_f1:.5f}")
    print(f"ROUGE-Lsum F1 score: {rougeLsum_mid_f1:.5f}")

    # 计算 METEOR 分数
    meteor_scores = [meteor_score(references=refs, hypothesis=pred) for pred, refs in zip(predictions_tokenized, references_tokenized)]
    average_meteor_score = sum(meteor_scores) / len(meteor_scores)
    print(f"Average METEOR score: {average_meteor_score:.5f}")

    # 计算 BERTScore 分数
    '''
    同样效果：
    bert_metric = load_metric("bertscore",cache_dir="/media/fenghe/New Volume/A2Q/Metric")
    bert_results = bert_metric.compute(predictions=predictions, references=references,lang="en",device=f"cuda:{torch.cuda.device_count() - 1}")

    设置 verbose=True 会使函数在计算过程中输出更多的信息，例如处理进度、当前正在处理的数据等。
    '''
    P, R, F1 = score(predictions, [ref[0] for ref in references], lang="en", verbose=False)
    average_bert_score = F1.mean().item()
    print(f"Average BERTScore F1: {average_bert_score:.5f}")

    return {
        "BLEU":B_S,
        "ROUGE":rouge_results,
        "METERO":meteor_scores,
        "BERTScore":{"Precision":P,"Recall":R,"F1":F1},
    }

# %%
with open('compare_work/DI_FT_alpaca_gen_0_2_20e.txt', 'r') as file:
    content = file.readlines()

# %%
refs = [ [i.replace('enquiry: ',"")] for i in val_dataset_t5['target_text']]

# %%
refs
# Out:
# [['Generate a simile comparing a sunset to fiction. '],
#  ['What is the leading cause of death for children under the age of 5? '],
#  ['Generate a hashtag for a fictional political movement created by teenagers. '],
#  ['Name three common validation techniques used in Machine Learning. '],
#  ['Assign an appropriate name to the following new species of butterfly. '],
#  ['Tell me something about a Nissan leaf. '],
#  ['Create a summary of the following text in no more than 4 lines. The effect of gun violence in the United States is widespread. According to the CDC, in 2018 there were 38,390 deaths due to firearm. Of these, 24,432 were suicides. The rate of firearm deaths per 100,000 people increased from 10.3 per 100,000 in 1999 to 12 per 100,000 in 2017.'],
#  ['Fill in the blank with an appropriate preposition: I like to stay ____ top of my work.'],
#  ['Compose an email to a potential client explaining the benefits of your service. '],
#  ['Provide an appropriate metaphor for the following situation. The sun is beginning to set against the horizon.'],
#  ['Create a design for a web page about local movie theatres '],
#  ['Generate an AI-generated Insult '],
#  ['Generate an appropriate response when an employee has tried his best to do a task but failed. '],
#  ['Find the verb in the sentence. He sometimes visits his grandparents.'],
#  ['Create ten multiple-choice questions about the topic of history. '],
#  ['Make a valid sentence using the words "quick," "brown," and "fox." '],
#  ['Suggest a title for an essay about the right to privacy. '],
#  ['Construct an analogy for the following sentence: "A computer is to code what a chef is to food." '],
#  ['What is the importance of using project management software? '],
#  ['Edit the following sentence to eliminate redundancy. The verdict of the court was unanimous in agreement.'],
#  ['What is the aproximate population of the UK? '],
#  ['Develop an algorithm that can recognize handwriting. '],
#  ['Write a story beginning with “He saw himself reflected in the mirror…” '],
#  ['Identify a cybersecurity risk that could affect an online store. '],
#  ['Generate an input data set that has three members and five attributes. '],
#  ['Name five dangers of space exploration. '],
#  ['Invent a computer gaming character that uses magic. '],
#  ['What are the key ingredients of Fajitas? '],
#  ['Identify which of these objects is not a mineral. Garnet, Gold, Ceramic'],
#  ['Tell me what the article below is about. The article is about the growth of artificial intelligence in healthcare.'],
#  ['Name two types of unsupervised learning. '],
#  ['Propose an alternative solution to the following problem: The current system of food delivery is inefficient and leads to wastage.'],
#  ["Identify the person in the following sentence. Output the person's name My brother likes to play football"],
#  ['Design a GPT model to generate a chatbot that helpsthe user find hotels in a certain city. '],
#  ['Rank the following items in order of relevance to the topic of artificial intelligence. Robotics, Machine Learning, Natural Language Processing'],
#  ['Take a complicated theory or concept, and explain it as simply as possible. The Catastrophe Theory'],
#  ['Create a research outline for a paper that examines the causes of poverty in the United States. '],
#  ['Give an example of a verb ending in -ed. '],
#  ['Write a jingle for an energy bar '],
#  ['Generate a list of US Presidents. '],
#  ['Write a comment for a given post "I\'m so excited for my graduation day!"'],
#  ['Sort these numbers from lowest to highest. 3, 2, 7, 5'],
#  ['Use the given information to create a multiple choice question. Person: Julius Caesar \nFact: Assassinated in 44 BC \nTime: Autumn 2020'],
#  ['Generate 5 tips on how to improve your public speaking skills. '],
#  ['Rearrange the given sentence to be an interrogative sentence. She moved to the United States two years ago.'],
#  ['Rewrite the given sentence with fewer words but not sacrificing any information from the original sentence. We have to make sure that every single person follows the safety regulations.'],
#  ['Categorize the phrase under the appropriate labels. Hurricanes'],
#  ['Create two authentic Thai dishes. '],
#  ['Analyze similarities and differences between two arguments. Argument A: We should tax the wealthy to help fund social programs.\nArgument B: All citizens should pay the same amount in taxes regardless of their income.'],
#  ['Suggest a question to ask in a job interview. '],
#  ['Provide the output of code that completes the given matrix with the sum of each row. matrix = [[1, 2, 3], \n          [2, 3, 4], \n          [3, 4, 5]]'],
#  ['Translate the following sentence into French:\n"We had a great time" '],
#  ['Create a blog post of 300-400 words discussing the benefits of a healthy lifestyle. No Input'],
#  ['Describe the significance of the Crick–Watson model. '],
#  ['Predict the possible outcomes of the following situation. A student studying for an important exam has to decide between going to bed early or staying up late to study.'],
#  ['Design a workflow for a machine learning system to analyze customer sentiment on social media. '],
#  ['Generate a musical arrangement that includes melodic lines, chords and accompanying instruments. '],
#  ['Name five famous companies that are famous for their customer service. '],
#  ['Select a topic to write an essay about. '],
#  ['Create a marketing campaign to promote a new food delivery service. '],
#  ['Name one major feature of an eagle. '],
#  ['Group the words according to their part of speech. Strong, long, apple'],
#  ['Create a list of the differences between quantitative and qualitative data. '],
#  ['Given the following sentence, make a sentence that uses a specific literary device. The river was raging.'],
#  ['Construct a numerical series where each number is the sum of its two predecessor numbers. '],
#  ['Below is a text, correct the grammatical errors. Globle warming are bothering us.'],
#  ['Design an algorithm to remove duplicates from a given array. '],
#  ['Change the following sentence so that it no longer contains the modifier "very". She is a very nice person.'],
#  ['List three elements of a successful brand. '],
#  ['Describe the meaning of the phrase "carpe diem." '],
#  ['List all the even numbers from a given array [1, 2, 3, 4, 5, 6]'],
#  ['Name some computer viruses '],
#  ['Generate a recipe for making a vanilla milkshake. '],
#  ['Name three factors that could cause the rapid melting of sea ice in the North Atlantic Ocean. '],
#  ["Rewrite the following paragraph to make it sound more formal. Moving away from home to college was really hard. It's like I had to let go of my comfort and safety and figure things out on my own."],
#  ['Reword the sentence by changing its tense to the past. The driver carefully turns the corner.'],
#  ['Display the sentiment of the statement The movie was terrible.'],
#  ['Analyze the following quote: "Life is what you make it." '],
#  ['Generate a list of 5 popular songs from the 1990s. '],
#  ['Compose a news article about the latest tech advancements '],
#  ['List 5 tips for improving public speaking skills. '],
#  ['Give an example of a time when an animal displayed an act of heroism. '],
#  ['Identify two potential interpretations of the sentence. I said goodbye to my parents.'],
#  ['Spell out the given word in 3 different ways. Receive'],
#  ['Write an imaginary dialogue between a doctor and a patient '],
#  ['Give an example of an active sentence using the verb "give". '],
#  ['Generate a story based on this context Once upon a time, there was a brave knight who had a magical sword that could slay any monster.'],
#  ['Generate a dialogue between two customers arguing about price. '],
#  ['Modify the sentence to include the phrase "in addition". He went for a run, took a long walk.'],
#  ['What is the gerund of the verb "run"? '],
#  ['Find and replace all misspelled words in the sentence. We need to acomplish this tusk by end of day.'],
#  ['Classify the following as a concrete or abstract noun. ruthlessness'],
#  ['What type of clothing is required for cold weather? '],
#  ['Reverse engineer a solution for the given problem. How to minimize wait times in customer service?'],
#  ['Compare and contrast the two styles of writing: writing for outdoor media versus writing for academic purposes. '],
#  ['Describe a person called Tom. '],
#  ['Find the range of numbers 25, 28, 30, 33 '],
#  ['Name two applications of trigonometric functions in real life. '],
#  ['Find a suitable title for the poem. He is the only one\nToo much to him I owe\nHis grace more sweet than honey\nHis face the gentlest glow'],
#  ['Generate a funny pun about the internet. '],
#  ['What are four ways to save money? '],
#  ['Write a news article about a new product. Product: Smart Car'],
#  ['Generate a list of 10 ways to be kind to the environment. '],
#  ['Generate a creative idea for an aquarium. '],
#  ['Analyze the below social media post and identify the most effective marketing strategy used. ![Social Media Post](https://i2.wp.com/techwood.in/wp-content/uploads/2020/06/Spinny-Feat1.jpg?fit=1080%2C810&ssl=1)'],
#  ['Pick the antonym of the following word. Fate'],
#  ['Classify the major cities in Japan. Tokyo, Osaka, Yokohama'],
#  ['Given a sentence, output the number of vowels and the number of consonants. She had to decide what to do.'],
#  ['Write a step-by-step procedure to make chocolate chip cookies. '],
#  ['Analyze the label of the alcohol and tell what the bottle contains. Label: an Irish Whiskey with a smooth finish.'],
#  ['Rewrite the given paragraph in a shorter, easier to understand form. Although it is generally accepted that the internet has allowed us to connect with people all over the world, there are still those people who are not familiar with its basic functions, who don’t understand why it has become so commonplace, or what its true capabilities are.'],
#  ['Name a Harry Potter character. '],
#  ['You must come up with a character for a film. '],
#  ['Write a response to a customer who is complaining about the wrong delivery. We received a wrong delivery and need the correct item ASAP.'],
#  ['Generate a properly formed question based on the given sentence. She had a difficult journey.'],
#  ['Name one disadvantage of using a credit card. '],
#  ['Explain why cell phones are useful. No input.'],
#  ['Give a critique of this poem. I am a poet\nof life and of light\nIn my words I must strive\nto make a lasting impression.'],
#  ['Generate a creative product description of a <mask>. Make sure to include the features and benefits of the product. Bluetooth Headset'],
#  ['Identify the use of language She screamed in terror'],
#  ['Find the element present in both of the given lists: List A: [2, 5, 10] \nList B: [3, 6, 9]'],
#  ['Name one artist from the 20th century. '],
#  ['Create a new word that has the following attributes: 1. verb, 2. can be used in everyday conversation, 3. consists of 4 letters '],
#  ['Edit the following sentence to make it grammatically correct: "The patient had to put on a ventilator to surgery" '],
#  ['Construct a persuasive letter to persuade a school to reduce their fees '],
#  ['Find ways to improve the following code snippet. def leap_year(year): \n    if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0: \n        return True \n    else: \n        return False'],
#  ['Synthesize an argument in support of renewable energy sources. '],
#  ['Assign a category to the given list of words. food, furniture, books'],
#  ['Come up with 10 math terms and their respective meanings '],
#  ['List the different forms of energy. '],
#  ['Compare the differences between the effects of the pandemic on traditional retail and online retail '],
#  ['Suggest a 5-star restaurant for the following group: a vegetarian and two meat-eaters. '],
#  ['Give an example of a country located in South America. '],
#  ["Eliminate the double negative in the following sentence I can't not go"],
#  ['Describe how the author uses imagery. The lion roared so loudly that it shook the ground.'],
#  ['Share two tips on how to write concisely. '],
#  ['Generate a list of five characteristics of an ideal leader. '],
#  ['How would you encourage someone to try something new '],
#  ['Explain why a country may use tariffs '],
#  ['Edit the given text so that it follows APA formatting style. Writting in the APA style is important in order to make sure that your work is correctly documented'],
#  ['Create a song title that fits the given theme. Summer'],
#  ['Create an equation to represent a linear trend. '],
#  ['Suggest an alternative to using plastic bags. '],
#  ['Identify the figures of speech used in the given text Life is going to hit you hard'],
#  ['Classification Task - Classify the following piano piece as classical or jazz genre. https://www.youtube.com/watch?v=hPUTzyOyfN4'],
#  ['Design a logo for an app related to budgeting '],
#  ['Create a classifcation model to determine whether a given mammal is a carnivore or an herbivore. Fennec Fox'],
#  ['Find an example of a web page that includes an account creation form. '],
#  ['Determine if the following numbers are prime or not. Output 1 for prime, and 0 for not prime. 19'],
#  ['Analyze a given dataset and describe the insights from it. Dataset: Weather Temperature variations over the past month'],
#  ['Design an interface for a new productivity app. '],
#  ['Describe how a specific character participates in the climax of a novel. Harry Potter in "Harry Potter and the Deathly Hallows"'],
#  ['Sort this list from shortest to longest. Giraffe, Chimpanzee, Kangaroo, Gorilla'],
#  ['Write a 500-word article summarizing the challenges associated with developing self-driving cars. '],
#  ['Generate a tweet promoting a vegan lifestyle '],
#  ['Given the following chart, explain the trend it is showing <image of a chart showing a trend>'],
#  ['Tell me what type of diet the following statement is referring to. "I\'m aiming to eliminate processed food, animal sources of saturated fats, and dietary cholesterol from my diet."'],
#  ['Suggest me a way to save money on a family vacation. '],
#  ['Generate a limerick that rhymes with the given word. Fox'],
#  ['Please provide a brief explanation of the differences between a deep learning algorithm and a traditional machine learning algorithm. '],
#  ['Name a professional organization that a software engineer would be interested in joining. '],
#  ['Given an ingredient, provide a recipe that can be prepared with the ingredient. Eggs'],
#  ['Evaluate the given website. https://example.com'],
#  ['Write a summary of the article "The Impact of Social Media on Student Stress". '],
#  ['What scientific evidence is there that laughter is beneficial to our health? '],
#  ['Turn this paragraph into a story. John woke up early to a beautiful sunny day. He got out of bed, put on his sneakers, and grabbed his backpack. He was excited to explore the forest he had been dreaming of for months.'],
#  ['Change the text formatting of the following sentence to make it easier to read. Thestudenthadacomplexproblemtocomplete'],
#  ['Categorize the following restaurant as being a fast-food restaurant or a classic restaurant. It is a small restaurant that serves Mexican food.'],
#  ['Given a piece of text, identify the tense used. I would like to have a meeting today.'],
#  ['Write a letter to persuade the reader to do something. Conduct a research project'],
#  ['Explain what a blockchain is and its benefits '],
#  ['Given a list of countries, find the ones with the lowest population. India, Brazil, Mexico, China, Germany'],
#  ['Given the phrase, rephrase it without changing the original meaning. "Don\'t count your chickens before they hatch"'],
#  ['What food is New York famous for? '],
#  ['Say two sentences that could go in an email to a customer who has a complaint. '],
#  ['Categorise the following word: "Aliquippa". '],
#  ["Rewrite the following sentence in a more fluent way: “I ran away, so the monster won't catch me” "],
#  ['Given a list of materials, come up with a plan to build a table. Materials: Wood, paint, glue, nails, screws'],
#  ['Convert 179 centimeters to feet. 179 centimeters'],
#  ['How can we increase the engagement rate of emails? '],
#  ['Edit the following sentence: "Joanna loves to to go swimming." Joanna loves to to go swimming.'],
#  ['How many gigs are in a terabyte? '],
#  ['Name a popular product manufactured by Apple. '],
#  ['Generate an original sentence that begins with “If only". '],
#  ['What is the best way to play an E chord on a guitar? '],
#  ['Name a common chess opening move. '],
#  ['Name three tropical birds. '],
#  ['Write a snippet of code to find the largest number in the array. [1, 5, 7, 18, 24, 32]'],
#  ['Write a step-by-step guide on how to backup and restore a database. '],
#  ['Find a title for a book discussing environment protection. '],
#  ['Generate a password containing 8 characters with one number and one special character. '],
#  ['Analyze what themes are present in the text below: Every summer, our family would make the eight-hour drive from Atlanta to Corpus Christi, Texas. We would stay in a rustic guest house with nothing more than the sound of the wind and the tide. Every morning, my grandmother would take me to the beach, and while the sun rose over the horizon, I would dig my toes into the sand and make sandcastles with my siblings.'],
#  ['Describe what intelligence is and its role in psychology. '],
#  ['How would you explain the concept of natural language processing (NLP) to a 6th grader? '],
#  ['Create a list of tasks that should be done to prepare for a long camping trip. '],
#  ["Choose the better summary of the given context from the given two summaries. Context: Several icecaps on the Greenland ice sheet have started to melt rapidly.\n\nSummaries:\na. The Greenland ice sheet has lost numerous icecaps over time.\nb. Greenland's icecaps are quickly melting away."],
#  ['Describe the ideal workspace '],
#  ['Create a recipe for mashed potato pancakes. '],
#  ['Describe a difficult situation that you have faced and how you worked to overcome it. '],
#  ['Find and identify a historic landmark in the US. '],
#  ['Given a set of equations, solve them 2x + 7y = 5\n3x - 7y = 5'],
#  ['Reflect the following matrix about the vertical axis. [[1, 2], [3, 4]]'],
#  ['What are the differences between the terms "agent" and "organization"? '],
#  ['Classify the following items as clothing, food, and toys: shirt, banana, doll. '],
#  ['What can I do to reduce the costs of hosting a website? '],
#  ['Research the regulations for motor vehicle emission standards in California. '],
#  ['Describe the story based on the given description. Description:\nAn old man lives a simple life in a small, remote village in the mountains. He is a recluse who mostly keeps to himself but loves to visit the nearby forest every day.'],
#  ['Generate a movie quote using the following words: adventure, destiny, courage. '],
#  ['Create a list of activities for hosting a virtual scavenger hunt '],
#  ['Solve the following equation 2x+5=7'],
#  ['Summarize an article titled "Advantages of Owning a Pet" '],
#  ['Come up with a list of ways to reduce carbon footprints. '],
#  ['Estimate the number of African countries that have ratified the African Charter on the Rights and Welfare of the Child. '],
#  ['Find an appropriate response for the following question: What is the best way to make new friends? No input'],
#  ['Create an algorithm to arrange a set of numbers from lowest to highest [3,7,2,4,9]'],
#  ['Generate a fun fact about the cuisines of Thailand. '],
#  ['Please write a brief description of what stress is and how it can affect an individual. '],
#  ['Describe a home kitchen '],
#  ['Brainstorm 5 keywords related to the following article In this article, we will explore the concept of online privacy.'],
#  ['Reword the following sentence making it shorter and more punchy. We are looking for food delivery services in the region that offer reasonably priced meals.'],
#  ['Generate a list of five topics for discussion for a group of teenagers. '],
#  ['Write a lesson plan for teaching basic coding. '],
#  ["Summarize the given text in 1 sentence The Mediterranean Sea is a sea located between Europe, northern Africa, and the Middle East. It is connected to the Atlantic Ocean through the Strait of Gibraltar and to the Red Sea through the Suez Canal. It is bordered by a number of nations, including Italy, Spain, Greece, France, Turkey and Spain. The Mediterranean Sea is known for its warm climates and its diverse marine life, with some of the world's most popular beaches located in the area."],
#  ['Generate an argument for or against the use of robots in the workplace '],
#  ["Given a sentence, classify the sentiment in the sentence as 'Positive', 'Negative' or 'Neutral'. Sentence: I have had a wonderful day."],
#  ['Rewrite the formula $y = \\frac{2x-1}{3}$ so that it can be solved for x. '],
#  ['Re-write the following sentence omitting the word "comfortable". We were quite comfortable with our decision.'],
#  ["Write a code to output a word pyramid from the word 'apple.' "],
#  ['Calculate the length of an arc with the following parameters. Angle of arc = 90°\nRadius = 5m'],
#  ['Why is it important to eat healthy food? '],
#  ['Propose a plan to reduce air pollution in urban areas. '],
#  ['Why is Python a good language for data science? '],
#  ['Create a brand name which stands for a product. Product: Laptop'],
#  ['Classify the following sentence according to their emotions: I am so pleased with you. '],
#  ['Group the following words according to their type. Output a list with the groups.\n1) Noun; 2) Adjective; 3) Verb happy, dog, barking'],
#  ['Explain the historical significance of the Cuban Missile Crisis. '],
#  ['Give a health-related tip '],
#  ['What data should I collect to calculate market share? '],
#  ['Classify a set of data as valid or invalid. Apple, Amazon, Google'],
#  ['Complete the sentence by providing an appropriate word. She was wearing a ____ dress.'],
#  ['Create a couplet about the joy of being together '],
#  ['Develop a plan to reduce electricity usage in a home. '],
#  ['What is the average annual salary for a customer service developer? '],
#  ['Add two numbers together. 25 + 45'],
#  ['Automatically generate a logo given the following business name and design guidelines. Business Name: Awesome Cafe\nDesign Guidelines: Abstract design with an emphasis on vibrant colors.'],
#  ['Remove any unnecessary words from the following sentence to make the sentence concise: I believe that it is important to be kind to others.'],
#  ['Why is preserving animal habitats important? '],
#  ["Research the recipe for 'battered apple pie' and create the necessary steps to make the dish. "],
#  ['Create a riddle using the following numbers: 16, 20, 27 '],
#  ['Describe a rescue mission in space. '],
#  ['Create a grocery list based on the ingredients mentioned below: flour, eggs, sugar, butter, parsley'],
#  ['Construct a flow chart for a process. Completing a survey'],
#  ['Generate a set of guidelines to follow when using this tool. No input'],
#  ['Compose an email about the topic of your choice '],
#  ['Compare and contrast the two different communication methods, email and telephone. '],
#  ['Write a story that begins with "It was a cold, dark night". '],
#  ['First categorize the following products as entry level, mid-level, or high-end. Apple watch series 5'],
#  ['List the points that the speaker should cover in the presentation on the given topic. Topic: The Role of Artificial Intelligence in Business'],
#  ['Edit the following sentence to make it more concise:\n\nThe experiment demonstrated that the bacteria survived in higher temperatures. '],
#  ['Rewrite the following sentence in the present tense and make it a command The user had to confirm their email address.'],
#  ['Generate a list of possible solutions for the given situation. My computer just crashed and I lost all my family photos.'],
#  ['Rewrite this sentence to make its meaning more concise Vacations are very important in helping people to destress from their everyday lives.'],
#  ['Generate a formal apology letter from a company towards a customer. Dear [person name],\n\nWe regret to inform you that due to some delays in shipment, we were unable to deliver your order on time.'],
#  ['Output the musical artist of the following song: Song: "Teardrops"'],
#  ['Classify the given text into a given field. Relativity Mathematics'],
#  ["What advice would you give to a person who's starting a business? "],
#  ['Generate a three line poem with the rhyme scheme "AAB". '],
#  ['Identify the two words that rhyme with "flame". '],
#  ['Generate a mission statement for a non-profit organization focused on animal welfare. '],
#  ['Generate a convincing argument in favor of the given statement. Video games should be treated like any other form of art.'],
#  ['Describe the core features of a general-purpose programming language. '],
#  ['List three common symptoms of a cold. '],
#  ['Suggest a list of 5 skills that a person should learn to succeed in a job. '],
#  ['Ask the assistant to click a certain link on a website. The link is https://example.com'],
#  ['Describe the best approach to manage a conflict between two individuals. '],
#  ['Explain what is a feature vector. '],
#  ['Reword the following sentence in a simpler form: "We have reached a point where we can no longer live in darkness". '],
#  ["Could you summarize this article about art therapy in three sentences? Art therapy is an innovative treatment approach that uses creative activities to address psychological issues. It's based on the idea that creating art can help individuals process and understand their emotions, navigate difficult times, and foster personal growth and development."],
#  ['Which type of resource does the following sentence describe? More people are employing video conferencing to stay connected.'],
#  ['Please provide some tips for writing a good blog post. '],
#  ['Point out the errors in the following sentence: “He borrowed hers pencil.” '],
#  ['In one sentence, summarize what the paragraph is about. A new study shows that the use of problem-solving strategies can help children learn to better manage challenging emotions.'],
#  ['List the steps to build a chatbot '],
#  ['Write a news report about the latest technological advancements. '],
#  ['Identify 3 differences between data science and artificial intelligence. '],
#  ["Rewrite the sentence to use the same vocabulary: I'm not pleased with the decision. The decision displeases me."],
#  ['Generate a product security policy following best practices. '],
#  ['Suggest a plan of action to handle a customer complaint about a defective product. '],
#  ['Name five ways to stay safe online. '],
#  ['Write a short story featuring a farmer, a lion and a mouse '],
#  ['List 4 characteristics that make a successful entrepreneur. '],
#  ['Describe the trajectory of a rocket given the following information. The rocket was launched vertically with an initial velocity of 120 m/s.'],
#  ['Provide a humorous response to the question "Why did the chicken cross the road?" '],
#  ['Predict the future trend in Natural Language Processing. '],
#  ['Generate a script for a commercial that promotes an animal adoption center. '],
#  ['Generate questions of the form "What is/are [X]?" '],
#  ["Predict whether the given review is positive or negative. Output 'positive' or 'negative'. This restaurant has great service and delicious food."],
#  ['Automatically trim a given phrase phrase: "The quick brown fox jumps over the lazy dog"'],
#  ['Write one sentence about handwashing. '],
#  ['Write an opinion of this photo. [Photo of a bridge in the forest]'],
#  ['Given a scenario, generate 5 possible solutions John and Sarah are struggling to manage a team of people with varying skill levels.'],
#  ['List 4 methods for dealing with the curse of dimensionality. '],
#  ['List three use cases for GPT-3. '],
#  ['Why is it important to get enough sleep? '],
#  ['Write a narrative for the given situations. Situation: Bob has a long and difficult road ahead of him.'],
#  ['Convert 23 kilograms to pounds 23 kilograms'],
#  ['Read the passage of text below and answer the question, who is being addressed by the speaker? "You have to make a choice, between your dreams and your family. You have to choose one or the other."'],
#  ['Generate a short story of maximum 100 words involving a king and a dragon. '],
#  ['Describe the impact of artificial intelligence on personal privacy. '],
#  ['Create a valid JSON string from the following: name: Joe Smith\nage: 33\noccupation: Software Developer'],
#  ['Generate a sentence containing the words cheerful and frog. '],
#  ['Write 3 ingredients for a cake. '],
#  ['Generate a sentence about going for a run. '],
#  ['Make recommendations for budgeting for a couple vacationing in Hawaii '],
#  ['Compose a five word sentence describing your day. '],
#  ['How can climate change be prevented? '],
#  ['Edit the following sentence so that it is grammatically correct: "The workers unions went to the negotiations with high hopes." '],
#  ['Give a logical conclusion to this story. John left home in a hurry to catch the bus but when he arrived, the bus had already left. He was overwhelmed and did not know what to do next.'],
#  ['Create a unique hashtag that promotes a positive message. '],
#  ['Identify the perspective of the speaker in the given statement The quality of this service was unacceptable'],
#  ['Give a short description of the effects of global warming. '],
#  ['Describe an unusual vacation spot. '],
#  ['Give me a one-sentence summery of the benefits of playing football. '],
#  ['Categorize the following words under the given categories. Sleep, Sofa, Chair\n\nCategories: Furniture, Human Activity'],
#  ["Create a bar chart to show the correlation between age and education level. Data: \n\nAge: 25, 30, 35, 40 \n\nEducation Level: High school, Bachelor's, Master's, Doctoral"],
#  ['Formulate a question about the concept of free will. '],
#  ['Create a speech that explains why everyone should recycle. '],
#  ['Generate 5 similes about a summer day '],
#  ['Output a summary of the paragraph. Powerful and yet surprisingly easy to use, cloud computing has revolutionised business practices, offering businesses a wide range of scalable services that are delivered effortlessly over the internet. It has become increasingly popular in recent years due to its low cost and scalability, its scalability making it ideal for businesses of any size. Additionally, cloud computing provides a variety of resources and applications that can be used for tasks ranging from data analysis to customer management.'],
#  ['Create a classificaiton task by adding two labels My cat is'],
#  ['Brainstorm 5 ways to reduce waste in an office. '],
#  ['Find an example of a company using ML for automated customer service '],
#  ['Given a product or service, explain why consumers would prefer it over another similar product or service. Netflix VS Hulu'],
#  ["Develop a hypothesis for the following experiment. Studying the impact of food coloring on children's behavior"],
#  ['Provide an example of an ethical issue related to Artificial Intelligence technology. '],
#  ['Predict a consequence of the following action. Bringing guns to school'],
#  ['Evaluate the following statement: "The internet will replace physical stores." '],
#  ['Name the capital of India '],
#  ['Analyze an existing story and come up with an alternate ending. The story is about a group of teenagers in search of a lost treasure.'],
#  ['List five famous people from India. '],
#  ['Identify the type of sentence used in the following example:\n\nShe went to the store, but forgot to buy milk '],
#  ['Classify the given sentence as ironic, metaphorical, or literal. "It is raining cats and dogs outside."'],
#  ['Name a popular book in the fantasy genre '],
#  ['Give two examples of how technology can improve education. '],
#  ['Provide three adjectives that describe the personality of a police officer. '],
#  ['Create a quiz about the solar system. '],
#  ['Create a function to find the closest number to a given number. num = 10, list = [3, 5, 7, 8, 11, 16]'],
#  ['Compose a tweet with the following words: Protest, Equality, Autonomy '],
#  ['Answer the following question in an essay format. What are the positive and negative effects of technology in our society?'],
#  ['Outline the process for registering to vote in your state. '],
#  ['Identify the part of speech of the underlined word in the following sentence:\n\nYesterday, he sang a very beautiful song. very'],
#  ['Given a customer review, classify if the review is positive or negative. This is by far the worst product I have ever used.'],
#  ['Find all the examples of hyperbole in the text. The new dress was so beautiful it seemed to defy the laws of physics. It was the most impressive thing my eyes had ever seen!'],
#  ['Tell me any 5 major human rights organisations with their countries. '],
#  ['Analyze the following data and explain the trends. The monthly revenues of a business over the last 10 months were: [7500, 7200, 9000, 8700, 7500, 8500, 10000, 8900, 8600, 10000].'],
#  ["Provide a mathematical explanation for fermat's last theorem. "],
#  ['Compare the themes of the following two poems. Poem 1\n"Heed my call, heed my warning\nNo one is of any use when they are mourning"\n\nPoem 2\n"Strike with haste, time to flow\nTake a deep breath and make it so"'],
#  ['Automatically generate a headline given an article. Deep learning promises improved medical imaging performance'],
#  ['Construct an argument against the commercialization of sports. '],
#  ['What are some potential challenges of online learning? '],
#  ['Describe the environmental impact of continuous flying '],
#  ['Summarize the story of Snow White and the Seven Dwarfs. '],
#  ['Illustrate the main concept of a given story. A story about a mermaid who discovers land'],
#  ['Generate an appropriate response to an angry customer. Customer: Your customer service is terrible!'],
#  ['Create 3 conversation topics for a business meeting with the given client. An investment firm'],
#  ['How do you write a for loop in Java? '],
#  ['Suggest an AI based system that can be used in marketing. '],
#  ['Describe the production process of an autonomous vehicle. '],
#  ['Describe the experience of being in Flagstaff, Arizona '],
#  ['Identify four uses of artificial intelligence in healthcare. '],
#  ['Create a password for email that includes 8 characters. '],
#  ['Explain the difference between generative and discriminative models. '],
#  ['List the 12 planets of the Solar System '],
#  ['Generate five questions to ask an expert in a given field. Machine Learning'],
#  ['Re-write the following sentence to have a different meaning: "I ate the apple." '],
#  ['Cite three sources on the effects of plastic waste on the environment. '],
#  ['Estimate the velocity of a car given its distance from start point and time spent travelling. Distance = 50 meters, Time = 10 seconds'],
#  ['Take a statement from the given text and turn it into an interrogative sentence. John loves to read books.'],
#  ['Reduce the following fraction. 6/3'],
#  ['Name a country that has the longest coastline '],
#  ["How would you explain the definition of 'time series data' to non-technical people? "],
#  ['Given two similar products, create a comparison table that highlights the differences between them. Product A: Lenovo Laptop\nProduct B: MacBook Pro'],
#  ['Identify at least three components of a standard computer system. '],
#  ['Is the following statement true or false? People in China make the most of their allowances. None'],
#  ['Find the elapsed time between 12:00 AM on 3 July 2018 and 12:00 PM on 4 July 2018. '],
#  ['Generate a list of 8 social media platforms. '],
#  ['Create a story starting with the sentence: "The day was brighter than usual". '],
#  ['Give an example of a creative way to use GPT models. '],
#  ['Determine the missing numbers in the sequence. 2, 4, 8, __, 16'],
#  ["Generate a definition for 'robot'. "],
#  ['Develop a chatbot that answers common questions related to air travel. '],
#  ['Tell me what is the best kind of food for a party. '],
#  ['Write a poem with four lines and the given words. universe, star'],
#  ['Analyze the given poem and rewrite it with a new title and an altered tone. Title: "Lost"\n\nI stare out into the void,\nSearching for a life I never employed.\n\nMy path is a long, sad descent,\nWords mean nothing as I relent.'],
#  ['Choose the best password for a given service. Online banking'],
#  ['Generate a list of tools that a person can use to quickly get started with a web design project. '],
#  ['What is the result of multiplying 87 and 183? '],
#  ['Using the facts given, generate a story about a character. Name: Jane Smith\nGender: Female\nAge: 32\nLocation: New York City\nOccupation: Public Relations Officer'],
#  ['What is a workable marketing plan for my small business? My small business offers web design services.'],
#  ['Determine the main idea of the sentence, output the main idea. Electronic books often have more interactive capabilities than physical books.'],
#  ['Given a sentence, convert it from present tense to future tense. He is eating his dinner.'],
#  ['Please fill in the short story prompt with a suitable sentence. Every day, he would go to the ocean'],
#  ['Make a list of 5 trendy fruits for a smoothie. No input.'],
#  ['Explain a quick and easy way for a person who is new to programming to get started. '],
#  ['Rewrite a sentence to take out its negative tone. It is impossible to make money online.'],
#  ["Language models often err in understanding the difference between 'your' and 'you're'. Therefore, given the sentence below, edit it to resolve this ambiguity. Your wrong about that"],
#  ['Create a short story of 4-5 sentences based on the following facts. Setting: Mountain\nProtagonist: Fisherman\nAntagonist: Shark'],
#  ['Classify the following into mammals and non-mammals. Dog, chicken, horse, cat'],
#  ['Determine the sentiment of the headline. Apple and Samsung succeeded in launching a new groundbreaking product.'],
#  ['Change the underlined words from present tense to past tense. She walk along the shoreline.'],
#  ['Automatically format the given text. Using the right tools,you can achievebetter results'],
#  ['Replace the following broken link with a working one. The link is https://www.example.com/page'],
#  ['Construct a valid argument. Multiple scientists have confirmed the existence of climate change, but some politicians deny it.'],
#  ['Explain the concept of biodiversity and its importance? '],
#  ['Make a list of 5 verbs in the past tense. '],
#  ['Make a chart that displays the data in a visual format. Data: The number of students in different grade levels'],
#  ['Please provide a detailed argument for or against the death penalty. '],
#  ['What is a recurring deposit account? '],
#  ['Create a keyword list of the given text With the cost of living continuing to rise and the cost of renting increasing steadily, many people are looking to buy their own home as an investment'],
#  ['What impact does climate change have on humans? '],
#  ['Generate three new ideas based on the following initial idea. Online school'],
#  ['Describe the flavor profile of a certain type of wine. Zinfandel'],
#  ['Develop a story with a moral about animal conservation. '],
#  ['Write a haiku poem describing the following nature scene. The sun is rising over a dense forest'],
#  ['Make up a sentence given the input sentence with at least 10 words. I love dogs'],
#  ['Create a list of skills required to become a software engineer. '],
#  ['Make a list of three items a photographer needs for a photo shoot. '],
#  ['Write a function to filter a list by items that contain a certain string. list = ["apple", "orange", "banana", "watermelon", "cherry"]\nstring = "an"'],
#  ['How did the fossil fuel revolution change the course of history? '],
#  ['Explain two effects of climate change on the environment '],
#  ['Given the following statement, classify it as true of false. The Earth is the only planet in the solar system with water.'],
#  ['Generate a formal email body with a meeting invitation. Topic: Business Proposal\nTime: Tuesday 5 pm\nLocation: Zoom Meeting'],
#  ['Explain what a Turing Test is. '],
#  ['Name two organic compounds that are widely used in medicine. '],
#  ['Give examples of three programs that are used for data wrangling. '],
#  ['Motivate someone to finish an assignment. '],
#  ['Predict the weather for the next 3 days in your city. City: Los Angeles'],
#  ['Explain the difference between a linear and a nonlinear equation. '],
#  ['Select the best website to buy a laptop. '],
#  ['Provide a list containing five adjectives to describe an elephant. '],
#  ['Compose a letter to a friend describing a recent vacation '],
#  ['Answer the following question: Why is the Sun so hot? '],
#  ['What is the mileage rate for business expenses in the United Kingdom? '],
#  ['Generate two alternative ways to say the same thing. I slept for 10 hours last night.'],
#  ['Give the chemical symbol for Carbon '],
#  ['Name the main characters in the Star Wars franchise. '],
#  ['Given a list of items, reorder them according to some criterion. Blueberries, Bananas, Apples, Oranges'],
#  ["Rewrite the following sentence so that it is a good example of effective communication. It was a hard decision to make, but I'm glad it's done."],
#  ['Rewrite this statement in the active voice. The award was won by Bob.'],
#  ['Write a description of a typical summer day in the countryside. '],
#  ['Provide an example of a product designed for convenience. '],
#  ['Name three items sold at a convenience store. '],
#  ['Write a newspaper headline that sums up the current presidential election. '],
#  ['Generate a new sentence that uses all the words from the given sentence in the same order. I went to the store to buy some apples.'],
#  ['How many legs does a spider have? '],
#  ['Generate a story that includes a stingray, a lion and a parrot. '],
#  ['Create a complimentary closing for a formal letter. '],
#  ['Given the following data, generate a direct marketing message Customers: Female movie goers'],
#  ['How can we measure the impact of a change in online user behavior? '],
#  ['Given the parameters of the user, write a query to select a suitable car. The user is looking for an economical, used car with a seating capacity of 5.'],
#  ['Given a business scenario, create a list of solutions. A new cafe with limited resources.'],
#  ['Using the provided ingredients, come up with a recipe. Carrots, celery, onions'],
#  ['Create a plan to prevent data loss. '],
#  ['What is the term for the structural pattern of haiku? '],
#  ['Design a t-shirt with a funny slogan. '],
#  ["Develop an algorithm to solve a Rubik's cube in the fewest moves possible. "],
#  ['Tell me one positive aspect of the current world. '],
#  ['Create an algorithm to detect spam emails. '],
#  ["Compare and contrast the Earth's four layers. "],
#  ['Generate a story about two friends who become rivals. Noinput'],
#  ['Classify a given object into the appropriate category. Crocodile'],
#  ['What are some misconceptions about natural language processing? '],
#  ['Identify a company that provides cloud computing services. '],
#  ['Generate a poetic sentence, with a rhyme, describing the beauty of a sunrise. No input'],
#  ['Write a script for an advertisement promoting a product. The product is a newly launched line of organic produce, grown with sustainable farming techniques.'],
#  ['Design a customer loyalty program for online shoppers with the given information. Target Audience: Millennial shoppers'],
#  ['Write a survey question to investigate the attitudes of people towards a certain issue. attitudes towards gender equality'],
#  ['Outline the steps for creating a web page '],
#  ['Rewrite the given sentence as an assertion in less than 10 words. The theory of evolution explains the diversity of life on earth.'],
#  ['Come up with a domain-specific metaphor to explain how a computer works '],
#  ['Given the following input, write a persuasive argument. Health benefits of regular exercise'],
#  ['Suggest a snack that you can make in under 5 minutes. '],
#  ['Give an example of a recipe involving an apple. '],
#  ['What is the main component of hydrogen peroxide? '],
#  ['Come up with a fun exercise activity. '],
#  ['Write a 10-word bio for the person in the input. John is a computer science student from the US.'],
#  ['Describe a hypothetical event in the future. '],
#  ['Describe the painting using 3 adjectives. [painting.jpg]'],
#  ['Generate a positive message about nature. '],
#  ['Generate a new board game idea. '],
#  ['Categorize this given text into “Positive” or “Negative” The software was buggy and kept crashing'],
#  ['Write a 5-line script for an engaging conversation '],
#  ['Where does the human body get energy from? '],
#  ['Given a sample of text, edit it to make it more concise while preserving the content. The large screens that you can purchase these days are good for watching movies and playing games on, but they can also be great for efficient productivity.'],
#  ['Design a classification model for sentiment analysis of movie reviews. '],
#  ['Design an experience for a customer portal. '],
#  ['Edit the following sentence to include the term "big data". The application of machine learning techniques can help us better understand our world.'],
#  ['List two benefits of using design thinking. '],
#  ['Come up with some possible topics for a research paper '],
#  ['Describe techniques to optimize web content '],
#  ['Find two solutions to this math problem 2x + 6 = 16'],
#  ['Construct a news headline using the adjectives excited, little, and fabulous. '],
#  ['Generate a speech to encourage people to stay environmentally friendly. '],
#  ['Create a function to calculate the standard deviation of a set of numbers. '],
#  ['Calculate the gross pay for the following person. Michael works 40 hours in a week and his hourly rate is $18.'],
#  ['Categorize the given information as qualitative or quantitative. The opinion of the public on the new mayor.'],
#  ["Correct the following paragraph and make grammatical changes. The current plan of action isn't working. We needs to try a  different approach."],
#  ['Implement a program to reverse a string. '],
#  ['Produce a list of the top 5 NHL players in 2021. '],
#  ['How would you create a website similar to Reddit? '],
#  ['Name two common cable TV companies in the United States. '],
#  ['Generate a recipe for a chili con carne dish. `<noinput>`'],
#  ['Re-order the words of the following sentence to create a grammatically correct sentence. often very different answers the same question'],
#  ["Name the figure of speech in the given sentence The prime minister proudly declared 'I am the leader of this nation'"],
#  ['Generate a computer program to calculate the area of rectangle '],
#  ['Write a Java program to implement a simple calculator. '],
#  ['Describe how this algorithm works Selection Sort'],
#  ['Make up a sentence with the word "Omnipresent". '],
#  ['Correct spelling mistakes in these sentences:\n"He went to the stroer to buy somethign"\n"She loves eating choclate cake" '],
#  ['Create a class in Python that represents a car '],
#  ['Explain the different components that make up an AI system. '],
#  ['Format the following sentence so it is gramatically correct. we need now to look back at important moments'],
#  ['Make up a riddle about mathematics. '],
#  ['Determine the length of the side of a square given the area. 24'],
#  ['Classify the given animals into two categories. Lion, Cheetah, Elephant'],
#  ['List three technologies that make life easier. '],
#  ['Translate the following sentence from English to Spanish. Output less than 25 words I am learning Spanish.'],
#  ['Create a database table for storing customer purchase history. '],
#  ['In this task, you need to restate the sentence using the given word. She was dancing. Word: twirl'],
#  ['Build an algorithm to detect fraud. '],
#  ['Describe the painting of the Mona Lisa. '],
#  ['Find an example of a C Major 7th chord on a piano. '],
#  ['Name any 5 spices that are commonly used in Indian cooking '],
# ...
#  ['Arrange the different food items in decreasing order of calories per portion. Food items: Apple, Burger, French Fries, Broccoli'],
#  ['Rewrite the following statement so it\'s more concise: "We must remember that the food that we eat can have an impact on our health." '],
#  ['Figure out the final principle payment amount for a loan with the given details. Principle balance: $400,000, Interest rate: 3.5%, Length of loan: 20 years'],
#  ['Complete the following sentence: "If I had the chance to visit a different country, I would choose _____." '],
#  ['Describe how home automation can save energy '],
#  ['Generate an algorithm for the game Hangman. '],
#  ['Create a two line poem about patience '],
#  ['Generate an appropriate response to the following instance message: "What’s the most popular sport in India?" '],
#  ['Compose an essay about the pros and cons of the internet. '],
#  ['Explain the role of physics in the study of astronomy. '],
#  ['Name the two methods of communication used in Conflict Resolution. '],
#  ['Generate a title for the story. Once upon a time, there was a bear who lived in the deep woods.'],
#  ['Design a voice assistant command to schedule an appointment. '],
#  ['Generate a random secret key for an encryption algorithm. '],
#  ['Describe the structure and function of an N-Gram language model. '],
#  ['Name five tools/equipment and their uses. '],
#  ['Create a unique name for a mobile game. '],
#  ['Create a password with 8 characters which includes two numbers. '],
#  ['Take the input string and make all the letters in it into capital letters, output the modified string. we like to learn'],
#  ["Give the French equivalent of the phrase 'It's raining cats and dogs'. "],
#  ['Create a new character for a classic Disney movie. '],
#  ['Outline the steps to send a package. noinput'],
#  ["How could living in a big city affect a person's life? "],
#  ['Construct an original sentence using the given word Lurid'],
#  ['Offer a solution for the following problem. Problem: A team is having communication issues.'],
#  ['Which word collocation is correct in the following sentence? In the 18th Century, European imports to the US __ vastly.'],
#  ['Describe what you like most about the city you live in '],
#  ['Given a string, reverse the order of the characters and print it on the screen Hello'],
#  ['Create a list of ideas for turning the text into a poem. The fields are golden with the wheat of summer.'],
#  ['Suggest a few approaches for dealing with the issue of climate change. '],
#  ['Take the given sentence and make a compound sentence with adjectives. We went to the beach.'],
#  ['Calculate the number of full days required to read a 400-pages book with a reading rate of 20 pages per day '],
#  ['Classify the following sentence as either an opinion or fact. A hot dog is just one of many types of processed meat you can eat.'],
#  ['Give an example of how natural language processing (NLP) has been used to address a real-world problem? '],
#  ['Write two verses of a song about nature. '],
#  ['Create a dialogue between a customer and a waiter. '],
#  ['Write a headline for a story involving a data breach. '],
#  ['Describe the impact of the coronavirus on the economy. '],
#  ['Describe the function of the hypothalamus '],
#  ['Create a blog post to discuss the current immigration laws in the United States '],
#  ['Create an analogie for the process of learning. Noinput'],
#  ['Create a sentence using a simile and a metaphor. '],
#  ['Explain why it is important to use a descriptive variable name in programming. '],
#  ['Write a couple of professional sentences in response to the following job offer The role of Medical Sales Representative is open to newly graduated nurses and/or established sales professionals'],
#  ['Create a list of at least five different types of fruits '],
#  ["Reformat the text for readability. we can do this task quickly. just say what the problem is and let's get it done"],
#  ['Make a list of common methods for debugging software. '],
#  ['Calculate the area of the triangle. Base: 5cm; Height: 6cm'],
#  ['Generate a list of health benefits associated with drinking green tea. '],
#  ['Select the correct answer from a list What is the second planet from the Sun?'],
#  ["Construct a regex for extracting names from a given string 'Jayden, Malcolm, and Jimmy went to school'"],
#  ['You are given a list of two or three items, create a unique story or dialogue that involves all the items. Apple, Robot'],
#  ['Return the hexadecimal code of the given color. Turquoise'],
#  ['Compare the two given pieces of prose below, explain the main difference between them. "The storm is raging over the sea while the sun is shining in the horizon."\n"Rain is pouring over the ocean while the sun is beaming in the distance."'],
#  ['Google the sentence "It was the best of times, it was the worst of times" and list the five top sources '],
#  ['Suggest a vegetarian breakfast menu. '],
#  ['What is the author\'s opinion about the stated topic? The article "The Pros and Cons of E-books"'],
#  ['What is the main purpose of blockchain technology? '],
#  ['Make an Italian pasta dish. '],
#  ['Detect the typos in the following sentence: I like to bak cakes. '],
#  ['Reorder the following words to form a question: the take lunch what do you the take lunch what do you'],
#  ['Wrte a short story about a character of your choice. Character: Adele the Fox'],
#  ['Provide an example of customer service email. '],
#  ['What is a good example of a real-time application? '],
#  ['Generate a hypothesis testing question related to education. '],
#  ['List the most common properties of a hologram. '],
#  ['How did the US respond to the attacks on 9/11? '],
#  ['Name a popular TV show from the 2000s '],
#  ['Find and replace the highlighted portion of the passage with a synonym. People agreed that the novel was much better than the film adaptation.'],
#  ['Suggest 3 topics as examples to write a blog post '],
#  ['Compare the benefits of an online course with the benefits of a traditional course. '],
#  ['Given a set of data, create a story based on the information Jack | age | 9 years old\nJack | hometown | New York City\nJack | hobby | building model airplanes'],
#  ['Find the independent clause (main clause) of a given sentence. I went to the store, but it was closed.'],
#  ['Classification task: Is the following sentence positive or negative? "I had the worst day ever." I had the worst day ever'],
#  ['What is the average lifespan of a Labrador Retriever? '],
#  ['Summarize how global warming affects the planet. '],
#  ['Formulate a mathematical equation to express the movement of 100 g of a substance from a temperature of 273 K to a temperature of 293 K. '],
#  ['Summarize in a sentence why it is important to make an effort to preserve native languages. '],
#  ['What is the best way to store certain types of food? Cheese'],
#  ['Create a sentence that describes the formation of a cloud. '],
#  ['Generate a metaphor describing a relentless pursuit. '],
#  ['Construct a Mathematical expression to find the cost after discount Original Cost= 100$\nDiscount percentage = 10%'],
#  ['Find the meaning of the phrase "out of the frying pan and into the fire" '],
#  ['Think of a game for two people to play. '],
#  ['Identify the following type of triangle: angle A = 60°, angle B = 60°, angle C = 60° '],
#  ['Outline the key steps to develop a website. '],
#  ['List out the steps to learn a new language '],
#  ['List three countries that have a population of more than 100 million people. '],
#  ['Suggest a topic that could be discussed in a debate. '],
#  ['How can businesses use AI technology to improve their marketing efforts? '],
#  ['Suggest an appropriate title for a comic about a cat and dog living together. '],
#  ["Give two pieces of advice based on the scenario. You just graduated from college and don't know what to do next."],
#  ['Speak about the given phrase for 1 minute. Impostor Syndrome'],
#  ['Create a user interface that allows users to search by keyword. '],
#  ['Look up the boiling point of water. '],
#  ['Suggest an example of a technology that utilizes natural language processing. '],
#  ['List four measures to prevent the spread of COVID-19. '],
#  ['Generate a ten word sentence with the word "raspberry". '],
#  ['Give an example of a syntax error in Python. '],
#  ['Categorize the following sentence according to the type of figure of speech used. She smiled with great delight.'],
#  ['Identify five key indicators of a healthy economy. '],
#  ["Explain the concept of 'Divide and Conquer'. "],
#  ['Create a program that can detect if a text is written in English. This text is written in English.'],
#  ['Tell me the two main types of monarchs '],
#  ['Given a sentence, detect whether the words follow the standard English grammar rules and punctuations. She brought the apple and oranges'],
#  ['Rewrite the given sentence by using a semicolon instead of a comma. She was a shy girl, yet she was able to speak in public.'],
#  ['Provide a contrastive statement related to the provided sentence. Education is important for personal development.'],
#  ['Explain the trade-offs of a decision-tree algorithm '],
#  ['Tell a story about a situation in which the person feels lonely. '],
#  ['Summarize the main argument of the paper "A Social Network that Influences Attitudes and Behaviors" '],
#  ['Create a story for a five-year-old about a person who moves to a new city. '],
#  ['Suggest a movie suitable for a family with children aged seven and twelve. '],
#  ['Generate a report summarizing the key statistics from the given dataset. https://data.worldbank.org/indicator/SP.POP.TOTL'],
#  ["Identify the type of writing style used in the text. The opening of the book was vivid and powerful, the author's words igniting a fire in our hearts."],
#  ['Gather information about a celebrity. Kaley Cuoco'],
#  ['Create a survey question about wildlife conservation '],
#  ['Edit the given text such that it becomes easier to read. The increasing usage of artificial inteligence requires additional considerations for the applications that require it for correct functioning.'],
#  ['Write about the benefits of cloud computing. '],
#  ['Compare and contrast socialism and communism. '],
#  ['Provide a solution to the equation 2a+3b=20 '],
#  ['Given two strings, find if one string is a sub-sequence of the other. String 1: abcd\nString 2: abcde'],
#  ['Generate a list of hobbies one can do indoors. '],
#  ['Explain why the moon looks different on different nights. '],
#  ['Give 5 examples of rodents. '],
#  ["Construct a sentence where the subject is 'my cat'. "],
#  ['Brainstorm new ways to use technology to save time. '],
#  ['Generate a list of 5 books related to space exploration '],
#  ['Create a call-to-action for a website '],
#  ['Describe what materials are required to build a birdhouse. '],
#  ['Print the following sentence in all capitals. The cat jumped on the bed.'],
#  ['What is the most common type of conflict in literature? '],
#  ['Tell me the population of the United States. '],
#  ["Create an example scenario to illustrate the concept of a 'domino effect'. "],
#  ["Generate a children's story with the following title: The Magic Violin. "],
#  ['Write four rhyming lines in the form of a poetic couplet. '],
#  ['Develop a persuasive argument to save the endangered species. '],
#  ['Explain the role of the Executive Branch of the U.S. government. '],
#  ['Given the following set of numbers, multiply them by two. 8, 15, 19'],
#  ['Suggest a creative way a small business can promote their marketing strategy. '],
#  ["Construct a data structure that stores the following information: A student's name, grade level and contact information. "],
#  ['Write a one-sentence description of the given US state. Delaware'],
#  ['False positive or false negative? A test result is negative but the person is actually having the infection.'],
#  ['Describe how machines can help people with their daily tasks. Noinput'],
#  ['Create a food allergy awareness campaign for a restaurant. '],
#  ['Add five entries to a list of US states. California, Florida, Texas, New York,'],
#  ['Convert the given number into its Roman numeral representation. 42'],
#  ['Categorize the following item: “Toyota Camry” '],
#  ['Generate a list of 5 idioms about happiness. '],
#  ['Give an example of how a computer can be used to control a manufacturing process. '],
#  ['Translate the following sentence from English to Spanish: "He was so tired that he fell asleep during the meeting." He was so tired that he fell asleep during the meeting.'],
#  ['Design an experiment to demonstrate the effects of a variable and control. '],
#  ['Describe the history of the automobile industry in the US. '],
#  ['Edit the sentence: The student went to sleep early for school. '],
#  ['Identify which of the options is the main argument of the passage. In recent years, the use of artificial intelligence has become increasingly widespread. AI is being used to automate processes, to increase efficiency, and to ramp up innovation across many industries. \n\nA) AI is rapidly becoming an essential part of the digital economy\nB) AI is helping to drive the growth of digital businesses\nC) AI is creating new opportunities for businesses in digital spaces\nD) AI is becoming essential for the digitalization of business processes'],
#  ['Suggest a plan for someone who wants to learn a new programming language. I want to learn Java.'],
#  ['How can an employer best motivate their employees to reach the next level of success? '],
#  ['In what year was the Taj Mahal built? '],
#  ['Generate a headline for a story about the death of a famous actor. Actor: Will Smith'],
#  ["Tell me what the antonym of 'tangible' is. "],
#  ['Given an input of a product title, classify it into a category. Apple iPhone 11 Pro Max'],
#  ['Assign a score out of 5 to the following book review. I really enjoyed this book. It was an engaging read and had an interesting plot.'],
#  ['Describe the impact of nanotechnology on medical treatments. '],
#  ['Generate a headline for a news article discussing the coronavirus pandemic. '],
#  ['Replace the bolded word with a suitable term from the given set The chef whipped up a delicious ___.\nOptions: soup, sauce, marinade'],
#  ["Compose a an original story using the words 'city' and 'river'. "],
#  ["Given the poem's title, create a single line stanza for the poem. The Joys of Life"],
#  ['Determine how many seconds are in a day. '],
#  ['Create an appropriate response to someone who made a mistake. '],
#  ['Generate a code snippet that prints the following word. Hello'],
#  ['Develop a new non-alcoholic drink that is perfect for a hot summer day. '],
#  ['Classify the food item given its nutritional information. Calories: 100 | Fat: 2g | Carbohydrates: 20g | Protein: 4g'],
#  ['Develop an AI assistant for grocery shopping. '],
#  ['Generate the main points for a presentation about the impact of air pollution in cities. '],
#  ['Given two pieces of text, compose a single sentence that combines their main points. Text 1: Apple has released a new phone.\nText 2: It has a powerful processor.'],
#  ['Given two cities, calculate the estimated travel time by car. San Francisco and Los Angeles'],
#  ['Name 5 different types of applications that can be developed with Python. '],
#  ['Remove the redundant verb from the sentence. He ran quickly ran to the store.'],
#  ['Describe a person in a way that will allow a machine learning algorithm to successfully classify the description as male or female in 10 words. '],
#  ["Write the opposite of 'She is doing the task'. "],
#  ['Name the members of a rock band '],
#  ['Give a sample dialogue of how to ask a customer for feedback. '],
#  ['List three benefits of the given technology. Cloud Computing'],
#  ['Compare and contrast print media and digital media. '],
#  ['Propose components for a customized AI solution. Solution: AI-Powered Image Recognition System'],
#  ['What is the best way to phrase the following sentence to sound more professional? We got it done quick.'],
#  ['Imagine an alternate world where humans no longer exist. Describe the environment. '],
#  ...]

# %%
res = Calmetic(references=refs,predictions=content)

# %%
print(res['BLEU']['precisions'])
print(res['ROUGE']['rougeL'][1])
# Out:
# [0.5876499170715851, 0.37760763629063165, 0.27798671116443674, 0.21013741833746338]
# Score(precision=0.5914537333495932, recall=0.5040462676649737, fmeasure=0.5289378745501897)

# %%
from transformers import BertTokenizer, BertModel
import torch
from torch.nn.functional import cosine_similarity as torch_cosine_similarity
from sentence_transformers import SentenceTransformer, util

sentence_model = SentenceTransformer('all-MiniLM-L6-v2')#SentenceTransformer("bert-base-uncased") 

reference_texts_ = [ i.replace('enquiry: ',"") for i in val_dataset_t5['target_text'] ]
embeddings1 = sentence_model.encode(content, convert_to_tensor=True)
embeddings2 = sentence_model.encode(reference_texts_, convert_to_tensor=True)

cosine_scores_2 = util.pytorch_cos_sim(embeddings1, embeddings2)   


print(f"Average Cosine Similarity: {cosine_scores_2.diagonal().mean()}")
print(f"Biggest Cosine Similarity: {cosine_scores_2.diagonal().max()}")
print(f"Middle Cosine Similarity: {cosine_scores_2.diagonal().median()}")
# Out:
# Average Cosine Similarity: 0.7711467146873474
# Biggest Cosine Similarity: 1.0000007152557373
# Middle Cosine Similarity: 0.8185164332389832

# %%
compare_df = pd.DataFrame(data={'answer':val_dataset_t5['output'],'gen_text':content,'ref':reference_texts_,'sim_score':cosine_scores_2.diagonal().cpu()})

# %%
compare_df
# Out:
#                                                   answer  \
# 0      Like a captivating work of fiction, a sunset d...
# 1      According to the World Health Organization, th...
# 2                                    #TheYouthWillRiseUp
# 3      1. **Cross-Validation:** Cross-validation is o...
# 4      It would be more suitable for a trained profes...
# ...                                                  ...
# 10396  Dave changed his mind quickly. Instead of stay...
# 10397  Interconnected nodes transmitting and sharing ...
# 10398  This article provides an overview of the histo...
# 10399  The vessel oscillated and fluctuated as the te...
# 10400                            It was hot in the room.
#
#                                                 gen_text  \
# 0              Create a metaphor to describe a sunset.\n
# 1      What is the leading cause of death for childre...
# 2      Generate a hashtag for a campaign to promote y...
# 3      List three validation techniques used in machi...
# 4      Identify a new butterfly species based on the ...
# ...                                                  ...
# 10396  Edit the following sentence to make it more co...
# 10397  Name two connected nodes that transmit and sha...
# 10398  Summarize this article about the history of th...
# 10399  Generate a sentence using the words "tempest",...
# 10400  Edit the following sentence to make it more co...
#
#                                                      ref  sim_score
# 0      Generate a simile comparing a sunset to fiction.    0.821832
# 1      What is the leading cause of death for childre...   1.000000
# 2      Generate a hashtag for a fictional political m...   0.744039
# 3      Name three common validation techniques used i...   0.933670
# 4      Assign an appropriate name to the following ne...   0.895642
# ...                                                  ...        ...
# 10396  Insert a sentence in the paragraph to provide ...   0.618833
# 10397           Describe a computer network in 5 words.    0.537861
# 10398  Provide a brief summary of the article "A Brie...   0.875040
# 10399  Rewrite the given passage using new vocabulary...   0.491592
# 10400  Remove the hyperbolic phrase from the followin...   0.617282
#
# [10401 rows x 4 columns]

# %%
sort_df = compare_df.sort_values('sim_score',ascending=False)

# %%
sort_df_part = sort_df[100:120]
sort_df_part.reset_index()
# Out:
#     index                                             answer  \
# 0    3361  Improving your persuasive writing technique in...
# 1    1541  Two animal species that live in the ocean are ...
# 2    9640  Here are some online marketing strategies that...
# 3    8740  One of the most common use cases for an AI vir...
# 4    4001  DNA replication is the process by which a cell...
# 5    9077  The closest galaxy to the Milky Way is the Can...
# 6    9820  Designing a machine learning algorithm to dete...
# 7    6214  One effective way to reduce stress is to pract...
# 8    1688  One possible algorithm to determine whether a ...
# 9    1980  A good credit score has several benefits, incl...
# 10   1149  One popular game that requires two players is ...
# 11   4671  Absolute advantage is an economic concept that...
# 12   5792  Here is one way to design an algorithm to find...
# 13   4669  To reduce the global plastic waste, we can tak...
# 14   8487  The maximum velocity of a jet powered boat var...
# 15   3854  The Google Pixel phone is known for its impres...
# 16   7242  One method of data encryption is the Advanced ...
# 17     60  One major feature of an eagle is its sharp and...
# 18   8493  Three branches of the military in the United S...
# 19   4678  There once was a young man named Tom, who drea...
#
#                                              gen_text  \
# 0   How can I improve my persuasive writing techni...
# 1   Name two animal species that live in the ocean.\n
# 2          Suggest some online marketing strategies\n
# 3   Describe a use case for an AI virtual assistan...
# 4           Explain the process of DNA replication.\n
# 5      What is the closest galaxy to the Milky Way?\n
# 6   Design a machine learning algorithm to detect ...
# 7                   Suggest a way to reduce stress.\n
# 8   Create an algorithm to determine whether a web...
# 9   What are the benefits of having a good credit ...
# 10   Name a popular game that requires two players.\n
# 11       Explain the concept of absolute advantage.\n
# 12  Design an algorithm to find the longest word i...
# 13      How can we reduce the global plastic waste?\n
# 14  What is the maximum velocity of a jet powered ...
# 15   Describe the features of a Google Pixel phone.\n
# 16              Name one method of data encryption.\n
# 17              Name one major feature of an eagle.\n
# 18  Name three branches of the military in the Uni...
# 19  Write a story about a person who goes on an ad...
#
#                                                   ref  sim_score
# 0   How can I improve my persuasive writing techni...        1.0
# 1    Name two animal species that live in the ocean.         1.0
# 2           Suggest some online marketing strategies         1.0
# 3   Describe a use case for an AI virtual assistant.         1.0
# 4            Explain the process of DNA replication.         1.0
# 5       What is the closest galaxy to the Milky Way?         1.0
# 6   Design a machine learning algorithm to detect ...        1.0
# 7                    Suggest a way to reduce stress.         1.0
# 8   Create an algorithm to determine whether a web...        1.0
# 9   What are the benefits of having a good credit ...        1.0
# 10    Name a popular game that requires two players.         1.0
# 11        Explain the concept of absolute advantage.         1.0
# 12  Design an algorithm to find the longest word i...        1.0
# 13       How can we reduce the global plastic waste?         1.0
# 14  What is the maximum velocity of a jet powered ...        1.0
# 15    Describe the features of a Google Pixel phone.         1.0
# 16               Name one method of data encryption.         1.0
# 17               Name one major feature of an eagle.         1.0
# 18  Name three branches of the military in the Uni...        1.0
# 19  Write a story about a person who goes on an ad...        1.0

# %%
idx = 5
print('Original_answer: ',sort_df_part.iloc[idx]['answer'])
mo_an = \
"While galaxies vary in distance from the Milky Way, one of the nearest is the Canis Major Dwarf Galaxy, positioned approximately 25,000 light years from the Milky Way's center and around 42,000 light years from our solar system. Interestingly, when discussing neighboring galaxies, many often think of the Andromeda Galaxy (M31), a much larger galaxy that lies about 2.5 million light years away and is commonly considered our closest major galactic neighbor. These cosmic relationships highlight both immediate proximity and the vast scales involved when observing galaxies beyond our own."
print('Modify_answer:  ',mo_an)
print('Ground_truth_enquiry: ',sort_df_part.iloc[idx]['ref'])
print('Origen_gen_enquiry: ',sort_df_part.iloc[idx]['gen_text'])
print('Aftmodify_gen_enquiry: ',generate_question(mo_an))
# Out:
# Original_answer:  The closest galaxy to the Milky Way is the Canis Major Dwarf Galaxy, which is about 25,000 light years away from the Milky Way's center, and 42,000 light years from our solar system. However, when most people ask about our neighboring galaxy, they are usually referring to the Andromeda Galaxy (M31), which is the closest major galaxy to ours and is located about 2.5 million light years away.
# Modify_answer:   While galaxies vary in distance from the Milky Way, one of the nearest is the Canis Major Dwarf Galaxy, positioned approximately 25,000 light years from the Milky Way's center and around 42,000 light years from our solar system. Interestingly, when discussing neighboring galaxies, many often think of the Andromeda Galaxy (M31), a much larger galaxy that lies about 2.5 million light years away and is commonly considered our closest major galactic neighbor. These cosmic relationships highlight both immediate proximity and the vast scales involved when observing galaxies beyond our own.
# Ground_truth_enquiry:  What is the closest galaxy to the Milky Way?
# Origen_gen_enquiry:  What is the closest galaxy to the Milky Way?
#
# Aftmodify_gen_enquiry:  enquiry: What is the closest galaxie to our solar system?
